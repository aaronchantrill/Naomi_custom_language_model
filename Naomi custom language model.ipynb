# %% [markdown]
# This notebook assumes you have installed Naomi, and Naomi created a Pocketsphinx directory at ~/.config/naomi/pocketsphinx and downloaded the standard en-US model.
#
# It also assumes you have installed phonetisaurus using `pip install phonetisaurus`
#
# You also need to have downloaded the VOSK 'en-US' language model https://alphacephei.com/vosk/models/vosk-model-en-us-0.22-compile.zip from https://alphacephei.com/vosk/lm and unzipped it into your ~/.config/naomi/vosk directory.
#
# You will also need to have installed the sphinxbase-utils package for access to the sphinx_jsgf2fsg command.

# %%
import os
import phonetisaurus
import re

# %% [markdown]
# # Pocketsphinx

# %%
# Read in the dictionary as a struct
RE_WORDS = re.compile(
    r"^(?P<word>[a-zA-Z0-9'\.\-]+)(\(\d\))?\s+(?P<pronunciation>[a-zA-Z]+.*[a-zA-Z0-9])\s*$"
)
lexicon = {}
with open(os.path.expanduser('~/.config/naomi/pocketsphinx/standard/en-US/cmudict.dict'), 'r') as f:
    line = f.readline()
    while line:
        one = False
        for match in RE_WORDS.finditer(line):
            one = True
            if(match.group('word') == 'magic'):
                print(f"{match.group('word')} {match.group('pronunciation')}")
            try:
                lexicon[match.group('word')].append(match.group('pronunciation').split())
            except KeyError:
                lexicon[match.group('word')]=[match.group('pronunciation').split()]
        if(not one):
            print(f"Unmatched line: {line}")
        line = f.readline()
lexicon
# Out:
# magic M AE JH IH K
# Unmatched line: mm M
# {"'bout": [['B', 'AW', 'T']],
#  "'cause": [['K', 'AH', 'Z']],
#  "'course": [['K', 'AO', 'R', 'S']],
#  "'cuse": [['K', 'Y', 'UW', 'Z']],
#  "'em": [['AH', 'M']],
#  "'frisco": [['F', 'R', 'IH', 'S', 'K', 'OW']],
#  "'gain": [['G', 'EH', 'N']],
#  "'kay": [['K', 'EY']],
#  "'m": [['AH', 'M']],
#  "'n": [['AH', 'N']],
#  "'round": [['R', 'AW', 'N', 'D']],
#  "'s": [['EH', 'S']],
#  "'til": [['T', 'IH', 'L']],
#  "'tis": [['T', 'IH', 'Z']],
#  "'twas": [['T', 'W', 'AH', 'Z']],
#  'a': [['AH'], ['EY']],
#  "a's": [['EY', 'Z']],
#  'a.': [['EY']],
#  "a.'s": [['EY', 'Z']],
#  'a.d.': [['EY', 'D', 'IY']],
#  'a.m.': [['EY', 'EH', 'M']],
#  'a.s': [['EY', 'Z']],
#  'aaa': [['T', 'R', 'IH', 'P', 'AH', 'L', 'EY']],
#  'aaberg': [['AA', 'B', 'ER', 'G']],
#  'aachen': [['AA', 'K', 'AH', 'N']],
#  'aachener': [['AA', 'K', 'AH', 'N', 'ER']],
#  'aaker': [['AA', 'K', 'ER']],
#  'aaliyah': [['AA', 'L', 'IY', 'AA']],
#  'aalseth': [['AA', 'L', 'S', 'EH', 'TH']],
#  'aamodt': [['AA', 'M', 'AH', 'T']],
#  'aancor': [['AA', 'N', 'K', 'AO', 'R']],
#  'aardema': [['AA', 'R', 'D', 'EH', 'M', 'AH']],
#  'aardvark': [['AA', 'R', 'D', 'V', 'AA', 'R', 'K']],
#  'aardvarks': [['AA', 'R', 'D', 'V', 'AA', 'R', 'K', 'S']],
#  'aargh': [['AA', 'R', 'G']],
#  'aarhus': [['AA', 'HH', 'UW', 'S']],
#  'aaron': [['EH', 'R', 'AH', 'N']],
#  "aaron's": [['EH', 'R', 'AH', 'N', 'Z']],
#  'aarons': [['EH', 'R', 'AH', 'N', 'Z']],
#  'aaronson': [['EH', 'R', 'AH', 'N', 'S', 'AH', 'N'],
#   ['AA', 'R', 'AH', 'N', 'S', 'AH', 'N']],
#  "aaronson's": [['EH', 'R', 'AH', 'N', 'S', 'AH', 'N', 'Z'],
#   ['AA', 'R', 'AH', 'N', 'S', 'AH', 'N', 'Z']],
#  'aarti': [['AA', 'R', 'T', 'IY']],
#  'aase': [['AA', 'S']],
#  'aasen': [['AA', 'S', 'AH', 'N']],
#  'ab': [['AE', 'B'], ['EY', 'B', 'IY']],
#  'aba': [['EY', 'B', 'IY', 'EY']],
#  'ababa': [['AH', 'B', 'AA', 'B', 'AH'], ['AA', 'B', 'AH', 'B', 'AH']],
#  'abacha': [['AE', 'B', 'AH', 'K', 'AH']],
#  'aback': [['AH', 'B', 'AE', 'K']],
#  'abaco': [['AE', 'B', 'AH', 'K', 'OW']],
#  'abacus': [['AE', 'B', 'AH', 'K', 'AH', 'S']],
#  'abad': [['AH', 'B', 'AA', 'D']],
#  'abadaka': [['AH', 'B', 'AE', 'D', 'AH', 'K', 'AH']],
#  'abadi': [['AH', 'B', 'AE', 'D', 'IY']],
#  'abadie': [['AH', 'B', 'AE', 'D', 'IY']],
#  'abair': [['AH', 'B', 'EH', 'R']],
#  'abalkin': [['AH', 'B', 'AA', 'L', 'K', 'IH', 'N']],
#  'abalone': [['AE', 'B', 'AH', 'L', 'OW', 'N', 'IY']],
#  'abalones': [['AE', 'B', 'AH', 'L', 'OW', 'N', 'IY', 'Z']],
#  'abalos': [['AA', 'B', 'AA', 'L', 'OW', 'Z']],
#  'abandon': [['AH', 'B', 'AE', 'N', 'D', 'AH', 'N']],
#  'abandoned': [['AH', 'B', 'AE', 'N', 'D', 'AH', 'N', 'D']],
#  'abandoning': [['AH', 'B', 'AE', 'N', 'D', 'AH', 'N', 'IH', 'NG']],
#  'abandonment': [['AH', 'B', 'AE', 'N', 'D', 'AH', 'N', 'M', 'AH', 'N', 'T']],
#  'abandonments': [['AH',
#    'B',
#    'AE',
#    'N',
#    'D',
#    'AH',
#    'N',
#    'M',
#    'AH',
#    'N',
#    'T',
#    'S']],
#  'abandons': [['AH', 'B', 'AE', 'N', 'D', 'AH', 'N', 'Z']],
#  'abanto': [['AH', 'B', 'AE', 'N', 'T', 'OW']],
#  'abarca': [['AH', 'B', 'AA', 'R', 'K', 'AH']],
#  'abare': [['AA', 'B', 'AA', 'R', 'IY']],
#  'abascal': [['AE', 'B', 'AH', 'S', 'K', 'AH', 'L']],
#  'abash': [['AH', 'B', 'AE', 'SH']],
#  'abashed': [['AH', 'B', 'AE', 'SH', 'T']],
#  'abasia': [['AH', 'B', 'EY', 'ZH', 'Y', 'AH']],
#  'abate': [['AH', 'B', 'EY', 'T']],
#  'abated': [['AH', 'B', 'EY', 'T', 'IH', 'D']],
#  'abatement': [['AH', 'B', 'EY', 'T', 'M', 'AH', 'N', 'T']],
#  'abatements': [['AH', 'B', 'EY', 'T', 'M', 'AH', 'N', 'T', 'S']],
#  'abates': [['AH', 'B', 'EY', 'T', 'S']],
#  'abating': [['AH', 'B', 'EY', 'T', 'IH', 'NG']],
#  'abattoir': [['AE', 'B', 'AH', 'T', 'W', 'AA', 'R']],
#  'abba': [['AE', 'B', 'AH']],
#  'abbado': [['AH', 'B', 'AA', 'D', 'OW']],
#  'abbas': [['AH', 'B', 'AA', 'S']],
#  'abbasi': [['AA', 'B', 'AA', 'S', 'IY']],
#  'abbate': [['AA', 'B', 'EY', 'T']],
#  'abbatiello': [['AA', 'B', 'AA', 'T', 'IY', 'EH', 'L', 'OW']],
#  'abbe': [['AE', 'B', 'IY'], ['AE', 'B', 'EY']],
#  'abbenhaus': [['AE', 'B', 'AH', 'N', 'HH', 'AW', 'S']],
#  'abbett': [['AH', 'B', 'EH', 'T']],
#  'abbeville': [['AE', 'B', 'V', 'IH', 'L']],
#  'abbey': [['AE', 'B', 'IY']],
#  "abbey's": [['AE', 'B', 'IY', 'Z']],
#  'abbie': [['AE', 'B', 'IY']],
#  'abbitt': [['AE', 'B', 'IH', 'T']],
#  'abbot': [['AE', 'B', 'AH', 'T']],
#  'abbotstown': [['AE', 'B', 'AH', 'T', 'S', 'T', 'AW', 'N']],
#  'abbott': [['AE', 'B', 'AH', 'T']],
#  "abbott's": [['AE', 'B', 'AH', 'T', 'S']],
#  'abbottstown': [['AE', 'B', 'AH', 'T', 'S', 'T', 'AW', 'N']],
#  'abboud': [['AH', 'B', 'UW', 'D'], ['AH', 'B', 'AW', 'D']],
#  'abbreviate': [['AH', 'B', 'R', 'IY', 'V', 'IY', 'EY', 'T']],
#  'abbreviated': [['AH', 'B', 'R', 'IY', 'V', 'IY', 'EY', 'T', 'IH', 'D']],
#  'abbreviates': [['AH', 'B', 'R', 'IY', 'V', 'IY', 'EY', 'T', 'S']],
#  'abbreviating': [['AH', 'B', 'R', 'IY', 'V', 'IY', 'EY', 'T', 'IH', 'NG']],
#  'abbreviation': [['AH', 'B', 'R', 'IY', 'V', 'IY', 'EY', 'SH', 'AH', 'N']],
#  'abbreviations': [['AH',
#    'B',
#    'R',
#    'IY',
#    'V',
#    'IY',
#    'EY',
#    'SH',
#    'AH',
#    'N',
#    'Z']],
#  'abbruzzese': [['AA', 'B', 'R', 'UW', 'T', 'S', 'EY', 'Z', 'IY']],
#  'abbs': [['AE', 'B', 'Z']],
#  'abby': [['AE', 'B', 'IY']],
#  'abc': [['EY', 'B', 'IY', 'S', 'IY']],
#  "abc's": [['EY', 'B', 'IY', 'S', 'IY', 'Z']],
#  'abco': [['AE', 'B', 'K', 'OW']],
#  'abcotek': [['AE', 'B', 'K', 'OW', 'T', 'EH', 'K']],
#  'abcs': [['EY', 'B', 'IY', 'S', 'IY', 'Z']],
#  'abd': [['EY', 'B', 'IY', 'D', 'IY']],
#  'abdalla': [['AE', 'B', 'D', 'AE', 'L', 'AH']],
#  'abdallah': [['AE', 'B', 'D', 'AE', 'L', 'AH']],
#  'abdel': [['AE', 'B', 'D', 'EH', 'L']],
#  'abdella': [['AE', 'B', 'D', 'EH', 'L', 'AH']],
#  'abdicate': [['AE', 'B', 'D', 'AH', 'K', 'EY', 'T']],
#  'abdicated': [['AE', 'B', 'D', 'AH', 'K', 'EY', 'T', 'IH', 'D']],
#  'abdicates': [['AE', 'B', 'D', 'AH', 'K', 'EY', 'T', 'S']],
#  'abdicating': [['AE', 'B', 'D', 'IH', 'K', 'EY', 'T', 'IH', 'NG']],
#  'abdication': [['AE', 'B', 'D', 'IH', 'K', 'EY', 'SH', 'AH', 'N']],
#  'abdnor': [['AE', 'B', 'D', 'N', 'ER']],
#  'abdo': [['AE', 'B', 'D', 'OW']],
#  'abdollah': [['AE', 'B', 'D', 'AA', 'L', 'AH']],
#  'abdomen': [['AE', 'B', 'D', 'OW', 'M', 'AH', 'N'],
#   ['AE', 'B', 'D', 'AH', 'M', 'AH', 'N']],
#  'abdominal': [['AE', 'B', 'D', 'AA', 'M', 'AH', 'N', 'AH', 'L'],
#   ['AH', 'B', 'D', 'AA', 'M', 'AH', 'N', 'AH', 'L']],
#  'abduct': [['AE', 'B', 'D', 'AH', 'K', 'T']],
#  'abducted': [['AE', 'B', 'D', 'AH', 'K', 'T', 'IH', 'D'],
#   ['AH', 'B', 'D', 'AH', 'K', 'T', 'IH', 'D']],
#  'abductee': [['AE', 'B', 'D', 'AH', 'K', 'T', 'IY']],
#  'abductees': [['AE', 'B', 'D', 'AH', 'K', 'T', 'IY', 'Z']],
#  'abducting': [['AE', 'B', 'D', 'AH', 'K', 'T', 'IH', 'NG'],
#   ['AH', 'B', 'D', 'AH', 'K', 'T', 'IH', 'NG']],
#  'abduction': [['AE', 'B', 'D', 'AH', 'K', 'SH', 'AH', 'N'],
#   ['AH', 'B', 'D', 'AH', 'K', 'SH', 'AH', 'N']],
#  'abductions': [['AE', 'B', 'D', 'AH', 'K', 'SH', 'AH', 'N', 'Z'],
#   ['AH', 'B', 'D', 'AH', 'K', 'SH', 'AH', 'N', 'Z']],
#  'abductor': [['AE', 'B', 'D', 'AH', 'K', 'T', 'ER'],
#   ['AH', 'B', 'D', 'AH', 'K', 'T', 'ER']],
#  'abductors': [['AE', 'B', 'D', 'AH', 'K', 'T', 'ER', 'Z'],
#   ['AH', 'B', 'D', 'AH', 'K', 'T', 'ER', 'Z']],
#  'abducts': [['AE', 'B', 'D', 'AH', 'K', 'T', 'S']],
#  'abdul': [['AE', 'B', 'D', 'UW', 'L']],
#  'abdulaziz': [['AE', 'B', 'D', 'UW', 'L', 'AH', 'Z', 'IY', 'Z']],
#  'abdulla': [['AA', 'B', 'D', 'UW', 'L', 'AH']],
#  'abdullah': [['AE', 'B', 'D', 'AH', 'L', 'AH']],
#  'abe': [['EY', 'B']],
#  'abed': [['AH', 'B', 'EH', 'D']],
#  'abedi': [['AH', 'B', 'EH', 'D', 'IY']],
#  'abee': [['AH', 'B', 'IY']],
#  'abel': [['EY', 'B', 'AH', 'L']],
#  'abela': [['AA', 'B', 'EH', 'L', 'AH']],
#  'abelard': [['AE', 'B', 'IH', 'L', 'ER', 'D']],
#  'abele': [['AH', 'B', 'EH', 'L']],
#  'abeles': [['AH', 'B', 'EH', 'L', 'Z'], ['EY', 'B', 'AH', 'L', 'IY', 'Z']],
#  'abell': [['EY', 'B', 'AH', 'L']],
#  'abella': [['AH', 'B', 'EH', 'L', 'AH']],
#  'abeln': [['AE', 'B', 'IH', 'L', 'N']],
#  'abelow': [['AE', 'B', 'AH', 'L', 'OW']],
#  'abels': [['EY', 'B', 'AH', 'L', 'Z']],
#  'abelson': [['AE', 'B', 'IH', 'L', 'S', 'AH', 'N']],
#  'abend': [['AE', 'B', 'EH', 'N', 'D'], ['AH', 'B', 'EH', 'N', 'D']],
#  'abendroth': [['AE', 'B', 'IH', 'N', 'D', 'R', 'AO', 'TH']],
#  'aber': [['EY', 'B', 'ER']],
#  'abercrombie': [['AE', 'B', 'ER', 'K', 'R', 'AA', 'M', 'B', 'IY']],
#  'aberdeen': [['AE', 'B', 'ER', 'D', 'IY', 'N']],
#  'aberford': [['EY', 'B', 'ER', 'F', 'ER', 'D']],
#  'aberg': [['AE', 'B', 'ER', 'G']],
#  'aberle': [['AE', 'B', 'ER', 'AH', 'L'], ['AE', 'B', 'ER', 'L']],
#  'abermin': [['AE', 'B', 'ER', 'M', 'IH', 'N']],
#  'abernathy': [['AE', 'B', 'ER', 'N', 'AE', 'TH', 'IY']],
#  'abernethy': [['AE', 'B', 'ER', 'N', 'EH', 'TH', 'IY']],
#  'aberrant': [['AE', 'B', 'EH', 'R', 'AH', 'N', 'T']],
#  'aberration': [['AE', 'B', 'ER', 'EY', 'SH', 'AH', 'N']],
#  'aberrational': [['AE', 'B', 'ER', 'EY', 'SH', 'AH', 'N', 'AH', 'L']],
#  'aberrations': [['AE', 'B', 'ER', 'EY', 'SH', 'AH', 'N', 'Z']],
#  'abert': [['AE', 'B', 'ER', 'T']],
#  'abet': [['AH', 'B', 'EH', 'T']],
#  'abetted': [['AH', 'B', 'EH', 'T', 'IH', 'D']],
#  'abetting': [['AH', 'B', 'EH', 'T', 'IH', 'NG']],
#  'abex': [['EY', 'B', 'EH', 'K', 'S']],
#  'abeyance': [['AH', 'B', 'EY', 'AH', 'N', 'S']],
#  'abeyta': [['AA', 'B', 'EY', 'T', 'AH']],
#  'abhor': [['AE', 'B', 'HH', 'AO', 'R']],
#  'abhorred': [['AH', 'B', 'HH', 'AO', 'R', 'D']],
#  'abhorrence': [['AH', 'B', 'HH', 'AO', 'R', 'AH', 'N', 'S']],
#  'abhorrent': [['AE', 'B', 'HH', 'AO', 'R', 'AH', 'N', 'T']],
#  'abhors': [['AH', 'B', 'HH', 'AO', 'R', 'Z']],
#  'abiam': [['EY', 'B', 'IY', 'AH', 'M']],
#  "abiam's": [['EY', 'B', 'IY', 'AH', 'M', 'Z']],
#  'abid': [['EY', 'B', 'IH', 'D']],
#  'abide': [['AH', 'B', 'AY', 'D']],
#  'abided': [['AH', 'B', 'AY', 'D', 'IH', 'D']],
#  'abides': [['AH', 'B', 'AY', 'D', 'Z']],
#  'abiding': [['AH', 'B', 'AY', 'D', 'IH', 'NG']],
#  'abidjan': [['AE', 'B', 'IH', 'JH', 'AA', 'N']],
#  'abie': [['AE', 'B', 'IY']],
#  'abigail': [['AE', 'B', 'AH', 'G', 'EY', 'L']],
#  'abila': [['AA', 'B', 'IY', 'L', 'AH']],
#  'abilene': [['AE', 'B', 'IH', 'L', 'IY', 'N']],
#  'abilities': [['AH', 'B', 'IH', 'L', 'AH', 'T', 'IY', 'Z']],
#  'ability': [['AH', 'B', 'IH', 'L', 'AH', 'T', 'IY']],
#  'abimael': [['AE', 'B', 'IH', 'M', 'EY', 'L']],
#  'abimaels': [['AE', 'B', 'IH', 'M', 'EY', 'L', 'Z']],
#  'abingdon': [['AE', 'B', 'IH', 'NG', 'D', 'AH', 'N']],
#  'abington': [['AE', 'B', 'IH', 'NG', 'T', 'AH', 'N']],
#  'abio': [['AA', 'B', 'IY', 'OW']],
#  'abiola': [['AA', 'B', 'IY', 'OW', 'L', 'AH']],
#  "abiola's": [['AA', 'B', 'IY', 'OW', 'L', 'AH', 'Z']],
#  'abiomed': [['EY', 'B', 'IY', 'AH', 'M', 'EH', 'D']],
#  'abiquiu': [['AH', 'B', 'IH', 'K', 'Y', 'UW']],
#  'abitibi': [['AE', 'B', 'IH', 'T', 'IY', 'B', 'IY']],
#  'abitz': [['AE', 'B', 'IH', 'T', 'S']],
#  'abject': [['AE', 'B', 'JH', 'EH', 'K', 'T']],
#  'abkhazia': [['AE', 'B', 'K', 'AA', 'Z', 'Y', 'AH'],
#   ['AE', 'B', 'K', 'AE', 'Z', 'Y', 'AH']],
#  'abkhazian': [['AE', 'B', 'K', 'AA', 'Z', 'IY', 'AH', 'N'],
#   ['AE', 'B', 'K', 'AE', 'Z', 'IY', 'AH', 'N'],
#   ['AE', 'B', 'K', 'AA', 'Z', 'Y', 'AH', 'N'],
#   ['AE', 'B', 'K', 'AE', 'Z', 'Y', 'AH', 'N']],
#  'abkhazians': [['AE', 'B', 'K', 'AA', 'Z', 'IY', 'AH', 'N', 'Z'],
#   ['AE', 'B', 'K', 'AE', 'Z', 'IY', 'AH', 'N', 'Z']],
#  'ablate': [['AH', 'B', 'L', 'EY', 'T']],
#  'ablation': [['AH', 'B', 'L', 'EY', 'SH', 'AH', 'N']],
#  'ablaze': [['AH', 'B', 'L', 'EY', 'Z']],
#  'able': [['EY', 'B', 'AH', 'L']],
#  'able-bodied': [['EY', 'B', 'AH', 'L', 'B', 'AA', 'D', 'IY', 'D']],
#  'abled': [['EY', 'B', 'AH', 'L', 'D']],
#  'abler': [['EY', 'B', 'AH', 'L', 'ER'], ['EY', 'B', 'L', 'ER']],
#  'ables': [['EY', 'B', 'AH', 'L', 'Z']],
#  'ablest': [['EY', 'B', 'AH', 'L', 'S', 'T'],
#   ['EY', 'B', 'L', 'AH', 'S', 'T']],
#  'abloom': [['AH', 'B', 'L', 'UW', 'M']],
#  'ablution': [['AH', 'B', 'L', 'UW', 'SH', 'AH', 'N']],
#  'ablutions': [['AH', 'B', 'L', 'UW', 'SH', 'AH', 'N', 'Z']],
#  'ably': [['EY', 'B', 'L', 'IY']],
#  'abnegation': [['AE', 'B', 'N', 'EH', 'G', 'EY', 'SH', 'AH', 'N']],
#  'abner': [['AE', 'B', 'N', 'ER']],
#  'abney': [['AE', 'B', 'N', 'IY']],
#  'abnormal': [['AE', 'B', 'N', 'AO', 'R', 'M', 'AH', 'L']],
#  'abnormalities': [['AE',
#    'B',
#    'N',
#    'AO',
#    'R',
#    'M',
#    'AE',
#    'L',
#    'AH',
#    'T',
#    'IY',
#    'Z']],
#  'abnormality': [['AE', 'B', 'N', 'AO', 'R', 'M', 'AE', 'L', 'AH', 'T', 'IY']],
#  'abnormally': [['AE', 'B', 'N', 'AO', 'R', 'M', 'AH', 'L', 'IY']],
#  'abo': [['AA', 'B', 'OW']],
#  "abo's": [['AA', 'B', 'OW', 'Z']],
#  'aboard': [['AH', 'B', 'AO', 'R', 'D']],
#  'abode': [['AH', 'B', 'OW', 'D']],
#  'abohalima': [['AE', 'B', 'AH', 'HH', 'AH', 'L', 'IY', 'M', 'AH']],
#  'abolish': [['AH', 'B', 'AA', 'L', 'IH', 'SH']],
#  'abolished': [['AH', 'B', 'AA', 'L', 'IH', 'SH', 'T']],
#  'abolishes': [['AH', 'B', 'AA', 'L', 'IH', 'SH', 'IH', 'Z']],
#  'abolishing': [['AH', 'B', 'AA', 'L', 'IH', 'SH', 'IH', 'NG']],
#  'abolition': [['AE', 'B', 'AH', 'L', 'IH', 'SH', 'AH', 'N']],
#  'abolitionism': [['AE',
#    'B',
#    'AH',
#    'L',
#    'IH',
#    'SH',
#    'AH',
#    'N',
#    'IH',
#    'Z',
#    'AH',
#    'M']],
#  'abolitionist': [['AE',
#    'B',
#    'AH',
#    'L',
#    'IH',
#    'SH',
#    'AH',
#    'N',
#    'AH',
#    'S',
#    'T']],
#  'abolitionists': [['AE',
#    'B',
#    'AH',
#    'L',
#    'IH',
#    'SH',
#    'AH',
#    'N',
#    'AH',
#    'S',
#    'T',
#    'S']],
#  'abominable': [['AH', 'B', 'AA', 'M', 'AH', 'N', 'AH', 'B', 'AH', 'L']],
#  'abomination': [['AH', 'B', 'AA', 'M', 'AH', 'N', 'EY', 'SH', 'AH', 'N']],
#  'abominations': [['AH',
#    'B',
#    'AA',
#    'M',
#    'AH',
#    'N',
#    'EY',
#    'SH',
#    'AH',
#    'N',
#    'Z']],
#  'abood': [['AH', 'B', 'UW', 'D']],
#  'aboodi': [['AH', 'B', 'UW', 'D', 'IY']],
#  'abor': [['AH', 'B', 'AO', 'R']],
#  'aboriginal': [['AE', 'B', 'ER', 'IH', 'JH', 'AH', 'N', 'AH', 'L']],
#  'aborigine': [['AE', 'B', 'ER', 'IH', 'JH', 'AH', 'N', 'IY']],
#  'aborigines': [['AE', 'B', 'ER', 'IH', 'JH', 'AH', 'N', 'IY', 'Z']],
#  'aborn': [['AH', 'B', 'AO', 'R', 'N']],
#  'abort': [['AH', 'B', 'AO', 'R', 'T']],
#  'aborted': [['AH', 'B', 'AO', 'R', 'T', 'IH', 'D']],
#  'abortifacient': [['AH',
#    'B',
#    'AO',
#    'R',
#    'T',
#    'AH',
#    'F',
#    'EY',
#    'SH',
#    'AH',
#    'N',
#    'T']],
#  'abortifacients': [['AH',
#    'B',
#    'AO',
#    'R',
#    'T',
#    'AH',
#    'F',
#    'EY',
#    'SH',
#    'AH',
#    'N',
#    'T',
#    'S']],
#  'aborting': [['AH', 'B', 'AO', 'R', 'T', 'IH', 'NG']],
#  'abortion': [['AH', 'B', 'AO', 'R', 'SH', 'AH', 'N']],
#  'abortionist': [['AH', 'B', 'AO', 'R', 'SH', 'AH', 'N', 'IH', 'S', 'T']],
#  'abortionists': [['AH',
#    'B',
#    'AO',
#    'R',
#    'SH',
#    'AH',
#    'N',
#    'IH',
#    'S',
#    'T',
#    'S']],
#  'abortions': [['AH', 'B', 'AO', 'R', 'SH', 'AH', 'N', 'Z']],
#  'abortive': [['AH', 'B', 'AO', 'R', 'T', 'IH', 'V']],
#  'aborts': [['AH', 'B', 'AO', 'R', 'T', 'S']],
#  'abott': [['AH', 'B', 'AA', 'T']],
#  'abou': [['AH', 'B', 'UW']],
#  'aboud': [['AA', 'B', 'UW', 'D']],
#  'abouhalima': [['AA', 'B', 'UW', 'HH', 'AA', 'L', 'IY', 'M', 'AH']],
#  "abouhalima's": [['AA', 'B', 'UW', 'HH', 'AA', 'L', 'IY', 'M', 'AH', 'Z']],
#  'abound': [['AH', 'B', 'AW', 'N', 'D']],
#  'abounded': [['AH', 'B', 'AW', 'N', 'D', 'IH', 'D']],
#  'abounding': [['AH', 'B', 'AW', 'N', 'D', 'IH', 'NG']],
#  'abounds': [['AH', 'B', 'AW', 'N', 'D', 'Z']],
#  'about': [['AH', 'B', 'AW', 'T']],
#  "about's": [['AH', 'B', 'AW', 'T', 'S']],
#  'above': [['AH', 'B', 'AH', 'V']],
#  "above's": [['AH', 'B', 'AH', 'V', 'Z']],
#  'aboveboard': [['AH', 'B', 'AH', 'V', 'B', 'AO', 'R', 'D']],
#  'abplanalp': [['AE', 'B', 'P', 'L', 'AH', 'N', 'AE', 'L', 'P']],
#  'abra': [['AA', 'B', 'R', 'AH']],
#  'abracadabra': [['AE', 'B', 'R', 'AH', 'K', 'AH', 'D', 'AE', 'B', 'R', 'AH']],
#  'abrade': [['AE', 'B', 'R', 'EY', 'D']],
#  'abraded': [['AE', 'B', 'R', 'EY', 'D', 'IH', 'D']],
#  'abrades': [['AE', 'B', 'R', 'EY', 'D', 'Z']],
#  'abraham': [['EY', 'B', 'R', 'AH', 'HH', 'AE', 'M']],
#  'abrahamian': [['AE', 'B', 'R', 'AH', 'HH', 'EY', 'M', 'IY', 'AH', 'N']],
#  'abrahams': [['EY', 'B', 'R', 'AH', 'HH', 'AE', 'M', 'Z']],
#  'abrahamsen': [['AE', 'B', 'R', 'AH', 'HH', 'AE', 'M', 'S', 'AH', 'N']],
#  'abrahamson': [['AH', 'B', 'R', 'AE', 'HH', 'AH', 'M', 'S', 'AH', 'N']],
#  'abram': [['AH', 'B', 'R', 'AE', 'M']],
#  "abram's": [['EY', 'B', 'R', 'AH', 'M', 'Z']],
#  'abramczyk': [['AA', 'B', 'R', 'AH', 'M', 'CH', 'IH', 'K']],
#  'abramo': [['AA', 'B', 'R', 'AA', 'M', 'OW']],
#  'abramovitz': [['AH', 'B', 'R', 'AA', 'M', 'AH', 'V', 'IH', 'T', 'S']],
#  'abramowicz': [['AH', 'B', 'R', 'AA', 'M', 'AH', 'V', 'IH', 'CH']],
#  'abramowitz': [['AH', 'B', 'R', 'AA', 'M', 'AH', 'W', 'IH', 'T', 'S']],
#  'abrams': [['EY', 'B', 'R', 'AH', 'M', 'Z']],
#  "abrams's": [['EY', 'B', 'R', 'AH', 'M', 'Z', 'IH', 'Z']],
#  'abramson': [['EY', 'B', 'R', 'AH', 'M', 'S', 'AH', 'N']],
#  'abrasion': [['AH', 'B', 'R', 'EY', 'ZH', 'AH', 'N']],
#  'abrasions': [['AH', 'B', 'R', 'EY', 'ZH', 'AH', 'N', 'Z']],
#  'abrasive': [['AH', 'B', 'R', 'EY', 'S', 'IH', 'V']],
#  'abrasives': [['AH', 'B', 'R', 'EY', 'S', 'IH', 'V', 'Z']],
#  'abraxa': [['AH', 'B', 'R', 'AE', 'K', 'S', 'AH']],
#  "abraxa's": [['AH', 'B', 'R', 'AE', 'K', 'S', 'AH', 'Z']],
#  'abraxas': [['AH', 'B', 'R', 'AE', 'K', 'S', 'AH', 'Z']],
#  'abreast': [['AH', 'B', 'R', 'EH', 'S', 'T']],
#  'abrego': [['AA', 'B', 'R', 'EH', 'G', 'OW']],
#  'abreu': [['AH', 'B', 'R', 'UW']],
#  'abridge': [['AH', 'B', 'R', 'IH', 'JH']],
#  'abridged': [['AH', 'B', 'R', 'IH', 'JH', 'D']],
#  'abridgement': [['AH', 'B', 'R', 'IH', 'JH', 'M', 'AH', 'N', 'T']],
#  'abridges': [['AH', 'B', 'R', 'IH', 'JH', 'AH', 'Z']],
#  'abridging': [['AH', 'B', 'R', 'IH', 'JH', 'IH', 'NG']],
#  'abril': [['AH', 'B', 'R', 'IH', 'L']],
#  'abroad': [['AH', 'B', 'R', 'AO', 'D']],
#  'abrogate': [['AE', 'B', 'R', 'AH', 'G', 'EY', 'T']],
#  'abrogated': [['AE', 'B', 'R', 'AH', 'G', 'EY', 'T', 'IH', 'D']],
#  'abrogating': [['AE', 'B', 'R', 'AH', 'G', 'EY', 'T', 'IH', 'NG']],
#  'abrogation': [['AE', 'B', 'R', 'AH', 'G', 'EY', 'SH', 'AH', 'N']],
#  'abrol': [['AH', 'B', 'R', 'OW', 'L']],
#  'abron': [['AH', 'B', 'R', 'AA', 'N']],
#  'abrupt': [['AH', 'B', 'R', 'AH', 'P', 'T']],
#  'abruptly': [['AH', 'B', 'R', 'AH', 'P', 'T', 'L', 'IY']],
#  'abruptness': [['AH', 'B', 'R', 'AH', 'P', 'T', 'N', 'AH', 'S']],
#  'abrutyn': [['EY', 'B', 'R', 'UW', 'T', 'IH', 'N']],
#  'abruzzese': [['AA', 'B', 'R', 'UW', 'T', 'S', 'EY', 'Z', 'IY']],
#  'abruzzo': [['AA', 'B', 'R', 'UW', 'Z', 'OW']],
#  'abs': [['EY', 'B', 'IY', 'EH', 'S'], ['AE', 'B', 'Z']],
#  'absalom': [['AE', 'B', 'S', 'AH', 'L', 'AH', 'M']],
#  'absaraka': [['AE', 'B', 'S', 'AA', 'R', 'AH', 'K', 'AH']],
#  'abscam': [['AE', 'B', 'S', 'K', 'AE', 'M']],
#  'abscess': [['AE', 'B', 'S', 'EH', 'S']],
#  'abscond': [['AE', 'B', 'S', 'K', 'AA', 'N', 'D']],
#  'absconded': [['AE', 'B', 'S', 'K', 'AA', 'N', 'D', 'IH', 'D']],
#  'absconding': [['AE', 'B', 'S', 'K', 'AA', 'N', 'D', 'IH', 'NG']],
#  'absconds': [['AE', 'B', 'S', 'K', 'AA', 'N', 'D', 'Z']],
#  'absecon': [['AE', 'B', 'S', 'AH', 'K', 'AO', 'N']],
#  'absence': [['AE', 'B', 'S', 'AH', 'N', 'S']],
#  'absences': [['AE', 'B', 'S', 'AH', 'N', 'S', 'IH', 'Z']],
#  'absent': [['AE', 'B', 'S', 'AH', 'N', 'T']],
#  'absentee': [['AE', 'B', 'S', 'AH', 'N', 'T', 'IY']],
#  'absenteeism': [['AE', 'B', 'S', 'AH', 'N', 'T', 'IY', 'IH', 'Z', 'AH', 'M']],
#  'absentees': [['AE', 'B', 'S', 'AH', 'N', 'T', 'IY', 'Z']],
#  'absentia': [['AE', 'B', 'S', 'EH', 'N', 'SH', 'AH']],
#  'absher': [['AE', 'B', 'SH', 'ER']],
#  'abshier': [['AE', 'B', 'SH', 'IY', 'ER']],
#  'abshire': [['AE', 'B', 'SH', 'AY', 'R']],
#  'absinthe': [['AE', 'B', 'S', 'IH', 'N', 'TH']],
#  'abso': [['AE', 'B', 'S', 'OW']],
#  'absolom': [['AE', 'B', 'S', 'AH', 'L', 'AH', 'M']],
#  'absolut': [['AE', 'B', 'S', 'AH', 'L', 'UW', 'T']],
#  "absolut's": [['AE', 'B', 'S', 'AH', 'L', 'UW', 'T', 'S']],
#  'absolute': [['AE', 'B', 'S', 'AH', 'L', 'UW', 'T']],
#  'absolutely': [['AE', 'B', 'S', 'AH', 'L', 'UW', 'T', 'L', 'IY']],
#  'absoluteness': [['AE', 'B', 'S', 'AH', 'L', 'UW', 'T', 'N', 'AH', 'S']],
#  'absolutes': [['AE', 'B', 'S', 'AH', 'L', 'UW', 'T', 'S']],
#  'absolution': [['AE', 'B', 'S', 'AH', 'L', 'UW', 'SH', 'AH', 'N']],
#  'absolutism': [['AE', 'B', 'S', 'AH', 'L', 'UW', 'T', 'IH', 'Z', 'AH', 'M']],
#  'absolutist': [['AE', 'B', 'S', 'AH', 'L', 'UW', 'T', 'IH', 'S', 'T']],
#  'absolve': [['AH', 'B', 'Z', 'AA', 'L', 'V'],
#   ['AE', 'B', 'Z', 'AA', 'L', 'V']],
#  'absolved': [['AH', 'B', 'Z', 'AA', 'L', 'V', 'D'],
#   ['AE', 'B', 'Z', 'AA', 'L', 'V', 'D']],
#  'absolves': [['AH', 'B', 'Z', 'AA', 'L', 'V', 'Z'],
#   ['AE', 'B', 'Z', 'AA', 'L', 'V', 'Z']],
#  'absolving': [['AH', 'B', 'Z', 'AA', 'L', 'V', 'IH', 'NG'],
#   ['AE', 'B', 'Z', 'AA', 'L', 'V', 'IH', 'NG']],
#  'absorb': [['AH', 'B', 'Z', 'AO', 'R', 'B']],
#  'absorbed': [['AH', 'B', 'Z', 'AO', 'R', 'B', 'D']],
#  'absorbency': [['AH', 'B', 'Z', 'AO', 'R', 'B', 'AH', 'N', 'S', 'IY']],
#  'absorbent': [['AH', 'B', 'Z', 'AO', 'R', 'B', 'AH', 'N', 'T']],
#  'absorber': [['AH', 'B', 'Z', 'AO', 'R', 'B', 'ER']],
#  'absorbers': [['AH', 'B', 'Z', 'AO', 'R', 'B', 'ER', 'Z']],
#  'absorbing': [['AH', 'B', 'Z', 'AO', 'R', 'B', 'IH', 'NG']],
#  'absorbs': [['AH', 'B', 'Z', 'AO', 'R', 'B', 'Z']],
#  'absorption': [['AH', 'B', 'Z', 'AO', 'R', 'P', 'SH', 'AH', 'N'],
#   ['AH', 'B', 'S', 'AO', 'R', 'P', 'SH', 'AH', 'N']],
#  'abstain': [['AH', 'B', 'S', 'T', 'EY', 'N'],
#   ['AE', 'B', 'S', 'T', 'EY', 'N']],
#  'abstained': [['AH', 'B', 'S', 'T', 'EY', 'N', 'D'],
#   ['AE', 'B', 'S', 'T', 'EY', 'N', 'D']],
#  'abstaining': [['AH', 'B', 'S', 'T', 'EY', 'N', 'IH', 'NG'],
#   ['AE', 'B', 'S', 'T', 'EY', 'N', 'IH', 'NG']],
#  'abstention': [['AH', 'B', 'S', 'T', 'EH', 'N', 'CH', 'AH', 'N'],
#   ['AE', 'B', 'S', 'T', 'EH', 'N', 'CH', 'AH', 'N']],
#  'abstentions': [['AH', 'B', 'S', 'T', 'EH', 'N', 'CH', 'AH', 'N', 'Z'],
#   ['AE', 'B', 'S', 'T', 'EH', 'N', 'CH', 'AH', 'N', 'Z']],
#  'abstinence': [['AE', 'B', 'S', 'T', 'AH', 'N', 'AH', 'N', 'S']],
#  'abstinent': [['AE', 'B', 'S', 'T', 'AH', 'N', 'AH', 'N', 'T']],
#  'abston': [['AE', 'B', 'S', 'T', 'AH', 'N']],
#  'abstract': [['AE', 'B', 'S', 'T', 'R', 'AE', 'K', 'T']],
#  'abstracted': [['AE', 'B', 'S', 'T', 'R', 'AE', 'K', 'T', 'IH', 'D']],
#  'abstraction': [['AE', 'B', 'S', 'T', 'R', 'AE', 'K', 'SH', 'AH', 'N']],
#  'abstractions': [['AE', 'B', 'S', 'T', 'R', 'AE', 'K', 'SH', 'AH', 'N', 'Z']],
#  'abstracts': [['AE', 'B', 'S', 'T', 'R', 'AE', 'K', 'T', 'S']],
#  'abstruse': [['AH', 'B', 'S', 'T', 'R', 'UW', 'S']],
#  'absurd': [['AH', 'B', 'S', 'ER', 'D']],
#  'absurdist': [['AH', 'B', 'S', 'ER', 'D', 'IH', 'S', 'T']],
#  'absurdities': [['AH', 'B', 'S', 'ER', 'D', 'AH', 'T', 'IY', 'Z']],
#  'absurdity': [['AH', 'B', 'S', 'ER', 'D', 'AH', 'T', 'IY']],
#  'absurdly': [['AH', 'B', 'S', 'ER', 'D', 'L', 'IY']],
#  'abt': [['AE', 'B', 'T'], ['EY', 'B', 'IY', 'T', 'IY']],
#  'abts': [['AE', 'B', 'T', 'S'],
#   ['EY', 'B', 'IY', 'T', 'IY', 'Z'],
#   ['EY', 'B', 'IY', 'T', 'IY', 'EH', 'S']],
#  'abu': [['AE', 'B', 'UW']],
#  'abudrahm': [['AH', 'B', 'AH', 'D', 'R', 'AH', 'M']],
#  'abuellah': [['AH', 'B', 'W', 'EH', 'L', 'AH']],
#  "abuellah's": [['AH', 'B', 'W', 'EH', 'L', 'AH', 'Z']],
#  'abuladze': [['AE', 'B', 'Y', 'UW', 'L', 'AE', 'D', 'Z', 'IY']],
#  'abundance': [['AH', 'B', 'AH', 'N', 'D', 'AH', 'N', 'S']],
#  'abundant': [['AH', 'B', 'AH', 'N', 'D', 'AH', 'N', 'T']],
#  'abundantly': [['AH', 'B', 'AH', 'N', 'D', 'AH', 'N', 'T', 'L', 'IY']],
#  'aburto': [['AH', 'B', 'UH', 'R', 'T', 'OW']],
#  "aburto's": [['AH', 'B', 'UH', 'R', 'T', 'OW', 'Z']],
#  'abuse': [['AH', 'B', 'Y', 'UW', 'S'], ['AH', 'B', 'Y', 'UW', 'Z']],
#  'abused': [['AH', 'B', 'Y', 'UW', 'Z', 'D']],
#  'abuser': [['AH', 'B', 'Y', 'UW', 'Z', 'ER']],
#  'abusers': [['AH', 'B', 'Y', 'UW', 'Z', 'ER', 'Z']],
#  'abuses': [['AH', 'B', 'Y', 'UW', 'S', 'IH', 'Z'],
#   ['AH', 'B', 'Y', 'UW', 'Z', 'IH', 'Z']],
#  'abusing': [['AH', 'B', 'Y', 'UW', 'Z', 'IH', 'NG']],
#  'abusive': [['AH', 'B', 'Y', 'UW', 'S', 'IH', 'V']],
#  'abut': [['AH', 'B', 'AH', 'T']],
#  'abuts': [['AH', 'B', 'AH', 'T', 'S']],
#  'abutted': [['AH', 'B', 'AH', 'T', 'IH', 'D']],
#  'abutting': [['AH', 'B', 'AH', 'T', 'IH', 'NG']],
#  'abuzz': [['AH', 'B', 'AH', 'Z']],
#  'abysmal': [['AH', 'B', 'IH', 'Z', 'M', 'AH', 'L']],
#  'abysmally': [['AH', 'B', 'IH', 'Z', 'M', 'AH', 'L', 'IY']],
#  'abyss': [['AH', 'B', 'IH', 'S']],
#  'abyssinia': [['AE', 'B', 'S', 'IH', 'N', 'IY', 'AH']],
#  'abyssinian': [['AE', 'B', 'S', 'IH', 'N', 'IY', 'AH', 'N']],
#  'abzug': [['AE', 'B', 'Z', 'AH', 'G'], ['AE', 'B', 'Z', 'UH', 'G']],
#  'ac': [['EY', 'S', 'IY']],
#  'aca': [['AE', 'K', 'AH']],
#  'acacia': [['AH', 'K', 'EY', 'SH', 'AH']],
#  'academe': [['AE', 'K', 'AH', 'D', 'IY', 'M']],
#  'academia': [['AE', 'K', 'AH', 'D', 'IY', 'M', 'IY', 'AH']],
#  'academic': [['AE', 'K', 'AH', 'D', 'EH', 'M', 'IH', 'K']],
#  'academically': [['AE', 'K', 'AH', 'D', 'EH', 'M', 'IH', 'K', 'L', 'IY']],
#  'academician': [['AE', 'K', 'AH', 'D', 'AH', 'M', 'IH', 'SH', 'AH', 'N']],
#  'academicians': [['AE',
#    'K',
#    'AH',
#    'D',
#    'AH',
#    'M',
#    'IH',
#    'SH',
#    'AH',
#    'N',
#    'Z'],
#   ['AH', 'K', 'AE', 'D', 'AH', 'M', 'IH', 'SH', 'AH', 'N', 'Z']],
#  'academics': [['AE', 'K', 'AH', 'D', 'EH', 'M', 'IH', 'K', 'S']],
#  'academies': [['AH', 'K', 'AE', 'D', 'AH', 'M', 'IY', 'Z']],
#  'academy': [['AH', 'K', 'AE', 'D', 'AH', 'M', 'IY']],
#  "academy's": [['AH', 'K', 'AE', 'D', 'AH', 'M', 'IY', 'Z']],
#  'acadia': [['AH', 'K', 'EY', 'D', 'IY', 'AH']],
#  'acampo': [['AH', 'K', 'AA', 'M', 'P', 'OW']],
#  'acampora': [['AH', 'K', 'AE', 'M', 'P', 'ER', 'AH']],
#  'acampsia': [['AH', 'K', 'AE', 'M', 'P', 'S', 'Y', 'AH']],
#  'acantha': [['AA', 'K', 'AA', 'N', 'DH', 'AH']],
#  'acapulco': [['AE', 'K', 'AH', 'P', 'UH', 'L', 'K', 'OW']],
#  'acary': [['AE', 'K', 'ER', 'IY']],
#  'acc': [['AY', 'S', 'IY', 'S', 'IY']],
#  'accardi': [['AA', 'K', 'AA', 'R', 'D', 'IY']],
#  'accardo': [['AA', 'K', 'AA', 'R', 'D', 'OW']],
#  'accede': [['AE', 'K', 'S', 'IY', 'D']],
#  'acceded': [['AE', 'K', 'S', 'IY', 'D', 'IH', 'D']],
#  'accedes': [['AE', 'K', 'S', 'IY', 'D', 'Z']],
#  'acceding': [['AE', 'K', 'S', 'IY', 'D', 'IH', 'NG']],
#  'accel': [['AH', 'K', 'S', 'EH', 'L']],
#  'accelerant': [['AE', 'K', 'S', 'EH', 'L', 'ER', 'AH', 'N', 'T']],
#  'accelerants': [['AE', 'K', 'S', 'EH', 'L', 'ER', 'AH', 'N', 'T', 'S']],
#  'accelerate': [['AE', 'K', 'S', 'EH', 'L', 'ER', 'EY', 'T']],
#  'accelerated': [['AE', 'K', 'S', 'EH', 'L', 'ER', 'EY', 'T', 'IH', 'D']],
#  'accelerates': [['AE', 'K', 'S', 'EH', 'L', 'ER', 'EY', 'T', 'S']],
#  'accelerating': [['AE', 'K', 'S', 'EH', 'L', 'ER', 'EY', 'T', 'IH', 'NG']],
#  'acceleration': [['AE', 'K', 'S', 'EH', 'L', 'ER', 'EY', 'SH', 'AH', 'N']],
#  'accelerator': [['AE', 'K', 'S', 'EH', 'L', 'ER', 'EY', 'T', 'ER']],
#  'accelerators': [['AE', 'K', 'S', 'EH', 'L', 'ER', 'EY', 'T', 'ER', 'Z']],
#  'accelerometer': [['AE',
#    'K',
#    'S',
#    'EH',
#    'L',
#    'ER',
#    'AA',
#    'M',
#    'AH',
#    'T',
#    'ER']],
#  'accelerometers': [['AE',
#    'K',
#    'S',
#    'EH',
#    'L',
#    'ER',
#    'AA',
#    'M',
#    'AH',
#    'T',
#    'ER',
#    'Z']],
#  'accent': [['AH', 'K', 'S', 'EH', 'N', 'T'],
#   ['AE', 'K', 'S', 'EH', 'N', 'T']],
#  'accented': [['AE', 'K', 'S', 'EH', 'N', 'T', 'IH', 'D']],
#  'accenting': [['AE', 'K', 'S', 'EH', 'N', 'T', 'IH', 'NG']],
#  'accents': [['AE', 'K', 'S', 'EH', 'N', 'T', 'S']],
#  'accentuate': [['AE', 'K', 'S', 'EH', 'N', 'CH', 'UW', 'EY', 'T']],
#  'accentuated': [['AE',
#    'K',
#    'S',
#    'EH',
#    'N',
#    'CH',
#    'UW',
#    'EY',
#    'T',
#    'IH',
#    'D']],
#  'accentuates': [['AE', 'K', 'S', 'EH', 'N', 'CH', 'UW', 'EY', 'T', 'S']],
#  'accentuating': [['AE',
#    'K',
#    'S',
#    'EH',
#    'N',
#    'CH',
#    'UW',
#    'EY',
#    'T',
#    'IH',
#    'NG']],
#  'accenture': [['AE', 'K', 'S', 'EH', 'N', 'CH', 'ER']],
#  'accept': [['AE', 'K', 'S', 'EH', 'P', 'T'],
#   ['AH', 'K', 'S', 'EH', 'P', 'T']],
#  'acceptability': [['AH',
#    'K',
#    'S',
#    'EH',
#    'P',
#    'T',
#    'AH',
#    'B',
#    'IH',
#    'L',
#    'AH',
#    'T',
#    'IY']],
#  'acceptable': [['AE', 'K', 'S', 'EH', 'P', 'T', 'AH', 'B', 'AH', 'L'],
#   ['AH', 'K', 'S', 'EH', 'P', 'T', 'AH', 'B', 'AH', 'L']],
#  'acceptably': [['AE', 'K', 'S', 'EH', 'P', 'T', 'AH', 'B', 'L', 'IY'],
#   ['AH', 'K', 'S', 'EH', 'P', 'T', 'AH', 'B', 'L', 'IY']],
#  'acceptance': [['AE', 'K', 'S', 'EH', 'P', 'T', 'AH', 'N', 'S'],
#   ['AH', 'K', 'S', 'EH', 'P', 'T', 'AH', 'N', 'S']],
#  'acceptances': [['AE', 'K', 'S', 'EH', 'P', 'T', 'AH', 'N', 'S', 'IH', 'Z']],
#  'accepted': [['AE', 'K', 'S', 'EH', 'P', 'T', 'IH', 'D'],
#   ['AH', 'K', 'S', 'EH', 'P', 'T', 'IH', 'D']],
#  'accepting': [['AE', 'K', 'S', 'EH', 'P', 'T', 'IH', 'NG'],
#   ['AH', 'K', 'S', 'EH', 'P', 'T', 'IH', 'NG']],
#  'accepts': [['AE', 'K', 'S', 'EH', 'P', 'T', 'S']],
#  'access': [['AE', 'K', 'S', 'EH', 'S']],
#  'accessed': [['AE', 'K', 'S', 'EH', 'S', 'T']],
#  'accessibility': [['AE',
#    'K',
#    'S',
#    'EH',
#    'S',
#    'AH',
#    'B',
#    'IH',
#    'L',
#    'IH',
#    'T',
#    'IY']],
#  'accessible': [['AE', 'K', 'S', 'EH', 'S', 'AH', 'B', 'AH', 'L']],
#  'accessing': [['AE', 'K', 'S', 'EH', 'S', 'IH', 'NG']],
#  'accession': [['AH', 'K', 'S', 'EH', 'SH', 'AH', 'N']],
#  'accessories': [['AE', 'K', 'S', 'EH', 'S', 'ER', 'IY', 'Z']],
#  'accessorize': [['AE', 'K', 'S', 'EH', 'S', 'ER', 'AY', 'Z']],
#  'accessorized': [['AE', 'K', 'S', 'EH', 'S', 'ER', 'AY', 'Z', 'D']],
#  'accessory': [['AE', 'K', 'S', 'EH', 'S', 'ER', 'IY']],
#  'accetta': [['AA', 'CH', 'EH', 'T', 'AH']],
#  'accident': [['AE', 'K', 'S', 'AH', 'D', 'AH', 'N', 'T']],
#  "accident's": [['AE', 'K', 'S', 'AH', 'D', 'AH', 'N', 'T', 'S']],
#  'accidental': [['AE', 'K', 'S', 'AH', 'D', 'EH', 'N', 'T', 'AH', 'L'],
#   ['AE', 'K', 'S', 'AH', 'D', 'EH', 'N', 'AH', 'L']],
#  'accidentally': [['AE', 'K', 'S', 'AH', 'D', 'EH', 'N', 'T', 'AH', 'L', 'IY'],
#   ['AE', 'K', 'S', 'AH', 'D', 'EH', 'N', 'AH', 'L', 'IY']],
#  'accidently': [['AE', 'K', 'S', 'AH', 'D', 'AH', 'N', 'T', 'L', 'IY']],
#  'accidents': [['AE', 'K', 'S', 'AH', 'D', 'AH', 'N', 'T', 'S']],
#  'accion': [['AE', 'CH', 'IY', 'AH', 'N']],
#  'accival': [['AE', 'S', 'IH', 'V', 'AA', 'L']],
#  'acclaim': [['AH', 'K', 'L', 'EY', 'M']],
#  "acclaim's": [['AH', 'K', 'L', 'EY', 'M', 'Z']],
#  'acclaimed': [['AH', 'K', 'L', 'EY', 'M', 'D']],
#  'acclaiming': [['AH', 'K', 'L', 'EY', 'M', 'IH', 'NG']],
#  'acclaims': [['AH', 'K', 'L', 'EY', 'M', 'Z']],
#  'acclamation': [['AE', 'K', 'L', 'AH', 'M', 'EY', 'SH', 'AH', 'N']],
#  'acclimate': [['AE', 'K', 'L', 'AH', 'M', 'EY', 'T']],
#  'acclimated': [['AE', 'K', 'L', 'AH', 'M', 'EY', 'T', 'IH', 'D']],
#  'acclimation': [['AE', 'K', 'L', 'AH', 'M', 'EY', 'SH', 'AH', 'N']],
#  'acco': [['AE', 'K', 'OW']],
#  'accokeek': [['AE', 'K', 'OW', 'K', 'IY', 'K']],
#  'accola': [['AA', 'K', 'OW', 'L', 'AH']],
#  'accolade': [['AE', 'K', 'AH', 'L', 'EY', 'D']],
#  'accolades': [['AE', 'K', 'AH', 'L', 'EY', 'D', 'Z']],
#  'accomando': [['AA', 'K', 'OW', 'M', 'AA', 'N', 'D', 'OW']],
#  'accommodate': [['AH', 'K', 'AA', 'M', 'AH', 'D', 'EY', 'T']],
#  'accommodated': [['AH', 'K', 'AA', 'M', 'AH', 'D', 'EY', 'T', 'IH', 'D']],
#  'accommodates': [['AH', 'K', 'AA', 'M', 'AH', 'D', 'EY', 'T', 'S']],
#  'accommodating': [['AH', 'K', 'AA', 'M', 'AH', 'D', 'EY', 'T', 'IH', 'NG']],
#  'accommodation': [['AH', 'K', 'AA', 'M', 'AH', 'D', 'EY', 'SH', 'AH', 'N']],
#  'accommodations': [['AH',
#    'K',
#    'AA',
#    'M',
#    'AH',
#    'D',
#    'EY',
#    'SH',
#    'AH',
#    'N',
#    'Z']],
#  'accommodative': [['AH', 'K', 'AA', 'M', 'AH', 'D', 'EY', 'T', 'IH', 'V']],
#  'accompanied': [['AH', 'K', 'AH', 'M', 'P', 'AH', 'N', 'IY', 'D']],
#  'accompanies': [['AH', 'K', 'AH', 'M', 'P', 'AH', 'N', 'IY', 'Z']],
#  'accompaniment': [['AH', 'K', 'AH', 'M', 'P', 'N', 'IH', 'M', 'AH', 'N', 'T'],
#   ['AH', 'K', 'AH', 'M', 'P', 'N', 'IY', 'M', 'AH', 'N', 'T']],
#  'accompaniments': [['AH',
#    'K',
#    'AH',
#    'M',
#    'P',
#    'N',
#    'IH',
#    'M',
#    'AH',
#    'N',
#    'T',
#    'S'],
#   ['AH', 'K', 'AH', 'M', 'P', 'N', 'IY', 'M', 'AH', 'N', 'T', 'S']],
#  'accompanist': [['AH', 'K', 'AH', 'M', 'P', 'AH', 'N', 'AH', 'S', 'T']],
#  'accompany': [['AH', 'K', 'AH', 'M', 'P', 'AH', 'N', 'IY']],
#  'accompanying': [['AH', 'K', 'AH', 'M', 'P', 'AH', 'N', 'IY', 'IH', 'NG']],
#  'accompli': [['AA', 'K', 'AA', 'M', 'P', 'L', 'IY'],
#   ['AH', 'K', 'AA', 'M', 'P', 'L', 'IY']],
#  'accomplice': [['AH', 'K', 'AA', 'M', 'P', 'L', 'AH', 'S']],
#  'accomplices': [['AH', 'K', 'AA', 'M', 'P', 'L', 'AH', 'S', 'AH', 'Z']],
#  'accomplish': [['AH', 'K', 'AA', 'M', 'P', 'L', 'IH', 'SH']],
#  'accomplished': [['AH', 'K', 'AA', 'M', 'P', 'L', 'IH', 'SH', 'T']],
#  'accomplishes': [['AH', 'K', 'AA', 'M', 'P', 'L', 'IH', 'SH', 'IH', 'Z']],
#  'accomplishing': [['AH', 'K', 'AA', 'M', 'P', 'L', 'IH', 'SH', 'IH', 'NG']],
#  'accomplishment': [['AH',
#    'K',
#    'AA',
#    'M',
#    'P',
#    'L',
#    'IH',
#    'SH',
#    'M',
#    'AH',
#    'N',
#    'T']],
#  'accomplishments': [['AH',
#    'K',
#    'AA',
#    'M',
#    'P',
#    'L',
#    'IH',
#    'SH',
#    'M',
#    'AH',
#    'N',
#    'T',
#    'S']],
#  'accor': [['AE', 'K', 'AO', 'R']],
#  "accor's": [['AE', 'K', 'ER', 'Z']],
#  'accord': [['AH', 'K', 'AO', 'R', 'D']],
#  "accord's": [['AH', 'K', 'AO', 'R', 'D', 'Z']],
#  'accordance': [['AH', 'K', 'AO', 'R', 'D', 'AH', 'N', 'S']],
#  'accorded': [['AH', 'K', 'AO', 'R', 'D', 'IH', 'D']],
#  'according': [['AH', 'K', 'AO', 'R', 'D', 'IH', 'NG']],
#  'accordingly': [['AH', 'K', 'AO', 'R', 'D', 'IH', 'NG', 'L', 'IY']],
#  'accordion': [['AH', 'K', 'AO', 'R', 'D', 'IY', 'AH', 'N']],
#  'accordions': [['AH', 'K', 'AO', 'R', 'D', 'IY', 'AH', 'N', 'Z']],
#  'accords': [['AH', 'K', 'AO', 'R', 'D', 'Z']],
#  'accost': [['AH', 'K', 'AO', 'S', 'T']],
#  'accosted': [['AH', 'K', 'AA', 'S', 'T', 'IH', 'D']],
#  'accosting': [['AH', 'K', 'AA', 'S', 'T', 'IH', 'NG']],
#  'account': [['AH', 'K', 'AW', 'N', 'T']],
#  "account's": [['AH', 'K', 'AW', 'N', 'T', 'S']],
#  'accountability': [['AH',
#    'K',
#    'AW',
#    'N',
#    'T',
#    'AH',
#    'B',
#    'IH',
#    'L',
#    'IH',
#    'T',
#    'IY'],
#   ['AH', 'K', 'AW', 'N', 'AH', 'B', 'IH', 'L', 'IH', 'T', 'IY']],
#  'accountable': [['AH', 'K', 'AW', 'N', 'T', 'AH', 'B', 'AH', 'L'],
#   ['AH', 'K', 'AW', 'N', 'AH', 'B', 'AH', 'L']],
#  'accountancy': [['AH', 'K', 'AW', 'N', 'T', 'AH', 'N', 'S', 'IY']],
#  'accountant': [['AH', 'K', 'AW', 'N', 'T', 'AH', 'N', 'T']],
#  "accountant's": [['AH', 'K', 'AW', 'N', 'T', 'AH', 'N', 'T', 'S']],
#  'accountants': [['AH', 'K', 'AW', 'N', 'T', 'AH', 'N', 'T', 'S']],
#  "accountants'": [['AH', 'K', 'AW', 'N', 'T', 'AH', 'N', 'T', 'S']],
#  'accounted': [['AH', 'K', 'AW', 'N', 'T', 'IH', 'D'],
#   ['AH', 'K', 'AW', 'N', 'AH', 'D']],
#  'accountemp': [['AH', 'K', 'AW', 'N', 'T', 'EH', 'M', 'P']],
#  'accountemps': [['AH', 'K', 'AW', 'N', 'T', 'EH', 'M', 'P', 'S']],
#  'accounting': [['AH', 'K', 'AW', 'N', 'T', 'IH', 'NG'],
#   ['AH', 'K', 'AW', 'N', 'IH', 'NG']],
#  'accounts': [['AH', 'K', 'AW', 'N', 'T', 'S']],
#  'accouterment': [['AH', 'K', 'UW', 'T', 'ER', 'M', 'AH', 'N', 'T']],
#  'accouterments': [['AH', 'K', 'UW', 'T', 'ER', 'M', 'AH', 'N', 'T', 'S']],
#  'accoutrement': [['AH', 'K', 'UW', 'T', 'ER', 'M', 'AH', 'N', 'T']],
#  'accoutrements': [['AH', 'K', 'UW', 'T', 'ER', 'M', 'AH', 'N', 'T', 'S']],
#  'accra': [['AA', 'K', 'R', 'AA']],
#  'accredit': [['AH', 'K', 'R', 'EH', 'D', 'AH', 'T']],
#  'accreditation': [['AH',
#    'K',
#    'R',
#    'EH',
#    'D',
#    'AH',
#    'T',
#    'EY',
#    'SH',
#    'AH',
#    'N']],
#  'accreditations': [['AH',
#    'K',
#    'R',
#    'EH',
#    'D',
#    'AH',
#    'T',
#    'EY',
#    'SH',
#    'AH',
#    'N',
#    'Z']],
#  'accredited': [['AH', 'K', 'R', 'EH', 'D', 'IH', 'T', 'IH', 'D']],
#  'accrediting': [['AH', 'K', 'R', 'EH', 'D', 'AH', 'T', 'IH', 'NG']],
#  'accreted': [['AH', 'K', 'R', 'IY', 'T', 'IH', 'D']],
#  'accretion': [['AH', 'K', 'R', 'IY', 'SH', 'AH', 'N']],
#  'accrual': [['AH', 'K', 'R', 'UW', 'AH', 'L']],
#  'accruals': [['AH', 'K', 'R', 'UW', 'AH', 'L', 'Z']],
#  'accrue': [['AH', 'K', 'R', 'UW']],
#  'accrued': [['AH', 'K', 'R', 'UW', 'D']],
#  'accrues': [['AH', 'K', 'R', 'UW', 'Z']],
#  'accruing': [['AH', 'K', 'R', 'UW', 'IH', 'NG']],
#  'accu': [['AE', 'K', 'Y', 'UW']],
#  'accuhealth': [['AE', 'K', 'Y', 'UW', 'HH', 'EH', 'L', 'TH']],
#  'accumulate': [['AH', 'K', 'Y', 'UW', 'M', 'Y', 'AH', 'L', 'EY', 'T']],
#  'accumulated': [['AH',
#    'K',
#    'Y',
#    'UW',
#    'M',
#    'Y',
#    'AH',
#    'L',
#    'EY',
#    'T',
#    'IH',
#    'D']],
#  'accumulates': [['AH', 'K', 'Y', 'UW', 'M', 'Y', 'AH', 'L', 'EY', 'T', 'S']],
#  'accumulating': [['AH',
#    'K',
#    'Y',
#    'UW',
#    'M',
#    'Y',
#    'AH',
#    'L',
#    'EY',
#    'T',
#    'IH',
#    'NG']],
#  'accumulation': [['AH',
#    'K',
#    'Y',
#    'UW',
#    'M',
#    'Y',
#    'AH',
#    'L',
#    'EY',
#    'SH',
#    'AH',
#    'N']],
#  'accumulations': [['AH',
#    'K',
#    'Y',
#    'UW',
#    'M',
#    'Y',
#    'AH',
#    'L',
#    'EY',
#    'SH',
#    'AH',
#    'N',
#    'Z']],
#  'accumulative': [['AH',
#    'K',
#    'Y',
#    'UW',
#    'M',
#    'Y',
#    'AH',
#    'L',
#    'EY',
#    'T',
#    'IH',
#    'V']],
#  'accumulatively': [['AH',
#    'K',
#    'Y',
#    'UW',
#    'M',
#    'Y',
#    'AH',
#    'L',
#    'EY',
#    'T',
#    'IH',
#    'V',
#    'L',
#    'IY'],
#   ['AH',
#    'K',
#    'Y',
#    'UW',
#    'M',
#    'Y',
#    'AH',
#    'L',
#    'AH',
#    'T',
#    'IH',
#    'V',
#    'L',
#    'IY']],
#  'accumulator': [['AH', 'K', 'Y', 'UW', 'M', 'Y', 'AH', 'L', 'EY', 'T', 'ER']],
#  'accumulators': [['AH',
#    'K',
#    'Y',
#    'UW',
#    'M',
#    'Y',
#    'AH',
#    'L',
#    'EY',
#    'T',
#    'ER',
#    'Z']],
#  'accuracies': [['AE', 'K', 'Y', 'ER', 'AH', 'S', 'IY', 'Z']],
#  'accuracy': [['AE', 'K', 'Y', 'ER', 'AH', 'S', 'IY']],
#  'accurate': [['AE', 'K', 'Y', 'ER', 'AH', 'T']],
#  'accurately': [['AE', 'K', 'Y', 'ER', 'AH', 'T', 'L', 'IY']],
#  'accuray': [['AE', 'K', 'Y', 'ER', 'EY']],
#  "accuray's": [['AE', 'K', 'Y', 'ER', 'EY', 'Z']],
#  'accuride': [['AE', 'K', 'Y', 'ER', 'AY', 'D']],
#  'accursed': [['AE', 'K', 'ER', 'S', 'T']],
#  'accurso': [['AA', 'K', 'UH', 'R', 'S', 'OW']],
#  'accusation': [['AE', 'K', 'Y', 'AH', 'Z', 'EY', 'SH', 'AH', 'N'],
#   ['AE', 'K', 'Y', 'UW', 'Z', 'EY', 'SH', 'AH', 'N']],
#  'accusations': [['AE', 'K', 'Y', 'AH', 'Z', 'EY', 'SH', 'AH', 'N', 'Z'],
#   ['AE', 'K', 'Y', 'UW', 'Z', 'EY', 'SH', 'AH', 'N', 'Z']],
#  'accusative': [['AH', 'K', 'Y', 'UW', 'Z', 'AH', 'T', 'IH', 'V']],
#  'accusatory': [['AH', 'K', 'Y', 'UW', 'Z', 'AH', 'T', 'AO', 'R', 'IY']],
#  'accuse': [['AH', 'K', 'Y', 'UW', 'Z']],
#  'accused': [['AH', 'K', 'Y', 'UW', 'Z', 'D']],
#  'accuser': [['AH', 'K', 'Y', 'UW', 'Z', 'ER']],
#  'accusers': [['AH', 'K', 'Y', 'UW', 'Z', 'ER', 'Z']],
#  'accuses': [['AH', 'K', 'Y', 'UW', 'Z', 'IH', 'Z']],
#  'accusing': [['AH', 'K', 'Y', 'UW', 'Z', 'IH', 'NG']],
#  'accusingly': [['AH', 'K', 'Y', 'UW', 'Z', 'IH', 'NG', 'L', 'IY']],
#  'accustom': [['AH', 'K', 'AH', 'S', 'T', 'AH', 'M']],
#  'accustomed': [['AH', 'K', 'AH', 'S', 'T', 'AH', 'M', 'D']],
#  'accutane': [['AE', 'K', 'Y', 'UW', 'T', 'EY', 'N']],
#  'ace': [['EY', 'S']],
#  'acecomm': [['EY', 'S', 'K', 'AA', 'M']],
#  'aced': [['EY', 'S', 'T']],
#  'acer': [['EY', 'S', 'ER']],
#  'acerbic': [['AH', 'S', 'EH', 'R', 'B', 'IH', 'K']],
#  'acero': [['AH', 'S', 'EH', 'R', 'OW'],
#   ['AH', 'S', 'Y', 'EH', 'R', 'OW'],
#   ['AH', 'TH', 'EH', 'R', 'OW']],
#  'acerra': [['AH', 'S', 'EH', 'R', 'AH']],
#  'aces': [['EY', 'S', 'IH', 'Z']],
#  'acetaminophen': [['AH',
#    'S',
#    'IY',
#    'T',
#    'AH',
#    'M',
#    'IH',
#    'N',
#    'AH',
#    'F',
#    'AH',
#    'N']],
#  'acetate': [['AE', 'S', 'AH', 'T', 'EY', 'T']],
#  'acetic': [['AH', 'S', 'EH', 'T', 'IH', 'K'],
#   ['AH', 'S', 'IY', 'T', 'IH', 'K']],
#  'aceto': [['AA', 'S', 'EH', 'T', 'OW']],
#  'acetochlor': [['AA', 'S', 'EH', 'T', 'OW', 'K', 'L', 'AO', 'R']],
#  'acetone': [['AE', 'S', 'AH', 'T', 'OW', 'N']],
#  'acetosyringone': [['AH',
#    'S',
#    'EH',
#    'T',
#    'OW',
#    'S',
#    'IH',
#    'R',
#    'IH',
#    'NG',
#    'G',
#    'AO',
#    'N']],
#  'acetylcholine': [['AH',
#    'S',
#    'EH',
#    'T',
#    'AH',
#    'L',
#    'K',
#    'OW',
#    'L',
#    'IY',
#    'N'],
#   ['AH', 'S', 'IY', 'T', 'AH', 'L', 'K', 'OW', 'L', 'IY', 'N']],
#  'acetylene': [['AH', 'S', 'EH', 'T', 'AH', 'L', 'IY', 'N']],
#  'acevedo': [['AE', 'S', 'AH', 'V', 'EY', 'D', 'OW']],
#  'aceves': [['AA', 'S', 'EY', 'V', 'EH', 'S']],
#  'acey': [['EY', 'S', 'IY']],
#  'ach': [['EY', 'S', 'IY', 'EY', 'CH']],
#  'achaean': [['AH', 'CH', 'IY', 'AH', 'N']],
#  'achatz': [['AE', 'K', 'AH', 'T', 'S']],
#  'ache': [['EY', 'K']],
#  'achebe': [['AA', 'CH', 'EY', 'B', 'IY']],
#  'ached': [['EY', 'K', 'T']],
#  'achee': [['AH', 'CH', 'IY']],
#  'achenbach': [['AE', 'K', 'IH', 'N', 'B', 'AA', 'K']],
#  'achenbaum': [['AE', 'K', 'AH', 'N', 'B', 'AW', 'M']],
#  'achene': [['AH', 'K', 'IY', 'N']],
#  'achenes': [['AH', 'K', 'IY', 'N', 'Z']],
#  'aches': [['EY', 'K', 'S']],
#  'acheson': [['AE', 'CH', 'AH', 'S', 'AH', 'N']],
#  "acheson's": [['AE', 'CH', 'AH', 'S', 'AH', 'N', 'Z']],
#  'achesons': [['AE', 'CH', 'AH', 'S', 'AH', 'N', 'Z']],
#  'achey': [['AE', 'CH', 'IY']],
#  'achieva': [['AH', 'CH', 'IY', 'V', 'AH']],
#  'achievable': [['AH', 'CH', 'IY', 'V', 'AH', 'B', 'AH', 'L']],
#  'achieve': [['AH', 'CH', 'IY', 'V']],
#  'achieved': [['AH', 'CH', 'IY', 'V', 'D']],
#  'achievement': [['AH', 'CH', 'IY', 'V', 'M', 'AH', 'N', 'T']],
#  'achievements': [['AH', 'CH', 'IY', 'V', 'M', 'AH', 'N', 'T', 'S']],
#  'achiever': [['AH', 'CH', 'IY', 'V', 'ER']],
#  'achievers': [['AH', 'CH', 'IY', 'V', 'ER', 'Z']],
#  'achieves': [['AH', 'CH', 'IY', 'V', 'Z']],
#  'achieving': [['AH', 'CH', 'IY', 'V', 'IH', 'NG']],
#  'achille': [['AH', 'K', 'IH', 'L', 'IY']],
#  'achilles': [['AH', 'K', 'IH', 'L', 'IY', 'Z']],
#  "achilles'": [['AH', 'K', 'IH', 'L', 'IY', 'Z']],
#  'aching': [['EY', 'K', 'IH', 'NG']],
#  'achingly': [['EY', 'K', 'IH', 'NG', 'L', 'IY']],
#  'achmed': [['AA', 'HH', 'M', 'EH', 'D']],
#  'achoa': [['AH', 'CH', 'OW', 'AH']],
#  "achoa's": [['AH', 'CH', 'OW', 'AH', 'Z']],
#  'achoo': [['AA', 'CH', 'UW']],
#  'achor': [['EY', 'K', 'ER']],
#  'achord': [['AE', 'K', 'AO', 'R', 'D']],
#  'achorn': [['AE', 'K', 'ER', 'N']],
#  'achtenberg': [['AE', 'K', 'T', 'EH', 'N', 'B', 'ER', 'G']],
#  'achterberg': [['AE', 'K', 'T', 'ER', 'B', 'ER', 'G']],
#  'achy': [['EY', 'K', 'IY']],
#  'acid': [['AE', 'S', 'AH', 'D']],
#  'acidic': [['AH', 'S', 'IH', 'D', 'IH', 'K']],
#  'acidification': [['AH',
#    'S',
#    'IH',
#    'D',
#    'AH',
#    'F',
#    'AH',
#    'K',
#    'EY',
#    'SH',
#    'AH',
#    'N']],
#  'acidified': [['AH', 'S', 'IH', 'D', 'AH', 'F', 'AY', 'D']],
#  'acidifies': [['AH', 'S', 'IH', 'D', 'AH', 'F', 'AY', 'Z']],
#  'acidify': [['AH', 'S', 'IH', 'D', 'AH', 'F', 'AY']],
#  'acidity': [['AH', 'S', 'IH', 'D', 'AH', 'T', 'IY']],
#  'acidly': [['AE', 'S', 'AH', 'D', 'L', 'IY']],
#  'acidosis': [['AE', 'S', 'AH', 'D', 'OW', 'S', 'AH', 'S']],
#  'acids': [['AE', 'S', 'AH', 'D', 'Z']],
#  'aciduria': [['AE', 'S', 'AH', 'D', 'UH', 'R', 'IY', 'AH']],
#  'acierno': [['AA', 'S', 'IH', 'R', 'N', 'OW']],
#  'ack': [['AE', 'K']],
#  'acker': [['AE', 'K', 'ER']],
#  "acker's": [['AE', 'K', 'ER', 'Z']],
#  'ackerley': [['AE', 'K', 'ER', 'L', 'IY']],
#  'ackerly': [['AE', 'K', 'ER', 'L', 'IY']],
#  'ackerman': [['AE', 'K', 'ER', 'M', 'AH', 'N']],
#  'ackermann': [['AE', 'K', 'ER', 'M', 'AH', 'N']],
#  'ackermanville': [['AE', 'K', 'ER', 'M', 'AH', 'N', 'V', 'IH', 'L']],
#  'ackerson': [['AE', 'K', 'ER', 'S', 'AH', 'N']],
#  'ackert': [['AE', 'K', 'ER', 'T']],
#  'ackhouse': [['AE', 'K', 'HH', 'AW', 'S']],
#  'ackland': [['AE', 'K', 'L', 'AH', 'N', 'D']],
#  'ackles': [['AE', 'K', 'AH', 'L', 'Z']],
#  'ackley': [['AE', 'K', 'L', 'IY']],
#  'acklin': [['AE', 'K', 'L', 'IH', 'N']],
#  'ackman': [['AE', 'K', 'M', 'AH', 'N']],
#  'acknowledge': [['AE', 'K', 'N', 'AA', 'L', 'IH', 'JH']],
#  'acknowledgeable': [['AE',
#    'K',
#    'N',
#    'AA',
#    'L',
#    'IH',
#    'JH',
#    'AH',
#    'B',
#    'AH',
#    'L']],
#  'acknowledged': [['AE', 'K', 'N', 'AA', 'L', 'IH', 'JH', 'D']],
#  'acknowledgement': [['AE',
#    'K',
#    'N',
#    'AA',
#    'L',
#    'IH',
#    'JH',
#    'M',
#    'AH',
#    'N',
#    'T']],
#  'acknowledgements': [['AE',
#    'K',
#    'N',
#    'AA',
#    'L',
#    'IH',
#    'JH',
#    'M',
#    'AH',
#    'N',
#    'T',
#    'S']],
#  'acknowledges': [['AE', 'K', 'N', 'AA', 'L', 'IH', 'JH', 'IH', 'Z']],
#  'acknowledging': [['AE', 'K', 'N', 'AA', 'L', 'IH', 'JH', 'IH', 'NG']],
#  'acknowledgment': [['AE',
#    'K',
#    'N',
#    'AA',
#    'L',
#    'IH',
#    'JH',
#    'M',
#    'AH',
#    'N',
#    'T']],
#  'acknowledgments': [['AE',
#    'K',
#    'N',
#    'AA',
#    'L',
#    'IH',
#    'JH',
#    'M',
#    'AH',
#    'N',
#    'T',
#    'S']],
#  'ackroyd': [['AE', 'K', 'R', 'OY', 'D']],
#  "ackroyd's": [['AE', 'K', 'R', 'OY', 'D', 'Z']],
#  'acm': [['EY', 'S', 'IY', 'EH', 'M']],
#  'acmat': [['AE', 'K', 'M', 'AE', 'T']],
#  "acmat's": [['AE', 'K', 'M', 'AE', 'T', 'S']],
#  'acme': [['AE', 'K', 'M', 'IY']],
#  "acme's": [['AE', 'K', 'M', 'IY', 'Z']],
#  'acne': [['AE', 'K', 'N', 'IY']],
#  'acocella': [['AA', 'K', 'OW', 'CH', 'EH', 'L', 'AH']],
#  'acoff': [['AE', 'K', 'AO', 'F']],
#  'acog': [['AH', 'K', 'AO', 'G']],
#  'acolyte': [['AE', 'K', 'AH', 'L', 'AY', 'T']],
#  'acolytes': [['AE', 'K', 'AH', 'L', 'AY', 'T', 'S']],
#  'acord': [['AH', 'K', 'AO', 'R', 'D']],
#  'acordia': [['AH', 'K', 'AO', 'R', 'D', 'IY', 'AH']],
#  'acorn': [['EY', 'K', 'AO', 'R', 'N']],
#  "acorn's": [['EY', 'K', 'AO', 'R', 'N', 'Z']],
#  'acorns': [['EY', 'K', 'AO', 'R', 'N', 'Z']],
#  'acosta': [['AH', 'K', 'AO', 'S', 'T', 'AH']],
#  'acott': [['EY', 'K', 'AO', 'T']],
#  'acoustic': [['AH', 'K', 'UW', 'S', 'T', 'IH', 'K']],
#  'acoustical': [['AH', 'K', 'UW', 'S', 'T', 'IH', 'K', 'AH', 'L']],
#  'acoustically': [['AH', 'K', 'UW', 'S', 'T', 'IH', 'K', 'L', 'IY']],
#  'acoustics': [['AH', 'K', 'UW', 'S', 'T', 'IH', 'K', 'S']],
#  'acquaint': [['AH', 'K', 'W', 'EY', 'N', 'T']],
#  'acquaintance': [['AH', 'K', 'W', 'EY', 'N', 'T', 'AH', 'N', 'S']],
#  'acquaintances': [['AH',
#    'K',
#    'W',
#    'EY',
#    'N',
#    'T',
#    'AH',
#    'N',
#    'S',
#    'IH',
#    'Z']],
#  'acquaintanceship': [['AH',
#    'K',
#    'W',
#    'EY',
#    'N',
#    'T',
#    'AH',
#    'N',
#    'S',
#    'SH',
#    'IH',
#    'P']],
#  'acquainted': [['AH', 'K', 'W', 'EY', 'N', 'T', 'IH', 'D'],
#   ['AH', 'K', 'W', 'EY', 'N', 'IH', 'D']],
#  'acquaviva': [['AA', 'K', 'W', 'AA', 'V', 'IY', 'V', 'AH']],
#  'acquiesce': [['AE', 'K', 'W', 'IY', 'EH', 'S']],
#  'acquiesced': [['AE', 'K', 'W', 'IY', 'EH', 'S', 'T']],
#  'acquiescence': [['AE', 'K', 'W', 'IY', 'EH', 'S', 'AH', 'N', 'S']],
#  'acquiescent': [['AE', 'K', 'W', 'IY', 'EH', 'S', 'AH', 'N', 'T']],
#  'acquiescing': [['AE', 'K', 'W', 'IY', 'EH', 'S', 'IH', 'NG']],
#  'acquire': [['AH', 'K', 'W', 'AY', 'ER']],
#  'acquired': [['AH', 'K', 'W', 'AY', 'ER', 'D']],
#  'acquirer': [['AH', 'K', 'W', 'AY', 'ER', 'ER']],
#  "acquirer's": [['AH', 'K', 'W', 'AY', 'ER', 'ER', 'Z']],
#  'acquirers': [['AH', 'K', 'W', 'AY', 'ER', 'ER', 'Z']],
#  'acquires': [['AH', 'K', 'W', 'AY', 'ER', 'Z']],
#  'acquiring': [['AH', 'K', 'W', 'AY', 'R', 'IH', 'NG'],
#   ['AH', 'K', 'W', 'AY', 'ER', 'IH', 'NG']],
#  'acquisition': [['AE', 'K', 'W', 'AH', 'Z', 'IH', 'SH', 'AH', 'N']],
#  "acquisition's": [['AE', 'K', 'W', 'AH', 'Z', 'IH', 'SH', 'AH', 'N', 'Z']],
#  'acquisitions': [['AE', 'K', 'W', 'AH', 'Z', 'IH', 'SH', 'AH', 'N', 'Z']],
#  'acquisitive': [['AH', 'K', 'W', 'IH', 'Z', 'AH', 'T', 'IH', 'V']],
#  'acquit': [['AH', 'K', 'W', 'IH', 'T']],
#  'acquitaine': [['AE', 'K', 'W', 'IH', 'T', 'EY', 'N']],
#  'acquits': [['AH', 'K', 'W', 'IH', 'T', 'S']],
#  'acquittal': [['AH', 'K', 'W', 'IH', 'T', 'AH', 'L']],
#  'acquittals': [['AH', 'K', 'W', 'IH', 'T', 'AH', 'L', 'Z']],
#  'acquitted': [['AH', 'K', 'W', 'IH', 'T', 'IH', 'D']],
#  'acquitting': [['AH', 'K', 'W', 'IH', 'T', 'IH', 'NG']],
#  'acre': [['EY', 'K', 'ER']],
#  'acreage': [['EY', 'K', 'ER', 'IH', 'JH'], ['EY', 'K', 'R', 'AH', 'JH']],
#  'acree': [['AH', 'K', 'R', 'IY']],
#  'acres': [['EY', 'K', 'ER', 'Z']],
#  'acrey': [['AE', 'K', 'R', 'IY']],
#  'acri': [['AA', 'K', 'R', 'IY']],
#  'acrid': [['AE', 'K', 'R', 'IH', 'D']],
#  'acrimonious': [['AE', 'K', 'R', 'AH', 'M', 'OW', 'N', 'IY', 'AH', 'S']],
#  'acrimony': [['AE', 'K', 'R', 'IH', 'M', 'OW', 'N', 'IY']],
#  'acro': [['AE', 'K', 'R', 'OW']],
#  'acrobat': [['AE', 'K', 'R', 'AH', 'B', 'AE', 'T']],
#  'acrobatic': [['AE', 'K', 'R', 'AH', 'B', 'AE', 'T', 'IH', 'K']],
#  'acrobatics': [['AE', 'K', 'R', 'AH', 'B', 'AE', 'T', 'IH', 'K', 'S']],
#  'acrobats': [['AE', 'K', 'R', 'AH', 'B', 'AE', 'T', 'S']],
#  'acrolein': [['AE', 'K', 'R', 'OW', 'L', 'IY', 'N']],
#  'acronym': [['AE', 'K', 'R', 'AH', 'N', 'IH', 'M']],
#  'acronyms': [['AE', 'K', 'R', 'AH', 'N', 'IH', 'M', 'Z']],
#  'acropolis': [['AH', 'K', 'R', 'AA', 'P', 'AH', 'L', 'AH', 'S']],
#  'across': [['AH', 'K', 'R', 'AO', 'S']],
#  'acrylic': [['AH', 'K', 'R', 'IH', 'L', 'IH', 'K']],
#  'acrylics': [['AH', 'K', 'R', 'IH', 'L', 'IH', 'K', 'S']],
#  'act': [['AE', 'K', 'T']],
#  "act's": [['AE', 'K', 'T', 'S']],
#  'acta': [['AE', 'K', 'T', 'AA']],
#  'actava': [['AE', 'K', 'T', 'AA', 'V', 'AH']],
#  "actava's": [['AE', 'K', 'T', 'AA', 'V', 'AH', 'Z']],
#  'actavas': [['AE', 'K', 'T', 'AA', 'V', 'AH', 'Z']],
#  'acted': [['AE', 'K', 'T', 'IH', 'D']],
#  'actel': [['AE', 'K', 'T', 'EH', 'L']],
#  'actigall': [['AE', 'K', 'T', 'IH', 'G', 'AO', 'L']],
#  'actin': [['AE', 'K', 'T', 'AH', 'N']],
#  'acting': [['AE', 'K', 'T', 'IH', 'NG']],
#  'actinide': [['AE', 'K', 'T', 'IH', 'N', 'AY', 'D']],
#  'actinidia': [['AE', 'K', 'T', 'IH', 'N', 'IH', 'D', 'IY', 'AH']],
#  'actinomycosis': [['AE',
#    'K',
#    'T',
#    'IH',
#    'N',
#    'OW',
#    'M',
#    'AY',
#    'K',
#    'OW',
#    'S',
#    'IH',
#    'S']],
#  'action': [['AE', 'K', 'SH', 'AH', 'N']],
#  "action's": [['AE', 'K', 'SH', 'AH', 'N', 'Z']],
#  'actionable': [['AE', 'K', 'SH', 'AH', 'N', 'AH', 'B', 'AH', 'L']],
#  'actions': [['AE', 'K', 'SH', 'AH', 'N', 'Z']],
#  'activase': [['AE', 'K', 'T', 'IH', 'V', 'EY', 'Z']],
#  'activate': [['AE', 'K', 'T', 'AH', 'V', 'EY', 'T']],
#  'activated': [['AE', 'K', 'T', 'AH', 'V', 'EY', 'T', 'IH', 'D']],
#  'activates': [['AE', 'K', 'T', 'AH', 'V', 'EY', 'T', 'S']],
#  'activating': [['AE', 'K', 'T', 'AH', 'V', 'EY', 'T', 'IH', 'NG']],
#  'activation': [['AE', 'K', 'T', 'AH', 'V', 'EY', 'SH', 'AH', 'N']],
#  'activator': [['AE', 'K', 'T', 'AH', 'V', 'EY', 'T', 'ER']],
#  'active': [['AE', 'K', 'T', 'IH', 'V']],
#  "active's": [['AE', 'K', 'T', 'IH', 'V', 'Z']],
#  'actively': [['AE', 'K', 'T', 'IH', 'V', 'L', 'IY']],
#  'actives': [['AE', 'K', 'T', 'IH', 'V', 'Z']],
#  'activision': [['AE', 'K', 'T', 'IH', 'V', 'IH', 'ZH', 'AH', 'N']],
#  'activism': [['AE', 'K', 'T', 'IH', 'V', 'IH', 'Z', 'AH', 'M']],
#  'activist': [['AE', 'K', 'T', 'AH', 'V', 'AH', 'S', 'T'],
#   ['AE', 'K', 'T', 'IH', 'V', 'IH', 'S', 'T']],
#  'activists': [['AE', 'K', 'T', 'AH', 'V', 'AH', 'S', 'T', 'S'],
#   ['AE', 'K', 'T', 'IH', 'V', 'IH', 'S', 'T', 'S']],
#  "activists'": [['AE', 'K', 'T', 'IH', 'V', 'IH', 'S', 'T', 'S']],
#  'activities': [['AE', 'K', 'T', 'IH', 'V', 'AH', 'T', 'IY', 'Z'],
#   ['AE', 'K', 'T', 'IH', 'V', 'IH', 'T', 'IY', 'Z']],
#  'activity': [['AE', 'K', 'T', 'IH', 'V', 'AH', 'T', 'IY'],
#   ['AE', 'K', 'T', 'IH', 'V', 'IH', 'T', 'IY']],
#  'actmedia': [['AE', 'K', 'T', 'M', 'IY', 'D', 'IY', 'AH']],
#  'actodine': [['AE', 'K', 'T', 'OW', 'D', 'AY', 'N']],
#  'acton': [['AE', 'K', 'T', 'AH', 'N']],
#  'actor': [['AE', 'K', 'T', 'ER']],
#  "actor's": [['AE', 'K', 'T', 'ER', 'Z']],
#  'actors': [['AE', 'K', 'T', 'ER', 'Z']],
#  "actors'": [['AE', 'K', 'T', 'ER', 'Z']],
#  'actress': [['AE', 'K', 'T', 'R', 'AH', 'S']],
#  "actress's": [['AE', 'K', 'T', 'R', 'AH', 'S', 'IH', 'Z']],
#  'actresses': [['AE', 'K', 'T', 'R', 'AH', 'S', 'IH', 'Z']],
#  'acts': [['AE', 'K', 'T', 'S'], ['AE', 'K', 'S']],
#  'actual': [['AE', 'K', 'CH', 'AH', 'W', 'AH', 'L'],
#   ['AE', 'K', 'SH', 'AH', 'L']],
#  'actuality': [['AE', 'K', 'CH', 'UW', 'AE', 'L', 'AH', 'T', 'IY']],
#  'actualize': [['AE', 'K', 'CH', 'UW', 'AH', 'L', 'AY', 'Z']],
#  'actually': [['AE', 'K', 'CH', 'UW', 'AH', 'L', 'IY'],
#   ['AE', 'K', 'CH', 'L', 'IY'],
#   ['AE', 'K', 'SH', 'AH', 'L', 'IY']],
#  'actuarial': [['AE', 'K', 'CH', 'UW', 'EH', 'R', 'IY', 'AH', 'L']],
#  'actuaries': [['AE', 'K', 'CH', 'UW', 'EH', 'R', 'IY', 'Z']],
#  'actuary': [['AE', 'K', 'CH', 'UW', 'EH', 'R', 'IY']],
#  'actuate': [['AE', 'K', 'CH', 'UW', 'EY', 'T']],
#  'actuator': [['AE', 'K', 'T', 'Y', 'UW', 'EY', 'T', 'ER'],
#   ['AE', 'K', 'CH', 'UW', 'EY', 'T', 'ER']],
#  'actuators': [['AE', 'K', 'T', 'Y', 'UW', 'EY', 'T', 'ER', 'Z'],
#   ['AE', 'K', 'CH', 'UW', 'EY', 'T', 'ER', 'Z']],
#  'actus': [['AE', 'K', 'T', 'AH', 'S']],
#  'acuff': [['AH', 'K', 'AH', 'F']],
#  'acuity': [['AH', 'K', 'Y', 'UW', 'AH', 'T', 'IY']],
#  'acumen': [['AH', 'K', 'Y', 'UW', 'M', 'AH', 'N']],
#  'acuna': [['AA', 'K', 'UW', 'N', 'AH']],
#  'acupuncture': [['AE', 'K', 'Y', 'UW', 'P', 'AH', 'NG', 'K', 'CH', 'ER']],
#  'acura': [['AE', 'K', 'Y', 'ER', 'AH']],
#  "acura's": [['AE', 'K', 'Y', 'ER', 'AH', 'Z']],
#  'acuras': [['AE', 'K', 'Y', 'ER', 'AH', 'Z']],
#  'acuson': [['AE', 'K', 'Y', 'UW', 'S', 'AH', 'N']],
#  'acustar': [['AE', 'K', 'Y', 'UW', 'S', 'T', 'AA', 'R']],
#  'acusyst': [['AE', 'K', 'Y', 'UW', 'S', 'IH', 'S', 'T']],
#  'acute': [['AH', 'K', 'Y', 'UW', 'T']],
#  'acutely': [['AH', 'K', 'Y', 'UW', 'T', 'L', 'IY']],
#  'acuteness': [['AH', 'K', 'Y', 'UW', 'T', 'N', 'AH', 'S']],
#  'acyclovir': [['AH', 'S', 'IH', 'K', 'L', 'OW', 'V', 'IH', 'R']],
#  'ad': [['AE', 'D']],
#  "ad's": [['AE', 'D', 'Z']],
#  'ad-hoc': [['AE', 'D', 'HH', 'AA', 'K']],
#  'ad-lib': [['AE', 'D', 'L', 'IH', 'B']],
#  'ad-nauseam': [['AE', 'D', 'N', 'AO', 'Z', 'IY', 'AA', 'M']],
#  'ad-nauseum': [['AE', 'D', 'N', 'AO', 'Z', 'IY', 'AH', 'M']],
#  'ada': [['EY', 'D', 'AH']],
#  "ada's": [['EY', 'D', 'AH', 'Z']],
#  'adabel': [['AE', 'D', 'AH', 'B', 'EH', 'L']],
#  'adabelle': [['AE', 'D', 'AH', 'B', 'AH', 'L']],
#  'adachi': [['AA', 'D', 'AA', 'K', 'IY']],
#  'adage': [['AE', 'D', 'AH', 'JH'], ['AE', 'D', 'IH', 'JH']],
#  'adagio': [['AH', 'D', 'AA', 'ZH', 'IY', 'OW']],
#  'adah': [['AE', 'D', 'AA']],
#  'adair': [['AH', 'D', 'EH', 'R']],
#  'adaire': [['AA', 'D', 'EH', 'R']],
#  'adak': [['AH', 'D', 'AE', 'K']],
#  'adalah': [['AA', 'D', 'AA', 'L', 'AH']],
#  'adalia': [['AA', 'D', 'AA', 'L', 'IY', 'AH']],
#  'adam': [['AE', 'D', 'AH', 'M']],
#  "adam's": [['AE', 'D', 'AH', 'M', 'Z']],
#  'adamant': [['AE', 'D', 'AH', 'M', 'AH', 'N', 'T']],
#  'adamantly': [['AE', 'D', 'AH', 'M', 'AH', 'N', 'T', 'L', 'IY']],
#  'adamcik': [['AA', 'D', 'AH', 'M', 'CH', 'IH', 'K']],
#  'adamczak': [['AA', 'D', 'AH', 'M', 'CH', 'AE', 'K']],
#  'adamczyk': [['AA', 'D', 'AH', 'M', 'CH', 'IH', 'K']],
#  'adame': [['AA', 'D', 'AA', 'M', 'IY']],
#  'adamec': [['AH', 'D', 'AA', 'M', 'IH', 'K']],
#  'adamek': [['AH', 'D', 'AA', 'M', 'EH', 'K']],
#  'adames': [['AH', 'D', 'EY', 'M', 'Z']],
#  'adami': [['AA', 'D', 'AA', 'M', 'IY']],
#  'adamik': [['AH', 'D', 'AA', 'M', 'IH', 'K']],
#  'adamina': [['AA', 'D', 'AA', 'M', 'IY', 'N', 'AH']],
#  'adamkus': [['AE', 'D', 'AH', 'M', 'K', 'AH', 'S']],
#  'adamo': [['AA', 'D', 'AA', 'M', 'OW']],
#  'adamowicz': [['AH', 'D', 'AA', 'M', 'AH', 'V', 'IH', 'CH']],
#  'adams': [['AE', 'D', 'AH', 'M', 'Z']],
#  "adams'": [['AE', 'D', 'AH', 'M', 'Z']],
#  "adams's": [['AE', 'D', 'AH', 'M', 'Z', 'IH', 'Z']],
#  'adamski': [['AH', 'D', 'AE', 'M', 'S', 'K', 'IY']],
#  'adamson': [['AE', 'D', 'AH', 'M', 'S', 'AH', 'N']],
#  'adamstown': [['AE', 'D', 'AH', 'M', 'S', 'T', 'AW', 'N']],
#  'adan': [['EY', 'D', 'AH', 'N']],
#  'adapso': [['AH', 'D', 'AE', 'P', 'S', 'OW']],
#  'adapt': [['AH', 'D', 'AE', 'P', 'T']],
#  'adaptability': [['AH',
#    'D',
#    'AE',
#    'P',
#    'T',
#    'AH',
#    'B',
#    'IH',
#    'L',
#    'AH',
#    'T',
#    'IY']],
#  'adaptable': [['AH', 'D', 'AE', 'P', 'T', 'AH', 'B', 'AH', 'L']],
#  'adaptaplex': [['AH', 'D', 'AE', 'P', 'T', 'AH', 'P', 'L', 'EH', 'K', 'S']],
#  'adaptation': [['AE', 'D', 'AH', 'P', 'T', 'EY', 'SH', 'AH', 'N']],
#  'adaptations': [['AE', 'D', 'AE', 'P', 'T', 'EY', 'SH', 'AH', 'N', 'Z'],
#   ['AE', 'D', 'AH', 'P', 'T', 'EY', 'SH', 'AH', 'N', 'Z']],
#  'adaptec': [['AH', 'D', 'AE', 'P', 'T', 'EH', 'K']],
#  "adaptec's": [['AH', 'D', 'AE', 'P', 'T', 'EH', 'K', 'S']],
#  'adapted': [['AH', 'D', 'AE', 'P', 'T', 'IH', 'D']],
#  'adapter': [['AH', 'D', 'AE', 'P', 'T', 'ER']],
#  'adapters': [['AH', 'D', 'AE', 'P', 'T', 'ER', 'Z']],
#  'adapting': [['AH', 'D', 'AE', 'P', 'T', 'IH', 'NG']],
#  'adaptive': [['AH', 'D', 'AE', 'P', 'T', 'IH', 'V']],
#  'adaptor': [['AH', 'D', 'AE', 'P', 'T', 'ER']],
#  'adaptors': [['AH', 'D', 'AE', 'P', 'T', 'ER', 'Z']],
#  'adapts': [['AH', 'D', 'AE', 'P', 'T', 'S']],
#  'adar': [['AH', 'D', 'AA', 'R']],
#  'adarand': [['AE', 'D', 'AH', 'R', 'AE', 'N', 'D']],
#  'adas': [['EY', 'D', 'AH', 'Z']],
#  'aday': [['AH', 'D', 'EY']],
#  'adaza': [['AH', 'D', 'AA', 'Z', 'AH']],
#  'adblock': [['AE', 'D', 'B', 'L', 'AA', 'K']],
#  'adcock': [['AH', 'D', 'K', 'AA', 'K']],
#  'adcox': [['AH', 'D', 'K', 'AA', 'K', 'S']],
#  'add': [['AE', 'D']],
#  'addair': [['AH', 'D', 'EH', 'R']],
#  'addams': [['AE', 'D', 'AH', 'M', 'Z']],
#  'added': [['AE', 'D', 'AH', 'D'], ['AE', 'D', 'IH', 'D']],
#  'addendum': [['AH', 'D', 'EH', 'N', 'D', 'AH', 'M']],
#  'addendums': [['AH', 'D', 'EH', 'N', 'D', 'AH', 'M', 'Z']],
#  'addeo': [['AA', 'D', 'IY', 'OW']],
#  'adder': [['AE', 'D', 'ER']],
#  'adderley': [['AH', 'D', 'ER', 'L', 'IY']],
#  'addicks': [['AE', 'D', 'IH', 'K', 'S']],
#  'addict': [['AH', 'D', 'IH', 'K', 'T'], ['AE', 'D', 'IH', 'K', 'T']],
#  'addicted': [['AH', 'D', 'IH', 'K', 'T', 'IH', 'D']],
#  'addicting': [['AH', 'D', 'IH', 'K', 'T', 'IH', 'NG']],
#  'addiction': [['AH', 'D', 'IH', 'K', 'SH', 'AH', 'N']],
#  'addictions': [['AH', 'D', 'IH', 'K', 'SH', 'AH', 'N', 'Z']],
#  'addictive': [['AH', 'D', 'IH', 'K', 'T', 'IH', 'V']],
#  'addicts': [['AH', 'D', 'IH', 'K', 'T', 'S'],
#   ['AE', 'D', 'IH', 'K', 'T', 'S']],
#  'addidas': [['AH', 'D', 'IY', 'D', 'AH', 'S']],
#  "addidas'": [['AH', 'D', 'IY', 'D', 'AH', 'S']],
#  "addidas's": [['AH', 'D', 'IY', 'D', 'AH', 'S', 'IH', 'Z']],
#  'addidases': [['AH', 'D', 'IY', 'D', 'AH', 'S', 'IH', 'Z']],
#  'addie': [['AE', 'D', 'IY']],
#  'adding': [['AE', 'D', 'IH', 'NG']],
#  'addington': [['AE', 'D', 'IH', 'NG', 'T', 'AH', 'N']],
#  'addis': [['AA', 'D', 'IH', 'S']],
#  'addis-ababa': [['AA', 'D', 'IH', 'S', 'AH', 'B', 'AA', 'B', 'AA'],
#   ['AA', 'D', 'IY', 'S', 'AH', 'B', 'AA', 'B', 'AA']],
#  'addison': [['AE', 'D', 'AH', 'S', 'AH', 'N'],
#   ['AE', 'D', 'IH', 'S', 'AH', 'N']],
#  "addison's": [['AE', 'D', 'IH', 'S', 'AH', 'N', 'Z']],
#  'addition': [['AH', 'D', 'IH', 'SH', 'AH', 'N']],
#  'additional': [['AH', 'D', 'IH', 'SH', 'AH', 'N', 'AH', 'L'],
#   ['AH', 'D', 'IH', 'SH', 'N', 'AH', 'L']],
#  'additionally': [['AH', 'D', 'IH', 'SH', 'AH', 'N', 'AH', 'L', 'IY'],
#   ['AH', 'D', 'IH', 'SH', 'N', 'AH', 'L', 'IY']],
#  'additions': [['AH', 'D', 'IH', 'SH', 'AH', 'N', 'Z']],
#  'additive': [['AE', 'D', 'AH', 'T', 'IH', 'V'],
#   ['AE', 'D', 'IH', 'T', 'IH', 'V']],
#  'additives': [['AE', 'D', 'AH', 'T', 'IH', 'V', 'Z'],
#   ['AE', 'D', 'IH', 'T', 'IH', 'V', 'Z']],
#  'addle': [['AE', 'D', 'AH', 'L']],
#  'addled': [['AE', 'D', 'AH', 'L', 'D']],
#  'addleman': [['AE', 'D', 'AH', 'L', 'M', 'AH', 'N']],
#  'address': [['AE', 'D', 'R', 'EH', 'S'], ['AH', 'D', 'R', 'EH', 'S']],
#  'addressable': [['AH', 'D', 'R', 'EH', 'S', 'AH', 'B', 'AH', 'L']],
#  'addressed': [['AH', 'D', 'R', 'EH', 'S', 'T']],
#  'addressee': [['AE', 'D', 'R', 'EH', 'S', 'IY']],
#  'addresses': [['AE', 'D', 'R', 'EH', 'S', 'IH', 'Z'],
#   ['AH', 'D', 'R', 'EH', 'S', 'IH', 'Z']],
#  'addressing': [['AH', 'D', 'R', 'EH', 'S', 'IH', 'NG']],
#  'adds': [['AE', 'D', 'Z']],
#  'adduci': [['AA', 'D', 'UW', 'CH', 'IY']],
#  'adduct': [['AE', 'D', 'AH', 'K', 'T']],
#  'addwest': [['AE', 'D', 'W', 'EH', 'S', 'T']],
#  'addy': [['AE', 'D', 'IY']],
#  'addyston': [['AE', 'D', 'IY', 'S', 'T', 'AH', 'N']],
#  'ade': [['EY', 'D']],
#  'adee': [['AH', 'D', 'IY']],
#  'adel': [['AH', 'D', 'EH', 'L']],
#  'adela': [['AH', 'D', 'EH', 'L', 'AH']],
#  'adelaar': [['AE', 'D', 'AH', 'L', 'AA', 'R']],
#  'adelaide': [['AE', 'D', 'AH', 'L', 'EY', 'D']],
#  'adelanto': [['AE', 'D', 'AH', 'L', 'AA', 'N', 'T', 'OW']],
#  'adelbert': [['AH', 'D', 'EH', 'L', 'B', 'ER', 'T']],
#  'adele': [['AH', 'D', 'EH', 'L']],
#  "adele's": [['AH', 'D', 'EH', 'L', 'Z']],
#  'adeline': [['AE', 'D', 'AH', 'L', 'AY', 'N']],
#  'adelizzi': [['AE', 'D', 'AH', 'L', 'IY', 'Z', 'IY']],
#  'adell': [['AH', 'D', 'EH', 'L']],
#  "adell's": [['AH', 'D', 'EH', 'L', 'Z']],
#  'adelle': [['AH', 'D', 'EH', 'L']],
#  'adelman': [['AE', 'D', 'AH', 'L', 'M', 'AH', 'N'],
#   ['EH', 'D', 'AH', 'L', 'M', 'AH', 'N']],
#  'adelmann': [['AE', 'D', 'AH', 'L', 'M', 'AH', 'N']],
#  ...}

# %%
phonetisaurus.train(
    lexicon,
    model_path='test_dict.model'
)
# Out:
# INFO:phonetisaurus-train:2022-10-31 10:36:47:  Checking command configuration...
# DEBUG:phonetisaurus-train:2022-10-31 10:36:47:  Directory /tmp/tmpgwkdqahh/train does not exist.  Trying to create.
# INFO:phonetisaurus-train:2022-10-31 10:36:47:  Checking lexicon for reserved characters: '}', '|', '_'...
# DEBUG:phonetisaurus-train:2022-10-31 10:36:47:  arpa_path:  train/model.o8.arpa
# DEBUG:phonetisaurus-train:2022-10-31 10:36:47:  corpus_path:  train/model.corpus
# DEBUG:phonetisaurus-train:2022-10-31 10:36:47:  dir_prefix:  train
# DEBUG:phonetisaurus-train:2022-10-31 10:36:47:  grow:  False
# DEBUG:phonetisaurus-train:2022-10-31 10:36:47:  lexicon_file:  /tmp/tmpqdpc1ump.txt
# DEBUG:phonetisaurus-train:2022-10-31 10:36:47:  logger:  <Logger phonetisaurus-train (DEBUG)>
# DEBUG:phonetisaurus-train:2022-10-31 10:36:47:  makeJointNgramCommand:  <bound method G2PModelTrainer._mitlm of <__main__.G2PModelTrainer object at 0x7fba8e96a0>>
# DEBUG:phonetisaurus-train:2022-10-31 10:36:47:  model_path:  train/model.fst
# DEBUG:phonetisaurus-train:2022-10-31 10:36:47:  model_prefix:  model
# DEBUG:phonetisaurus-train:2022-10-31 10:36:47:  ngram_order:  8
# DEBUG:phonetisaurus-train:2022-10-31 10:36:47:  seq1_del:  False
# DEBUG:phonetisaurus-train:2022-10-31 10:36:47:  seq1_max:  2
# DEBUG:phonetisaurus-train:2022-10-31 10:36:47:  seq2_del:  True
# DEBUG:phonetisaurus-train:2022-10-31 10:36:47:  seq2_max:  2
# DEBUG:phonetisaurus-train:2022-10-31 10:36:47:  verbose:  True
# DEBUG:phonetisaurus-train:2022-10-31 10:36:47:  phonetisaurus-align --input=/tmp/tmpqdpc1ump.txt --ofile=train/model.corpus --seq1_del=false --seq2_del=true --seq1_max=2 --seq2_max=2 --grow=false
# INFO:phonetisaurus-train:2022-10-31 10:36:47:  Aligning lexicon...
# GitRevision: package
# Loading input file: /tmp/tmpqdpc1ump.txt
# Alignment failed: a a a
# Alignment failed: a l .
# Alignment failed: a o l
# Alignment failed: a w b
# Alignment failed: a w b
# Alignment failed: b b q
# Alignment failed: b b q
# Alignment failed: b m w
# Alignment failed: c 1
# Alignment failed: c 3
# Alignment failed: c 4
# Alignment failed: c 5
# Alignment failed: c o r p
# Alignment failed: c r .
# Alignment failed: c x c
# Alignment failed: d f w
# Alignment failed: d f w
# Alignment failed: d r
# Alignment failed: d w i
# Alignment failed: d w i
# Alignment failed: e t c
# Alignment failed: f e b
# Alignment failed: f y i
# Alignment failed: g a
# Alignment failed: i n c .
# Alignment failed: j r
# Alignment failed: k w h
# Alignment failed: l t d
# Alignment failed: m 1
# Alignment failed: m 3
# Alignment failed: m 4
# Alignment failed: m 5
# Alignment failed: m p g
# Alignment failed: m p h
# Alignment failed: m r
# Alignment failed: p e n n a
# Alignment failed: q
# Alignment failed: r e p
# Alignment failed: r e p .
# Alignment failed: s g t
# Alignment failed: s q l
# Alignment failed: s r
# Alignment failed: s r
# Alignment failed: s t
# Alignment failed: t e w
# Alignment failed: t v
# Alignment failed: w
# Alignment failed: w ' s
# Alignment failed: w .
# Alignment failed: w . s
# Alignment failed: w a g a
# Alignment failed: w a g a
# Alignment failed: w m
# Alignment failed: w m
# Alignment failed: w o r
# Alignment failed: w o r
# Alignment failed: w s
# Alignment failed: w s
# Alignment failed: w y
# Alignment failed: x
# Alignment failed: x m l
# Starting EM...
# Finished first iter...
# Iteration: 1 Change: 1.1533
# Iteration: 2 Change: 0.140089
# Iteration: 3 Change: 0.0440178
# Iteration: 4 Change: 0.0153551
# Iteration: 5 Change: 0.00670624
# Iteration: 6 Change: 0.00353622
# Iteration: 7 Change: 0.00128269
# Iteration: 8 Change: 0.00196075
# Iteration: 9 Change: 0.00149441
# Iteration: 10 Change: 0.00111103
# Iteration: 11 Change: 0.000889778
# Last iteration:
# DEBUG:phonetisaurus-train:2022-10-31 10:45:33:  estimate-ngram -o 8 -t train/model.corpus -wl train/model.o8.arpa
# INFO:phonetisaurus-train:2022-10-31 10:45:33:  Training joint ngram model...
# 0.002	Loading corpus train/model.corpus...
# 2.006	Smoothing[1] = ModKN
# 2.006	Smoothing[2] = ModKN
# 2.006	Smoothing[3] = ModKN
# 2.006	Smoothing[4] = ModKN
# 2.006	Smoothing[5] = ModKN
# 2.006	Smoothing[6] = ModKN
# 2.006	Smoothing[7] = ModKN
# 2.006	Smoothing[8] = ModKN
# 2.006	Set smoothing algorithms...
# 2.006	Y 6.926829e-01
# 2.006	Y 5.967271e-01
# 2.010	Y 6.345374e-01
# 2.024	Y 7.229943e-01
# 2.048	Y 7.915868e-01
# 2.073	Y 8.398123e-01
# 2.093	Y 8.739715e-01
# 2.102	Y 8.067595e-01
# 2.102	Estimating full n-gram model...
# 2.195	Saving LM to train/model.o8.arpa...
# DEBUG:phonetisaurus-train:2022-10-31 10:45:39:  phonetisaurus-arpa2wfst --lm=train/model.o8.arpa --ofile=train/model.fst
# INFO:phonetisaurus-train:2022-10-31 10:45:39:  Converting ARPA format joint n-gram model to WFST format...
# GitRevision: package
# Initializing...
# Converting...
# INFO:phonetisaurus-train:2022-10-31 10:46:12:  G2P training succeeded: train/model.fst

# %%
for prediction in phonetisaurus.predict(
    words=['magic','voice','magicvoice',"'bout"],
    model_path='test_dict.model',
    nbest=1
):
    print(prediction)
# Out:
# ('magic', ['M', 'AE', 'JH', 'IH', 'K'])
# ('voice', ['V', 'OY', 'S'])
# ('magicvoice', ['M', 'AE', 'JH', 'IH', 'K', 'V', 'OY', 'S'])
# ("'bout", ['B', 'AW', 'T'])

# %% [markdown]
# # VOSK

# %%
# Generate a vocabulary dictionary based on an exported corpus
# !text2wfreq < vosk_lm/corpus.txt | wfreq2vocab > vosk_lm/vocab
# Out:
# wfreq2vocab : Will generate a vocabulary containing the most
#               frequent 20000 words. Reading wfreq stream from stdin...
# text2wfreq : Reading text from standard input...
# text2wfreq : Done.
# wfreq2vocab : Done.

# %%
# read the VOSK dictionary
RE_WORDS = re.compile(
    r"^(?P<word>[\[!]?[a-zA-Z0-9'´\.\-āăáæćçčėèéęğģģìi̇łľňñńņøóöōőřŕšşśťţűứüūž&]+)[\]]?\s+(?P<pronunciation>[a-zA-Z0-9\`\{\@\s\:]+)\s*$"
)
lexicon = {}
with open(os.path.expanduser('~/.config/naomi/vosk/vosk-model-en-us-0.22-compile/db/en.dic')) as f:
    line = f.readline()
    while line:
        one = False
        for match in RE_WORDS.finditer(line):
            one = True
            if(match.group('word') == 'magic'):
                print(f"{match.group('word')} {match.group('pronunciation')}")
            try:
                lexicon[match.group('word')].append(match.group('pronunciation').split())
            except KeyError:
                lexicon[match.group('word')]=[match.group('pronunciation').split()]
        if(not one):
            print(f"Unmatched line: {line}")
        line = f.readline()
lexicon
# Out:
# Unmatched line: ch��vez s i eI tS v i i z i
#
# Unmatched line: copyright© k A p i r aI t
#
# Unmatched line: high�tech eI tS aI dZ i eI tS t i i s i eI tS
#
# Unmatched line: hospital�acquired eI tS oU E s p i aI t i eI E l eI s i k j u j u aI A r i d i
#
# magic m { dZ I k
#
# Unmatched line: pseudo�democracies p i E s i j u d i oU d i i E m oU s i A r eI s i aI i E s
#
# Unmatched line: self�serving E s i E l E f E s i A r v i aI E n dZ i
#
# Unmatched line: they�focus t i eI tS i w aI E f oU s i j u E s
#
# Unmatched line: you¿re w aI oU j u A r i
# {'!SIL': [['SIL']],
#  "'bout": [['b', 'aU', 't']],
#  "'cause": [['k', '@', 'z']],
#  "'clock": [['k', 'l', 'A', 'k']],
#  "'d": [['d', 'i']],
#  "'m": [['m']],
#  "'re": [['3`'], ['r']],
#  "'s": [['E', 's'], ['I', 'z'], ['s'], ['z']],
#  "'t": [['t']],
#  "'til": [['t', 'I', 'l']],
#  "'ve": [['v']],
#  'a': [['@'], ['V'], ['eI']],
#  'a&e': [['eI', '{', 'n', 'd', 'i']],
#  'a&m': [['eI', '{', 'n', 'd', 'E', 'm']],
#  "a''s": [['eI', 'z']],
#  "a'body": [['eI', 'b', 'A', 'd', 'i']],
#  "a'court": [['eI', 'k', 'O', 'r', 't']],
#  "a'd": [['eI', 'd']],
#  "a'gha": [['eI', 'g', '@']],
#  "a'goin": [['eI', 'g', 'OI', 'n']],
#  "a'isha": [['A', 'I', 'S', 'V']],
#  "a'll": [['eI', 'l']],
#  "a'm": [['eI', 'm']],
#  "a'mighty": [['eI', 'm', 'aI', '4', 'i']],
#  "a'mighty's": [['eI', 'm', 'aI', '4', 'i', 'z']],
#  "a'most": [['eI', 'm', 'oU', 's', 't']],
#  "a'n't": [['eI', '@', 'n', 't']],
#  "a'penny": [['eI', 'p', 'E', 'n', 'i']],
#  "a'ready": [['eI', 'r', 'i', 'd', 'i']],
#  "a'right": [['eI', 'r', 'aI', 't']],
#  "a'rony": [['eI', 'r', 'oU', 'n', 'i']],
#  "a's": [['eI', 'z']],
#  "a'sdjei": [['V', 'dZ', 'eI']],
#  "a'sdjmi": [['V', 'dZ', 'm', 'i']],
#  "a'smkar": [['V', 's', 'm', 'k', 'A', 'r']],
#  "a'ssa'ib": [['V', 's', 'A', 'I', 'b']],
#  "a'sssos": [['V', 's', 'oU', 'z']],
#  "a'ter": [['eI', '4', '@`']],
#  "a'ternoon": [['eI', '4', '@`', 'n', 'u', 'n']],
#  "a'terwards": [['eI', '4', '@`', 'w', '@`', 'd', 'z']],
#  "a'thegither": [['eI', 'D', '@', 'dZ', 'I', 'D', '@`']],
#  "a'thing": [['eI', 'D', 'I', 'N']],
#  "a'tim": [['eI', '4', 'I', 'm']],
#  "a've": [['@', 'v']],
#  'a-': [['@'], ['A'], ['E'], ['O'], ['eI'], ['{', 'l'], ['{']],
#  'a-b.': [['V', 'b', 'i']],
#  'a-bat': [['V', 'b', '{', 't']],
#  'a-choosing': [['@', 'tS', 'u', 'z', 'I', 'N']],
#  'a-com': [['V', 'k', 'A', 'm']],
#  'a-h': [['V', 'eI', 'tS']],
#  'a-h.': [['V', 'eI', 'tS']],
#  'a-j.': [['V', 'dZ', 'eI']],
#  'a-k.': [['V', 'k', 'eI']],
#  'a-levels': [['V', 'l', 'E', 'v', 'V', 'l', 'z']],
#  'a-list': [['V', 'l', 'I', 's', 't']],
#  'a-roid': [['V', 'r', 'OI', 'd']],
#  'a-space': [['V', 's', 'p', 'eI', 's']],
#  'a-star': [['V', 's', 't', 'A', 'r']],
#  'a-t.': [['V', 't', 'i']],
#  'a-z.': [['V', 'z', 'i']],
#  'a.': [['eI']],
#  "a.'s": [['eI', 'z']],
#  'a.a.': [['eI', 'eI']],
#  "a.a.'s": [['eI', 'eI', 'E', 's']],
#  'a.a.a.s.': [['eI', 'eI', 'eI', 'E', 's']],
#  'a.a.b.': [['eI', 'eI', 'b', 'i']],
#  'a.a.e.': [['eI', 'eI', 'i']],
#  'a.a.j.': [['eI', 'eI', 'dZ', 'eI']],
#  'a.a.p.': [['eI', 'eI', 'p', 'i']],
#  'a.a.p.l.': [['eI', 'eI', 'p', 'i', 'E', 'l']],
#  'a.a.r.': [['eI', 'eI', 'A', 'r']],
#  'a.a.r.c.': [['eI', 'eI', 'A', 'r', 's', 'i']],
#  'a.a.r.p.': [['eI', 'eI', 'A', 'r', 'p', 'i']],
#  "a.a.r.p.'s": [['eI', 'eI', 'A', 'r', 'p', 'i', 'E', 's']],
#  'a.a.s.': [['eI', 'eI', 'E', 's']],
#  'a.a.u.': [['eI', 'eI', 'j', 'u']],
#  'a.a.u.w.': [['eI', 'eI', 'j', 'u', 'd', 'V', 'b', 'V', 'l', 'j', 'u']],
#  'a.a.v.': [['eI', 'eI', 'v', 'i']],
#  'a.b.': [['eI', 'b', 'i']],
#  "a.b.'s": [['eI', 'b', 'i', 'E', 's']],
#  'a.b.a.': [['eI', 'b', 'i', 'eI']],
#  "a.b.a.'s": [['eI', 'b', 'i', 'eI', 'E', 's']],
#  'a.b.b.': [['eI', 'b', 'i', 'b', 'i']],
#  "a.b.b.a.'s": [['eI', 'b', 'i', 'b', 'i', 'eI', 'E', 's']],
#  'a.b.c.': [['eI', 'b', 'i', 's', 'i']],
#  "a.b.c.'s": [['eI', 'b', 'i', 's', 'i', 'E', 's']],
#  'a.b.h.': [['eI', 'b', 'i', 'eI', 'tS']],
#  'a.b.i.': [['eI', 'b', 'i', 'aI']],
#  'a.b.l.': [['eI', 'b', 'i', 'E', 'l']],
#  'a.b.m.': [['eI', 'b', 'i', 'E', 'm']],
#  "a.b.m.'s": [['eI', 'b', 'i', 'E', 'm', 'E', 's']],
#  'a.b.m.s.': [['eI', 'b', 'i', 'E', 'm', 'E', 's']],
#  'a.b.n.': [['eI', 'b', 'i', 'E', 'n']],
#  'a.b.p.': [['eI', 'b', 'i', 'p', 'i']],
#  'a.b.r.': [['eI', 'b', 'i', 'A', 'r']],
#  'a.b.s.': [['eI', 'b', 'i', 'E', 's']],
#  'a.b.s.a.': [['eI', 'b', 'i', 'E', 's', 'eI']],
#  'a.b.t.': [['eI', 'b', 'i', 't', 'i']],
#  'a.b.t.a.': [['eI', 'b', 'i', 't', 'i', 'eI']],
#  'a.b.v.': [['eI', 'b', 'i', 'v', 'i']],
#  'a.c.': [['eI', 's', 'i']],
#  "a.c.'s": [['eI', 's', 'i', 'E', 's']],
#  'a.c.c.': [['eI', 's', 'i', 's', 'i']],
#  'a.c.c.s.': [['eI', 's', 'i', 's', 'i', 'E', 's']],
#  'a.c.f.': [['eI', 's', 'i', 'E', 'f']],
#  'a.c.g.': [['eI', 's', 'i', 'dZ', 'i']],
#  'a.c.i.': [['eI', 's', 'i', 'aI']],
#  'a.c.l.': [['eI', 's', 'i', 'E', 'l']],
#  'a.c.l.u.': [['eI', 's', 'i', 'E', 'l', 'j', 'u']],
#  "a.c.l.u.'s": [['eI', 's', 'i', 'E', 'l', 'j', 'u', 'E', 's']],
#  'a.c.m.': [['eI', 's', 'i', 'E', 'm']],
#  'a.c.m.d.': [['eI', 's', 'i', 'E', 'm', 'd', 'i']],
#  'a.c.p.': [['eI', 's', 'i', 'p', 'i']],
#  'a.c.r.': [['eI', 's', 'i', 'A', 'r']],
#  'a.c.s.': [['eI', 's', 'i', 'E', 's']],
#  'a.c.t.a.': [['eI', 's', 'i', 't', 'i', 'eI']],
#  'a.c.u.': [['eI', 's', 'i', 'j', 'u']],
#  'a.c.w.': [['eI', 's', 'i', 'd', 'V', 'b', 'V', 'l', 'j', 'u']],
#  'a.d.': [['eI', 'd', 'i']],
#  'a.d.a.': [['eI', 'd', 'i', 'eI']],
#  "a.d.a.'s": [['eI', 'd', 'i', 'eI', 'E', 's']],
#  'a.d.b.': [['eI', 'd', 'i', 'b', 'i']],
#  'a.d.c.': [['eI', 'd', 'i', 's', 'i']],
#  'a.d.d.': [['eI', 'd', 'i', 'd', 'i']],
#  'a.d.h.': [['eI', 'd', 'i', 'eI', 'tS']],
#  'a.d.l.': [['eI', 'd', 'i', 'E', 'l']],
#  'a.d.m.': [['eI', 'd', 'i', 'E', 'm']],
#  'a.d.n.': [['eI', 'd', 'i', 'E', 'n']],
#  'a.d.p.': [['eI', 'd', 'i', 'p', 'i']],
#  'a.d.r.': [['eI', 'd', 'i', 'A', 'r']],
#  "a.d.r.'s": [['eI', 'd', 'i', 'A', 'r', 'E', 's']],
#  'a.d.t.': [['eI', 'd', 'i', 't', 'i']],
#  'a.e.a.': [['eI', 'i', 'eI']],
#  "a.e.d.'s": [['eI', 'i', 'd', 'i', 'E', 's']],
#  'a.e.g.': [['eI', 'i', 'dZ', 'i']],
#  'a.e.p.': [['eI', 'i', 'p', 'i']],
#  'a.f.': [['eI', 'E', 'f']],
#  'a.f.-on': [['eI', 'E', 'f', 'A', 'n']],
#  'a.f.c.': [['eI', 'E', 'f', 's', 'i']],
#  "a.f.c.'s": [['eI', 'E', 'f', 's', 'i', 'E', 's']],
#  'a.f.g.e.': [['eI', 'E', 'f', 'dZ', 'i', 'i']],
#  'a.f.i.s.': [['eI', 'E', 'f', 'aI', 'E', 's']],
#  'a.f.l.': [['eI', 'E', 'f', 'E', 'l']],
#  'a.f.l.-c.i.o.': [['eI', 'E', 'f', 'E', 'l', 's', 'i', 'aI', 'oU']],
#  'a.f.l.-cio': [['eI', 'E', 'f', 'E', 'l', 'tS', 'i', 'oU']],
#  'a.f.m.': [['eI', 'E', 'f', 'E', 'm']],
#  'a.f.p.': [['eI', 'E', 'f', 'p', 'i']],
#  'a.f.r.': [['eI', 'E', 'f', 'A', 'r']],
#  'a.g.': [['eI', 'dZ', 'i']],
#  "a.g.'s": [['eI', 'dZ', 'i', 'E', 's']],
#  'a.g.c.': [['eI', 'dZ', 'i', 's', 'i']],
#  'a.g.i.': [['eI', 'dZ', 'i', 'aI']],
#  'a.g.m.': [['eI', 'dZ', 'i', 'E', 'm']],
#  'a.g.r.': [['eI', 'dZ', 'i', 'A', 'r']],
#  'a.g.u.': [['eI', 'dZ', 'i', 'j', 'u']],
#  'a.h.': [['eI', 'eI', 'tS']],
#  'a.h.l.': [['eI', 'eI', 'tS', 'E', 'l']],
#  'a.h.r.q.': [['eI', 'eI', 'tS', 'A', 'r', 'k', 'j', 'u']],
#  'a.i.': [['eI', 'aI']],
#  'a.i.a.': [['eI', 'aI', 'eI']],
#  "a.i.a.'s": [['eI', 'aI', 'eI', 'E', 's']],
#  'a.i.b.': [['eI', 'aI', 'b', 'i']],
#  'a.i.f.': [['eI', 'aI', 'E', 'f']],
#  'a.i.g.': [['eI', 'aI', 'dZ', 'i']],
#  "a.i.l.'s": [['eI', 'aI', 'E', 'l', 'E', 's']],
#  'a.i.m.': [['eI', 'aI', 'E', 'm']],
#  'a.i.s.i.': [['eI', 'aI', 'E', 's', 'aI']],
#  'a.j.': [['eI', 'dZ', 'eI']],
#  'a.j.c.': [['eI', 'dZ', 'eI', 's', 'i']],
#  'a.k.a': [['eI', 'k', 'eI', 'V']],
#  'a.k.a.': [['eI', 'k', 'eI', 'eI']],
#  'a.k.p.': [['eI', 'k', 'eI', 'p', 'i']],
#  'a.l.': [['eI', 'E', 'l']],
#  "a.l.'s": [['eI', 'E', 'l', 'E', 's']],
#  'a.l.c.s.': [['eI', 'E', 'l', 's', 'i', 'E', 's']],
#  'a.l.g.': [['eI', 'E', 'l', 'dZ', 'i']],
#  'a.l.l.l.': [['eI', 'E', 'l', 'E', 'l', 'E', 'l']],
#  'a.l.p.': [['eI', 'E', 'l', 'p', 'i']],
#  'a.l.s.': [['eI', 'E', 'l', 'E', 's']],
#  'a.m.': [['eI', 'E', 'm']],
#  'a.m.a.': [['eI', 'E', 'm', 'eI']],
#  "a.m.a.'s": [['eI', 'E', 'm', 'eI', 'E', 's']],
#  'a.m.b.': [['eI', 'E', 'm', 'b', 'i']],
#  'a.m.d.': [['eI', 'E', 'm', 'd', 'i']],
#  "a.m.d.'s": [['eI', 'E', 'm', 'd', 'i', 'E', 's']],
#  "a.m.i.'s": [['eI', 'E', 'm', 'aI', 'E', 's']],
#  'a.m.i.a.': [['eI', 'E', 'm', 'aI', 'eI']],
#  'a.m.m.': [['eI', 'E', 'm', 'E', 'm']],
#  'a.m.r.': [['eI', 'E', 'm', 'A', 'r']],
#  'a.m.t.': [['eI', 'E', 'm', 't', 'i']],
#  'a.n.c.': [['eI', 'E', 'n', 's', 'i']],
#  'a.n.s.i.': [['eI', 'E', 'n', 'E', 's', 'aI']],
#  'a.n.z.': [['eI', 'E', 'n', 'z', 'i']],
#  'a.o.': [['eI', 'oU']],
#  'a.o.l.': [['eI', 'oU', 'E', 'l']],
#  "a.o.l.'s": [['eI', 'oU', 'E', 'l', 'E', 's']],
#  'a.o.n.b.': [['eI', 'oU', 'E', 'n', 'b', 'i']],
#  'a.p.': [['eI', 'p', 'i']],
#  "a.p.'s": [['eI', 'p', 'i', 'E', 's']],
#  'a.p.a.': [['eI', 'p', 'i', 'eI']],
#  'a.p.b.': [['eI', 'p', 'i', 'b', 'i']],
#  'a.p.c.': [['eI', 'p', 'i', 's', 'i']],
#  "a.p.c.'s": [['eI', 'p', 'i', 's', 'i', 'E', 's']],
#  'a.p.g.': [['eI', 'p', 'i', 'dZ', 'i']],
#  'a.p.i.': [['eI', 'p', 'i', 'aI']],
#  "a.p.l.'s": [['eI', 'p', 'i', 'E', 'l', 'E', 's']],
#  'a.p.r.': [['eI', 'p', 'i', 'A', 'r']],
#  "a.p.r.'s": [['eI', 'p', 'i', 'A', 'r', 'E', 's']],
#  'a.p.s.': [['eI', 'p', 'i', 'E', 's']],
#  'a.p.s.a.': [['eI', 'p', 'i', 'E', 's', 'eI']],
#  'a.p.t.a.': [['eI', 'p', 'i', 't', 'i', 'eI']],
#  'a.q.': [['eI', 'k', 'j', 'u']],
#  'a.q.a.': [['eI', 'k', 'j', 'u', 'eI']],
#  'a.q.i.m.': [['eI', 'k', 'j', 'u', 'aI', 'E', 'm']],
#  'a.q.r.': [['eI', 'k', 'j', 'u', 'A', 'r']],
#  'a.r.c.a.': [['eI', 'A', 'r', 's', 'i', 'eI']],
#  'a.r.g.s': [['eI', 'A', 'r', 'dZ', 'i', 'E', 's']],
#  "a.r.i.f.'s": [['eI', 'A', 'r', 'aI', 'E', 'f', 'E', 's']],
#  'a.r.u.': [['eI', 'A', 'r', 'j', 'u']],
#  'a.r.v.': [['eI', 'A', 'r', 'v', 'i']],
#  "a.r.v.'s": [['eI', 'A', 'r', 'v', 'i', 'E', 's']],
#  'a.s': [['eI', 'z']],
#  'a.s.': [['eI', 'E', 's']],
#  'a.s.a.p.': [['eI', 'E', 's', 'eI', 'p', 'i']],
#  'a.s.b.': [['eI', 'E', 's', 'b', 'i']],
#  'a.s.c.': [['eI', 'E', 's', 's', 'i']],
#  'a.s.d.': [['eI', 'E', 's', 'd', 'i']],
#  'a.s.e.': [['eI', 'E', 's', 'i']],
#  'a.s.i.': [['eI', 'E', 's', 'aI']],
#  'a.s.i.s.': [['eI', 'E', 's', 'aI', 'E', 's']],
#  'a.s.l.': [['eI', 'E', 's', 'E', 'l']],
#  'a.s.m.': [['eI', 'E', 's', 'E', 'm']],
#  'a.s.n.': [['eI', 'E', 's', 'E', 'n']],
#  'a.s.o.': [['eI', 'E', 's', 'oU']],
#  "a.s.p.'s": [['eI', 'E', 's', 'p', 'i', 'E', 's']],
#  'a.s.p.c.a.': [['eI', 'E', 's', 'p', 'i', 's', 'i', 'eI']],
#  'a.s.r.': [['eI', 'E', 's', 'A', 'r']],
#  'a.s.r.m.': [['eI', 'E', 's', 'A', 'r', 'E', 'm']],
#  'a.s.u.': [['eI', 'E', 's', 'j', 'u']],
#  'a.s.u.r.': [['eI', 'E', 's', 'j', 'u', 'A', 'r']],
#  'a.s.u.s.': [['eI', 'E', 's', 'j', 'u', 'E', 's']],
#  'a.s.x.': [['eI', 'E', 's', '{', 'k', 's']],
#  'a.t.': [['eI', 't', 'i']],
#  "a.t.a.'s": [['eI', 't', 'i', 'eI', 'E', 's']],
#  'a.t.c.': [['eI', 't', 'i', 's', 'i']],
#  'a.t.c.a.': [['eI', 't', 'i', 's', 'i', 'eI']],
#  'a.t.f.': [['eI', 't', 'i', 'E', 'f']],
#  'a.t.g.': [['eI', 't', 'i', 'dZ', 'i']],
#  'a.t.l.': [['eI', 't', 'i', 'E', 'l']],
#  'a.t.m.': [['eI', 't', 'i', 'E', 'm']],
#  "a.t.m.'s": [['eI', 't', 'i', 'E', 'm', 'E', 's']],
#  'a.t.m.s.': [['eI', 't', 'i', 'E', 'm', 'E', 's']],
#  'a.t.o.c.': [['eI', 't', 'i', 'oU', 's', 'i']],
#  'a.t.o.l.': [['eI', 't', 'i', 'oU', 'E', 'l']],
#  'a.t.p.': [['eI', 't', 'i', 'p', 'i']],
#  "a.t.p.'s": [['eI', 't', 'i', 'p', 'i', 'E', 's']],
#  'a.t.r.': [['eI', 't', 'i', 'A', 'r']],
#  'a.t.t.': [['eI', 't', 'i', 't', 'i']],
#  "a.t.t.'s": [['eI', 't', 'i', 't', 'i', 'E', 's']],
#  'a.t.v.': [['eI', 't', 'i', 'v', 'i']],
#  "a.t.v.'s": [['eI', 't', 'i', 'v', 'i', 'E', 's']],
#  'a.u.': [['eI', 'j', 'u']],
#  "a.u.'s": [['eI', 'j', 'u', 'E', 's']],
#  'a.u.c.': [['eI', 'j', 'u', 's', 'i']],
#  'a.v.': [['eI', 'v', 'i']],
#  'a.v.c.': [['eI', 'v', 'i', 's', 'i']],
#  'a.v.e.o.': [['eI', 'v', 'i', 'i', 'oU']],
#  'a.v.m.': [['eI', 'v', 'i', 'E', 'm']],
#  'a.v.m.a.': [['eI', 'v', 'i', 'E', 'm', 'eI']],
#  'a.w.b.': [['eI', 'd', 'V', 'b', 'V', 'l', 'j', 'u', 'b', 'i']],
#  'a.w.t.': [['eI', 'd', 'V', 'b', 'V', 'l', 'j', 'u', 't', 'i']],
#  'a.x.i.': [['eI', '{', 'k', 's', 'aI']],
#  'a.y.p.': [['eI', 'w', 'aI', 'p', 'i']],
#  'a.z.': [['eI', 'z', 'i']],
#  'a.z.t.': [['eI', 'z', 'i', 't', 'i']],
#  'a.z.u.z.': [['eI', 'z', 'i', 'j', 'u', 'z', 'i']],
#  'a.z.z.': [['eI', 'z', 'i', 'z', 'i']],
#  'a1': [['eI', 'w', 'V', 'n']],
#  'aa': [['A'], ['{', 'A']],
#  'aaa': [['t', 'r', 'I', 'p', 'V', 'l', 'eI']],
#  'aaaa': [['A', 'A', 'A']],
#  'aaaaa': [['A', 'A'], ['E', 'V', 'V']],
#  'aaaaaaaargh': [['A', 'V', 'V', 'V', 'A', 'r', 'g']],
#  'aaah': [['A']],
#  'aaanthor': [['t', 'r', 'I', 'p', '@', 'l', 'eI', 'n', 'T', '@`']],
#  'aabar': [['A', 'b', 'A', 'r']],
#  'aac': [['V', 'k']],
#  'aace': [['A', 'tS', 'i']],
#  'aachen': [['A', 'k', '@', 'n'], ['A', 'k', 'V', 'n']],
#  'aad': [['A', 'd'], ['{', 'd']],
#  'aaden': [['A', 'd', 'V', 'n'], ['eI', 'd', 'V', 'n']],
#  'aadmi': [['A', 'd', 'm', 'i'], ['{', 'd', 'm', 'i']],
#  'aae': [['eI', 'eI']],
#  'aafa': [['A', 'f', 'V']],
#  'aafes': [['A', 'f', 's'], ['{', 'f', 's']],
#  'aafia': [['A', 'f', 'i', 'V']],
#  'aafp': [['A', 'f', 'p'], ['{', 'f', 'p']],
#  'aage': [['A', 'Z']],
#  "aage's": [['I', 'dZ', 'I', 'z']],
#  'aagot': [['A', 'g', '@', 't']],
#  "aagot's": [['A', 'g', '@', 't', 's']],
#  'aah': [['A']],
#  'aah-aah': [['A', 'A']],
#  'aahed': [['A', 't']],
#  'aahing': [['A', 'I', 'N']],
#  'aahmes': [['A', 'm', 'z']],
#  'aahs': [['A', 'z']],
#  'aai': [['A', 'aI'], ['A', 'i']],
#  'aaib': [['A', 'i', 'b'], ['{', 'eI', 'b']],
#  'aaim': [['{', 'eI', 'm']],
#  'aaj': [['A', 'dZ'], ['{']],
#  'aakash': [['A', 'k', 'A', 'S']],
#  'aakre': [['A', 'k', '3`'], ['A', 'k', '@`']],
#  'aal': [['A', 'l'], ['{', 'l']],
#  'aalbom': [['A', 'l', 'b', 'O', 'm']],
#  'aalborg': [['A', 'l', 'b', 'O', 'r', 'g'], ['{', 'l', 'b', 'O', 'r', 'g']],
#  'aaleh': [['{', 'l', 'V']],
#  'aaliyah': [['A', 'l', 'i', '@'],
#   ['V', 'l', 'i', 'V'],
#   ['{', 'l', 'I', 'j', 'V']],
#  'aalst': [['A', 'l', 's', 't']],
#  'aalto': [['A', 'l', 't', 'oU'], ['{', 'l', 't', 'oU']],
#  'aaltonen': [['{', 'l', 't', 'V', 'n', 'V', 'n']],
#  'aam': [['A', 'm'], ['{', 'm']],
#  'aamac': [['A', 'm', '{', 'k']],
#  'aamash': [['A', 'm', '{', 'S']],
#  'aamer': [['A', 'm', '3`'], ['eI', 'm', '3`']],
#  'aames': [['eI', 'm', 'z']],
#  'aamir': [['A', 'm', 'I', 'r'], ['V', 'm', 'I', 'r']],
#  'aamodt': [['A', 'm', 'V', 't']],
#  'aan': [['A', 'n'], ['{', 'n']],
#  'aana': [['A', 'n', '@']],
#  'aand': [['A', 'n', 'd'], ['{', 'n', 'd']],
#  'aandahl': [['A', 'n', 'd', 'A', 'l'], ['{', 'n', 'd', 'A', 'l']],
#  'aanensen': [['A', 'n', 'V', 'n', 's', 'V', 'n']],
#  'aanenson': [['A', 'n', 'V', 'n', 's', 'V', 'n']],
#  'aanti': [['{', 'n', 't', 'i']],
#  'aany': [['E', 'n', 'i']],
#  'aaos': [['A', 'oU', 'z'], ['eI', 'oU', 's']],
#  'aap': [['{', 'p']],
#  'aapd': [['{', 'p', 'd']],
#  'aapl': [['A', 'p', 'V', 'l'], ['{', 'p', 'l']],
#  'aar': [['A', 'r']],
#  'aaraaf': [['A', 'r', 'A', 'f']],
#  'aarabi': [['A', 'r', 'A', 'b', 'i'], ['{', 'A', 'b', 'i']],
#  'aaraji': [['A', 'r', 'A', 'i']],
#  'aarau': [['A', 'r', 'aU']],
#  'aard': [['A', 'r', 'd']],
#  'aardman': [['A', 'r', 'd', 'm', 'V', 'n']],
#  'aardonyx': [['A', 'r', 'd', 'A', 'n', 'I', 'k', 's'],
#   ['A', 'r', 'd', 'V', 'n', 'I', 'k', 's']],
#  'aardsma': [['A', 'r', 'd', 'z', 'm', 'V']],
#  'aardvark': [['A', 'r', 'd', 'v', 'A', 'r', 'k']],
#  'aardvarks': [['A', 'r', 'd', 'v', 'A', 'r', 'k', 's']],
#  'aardwolf': [['A', 'r', 'd', 'w', 'U', 'l', 'f']],
#  'aare': [['E', 'r']],
#  'aargh': [['A', 'r', 'g']],
#  "aargon's": [['A', 'r', 'g', 'A', 'n', 'z']],
#  'aarhus': [['A', 'r', '@', 'z'],
#   ['A', 'r', 'h', 'I', 's'],
#   ['A', 'r', 'h', 'U', 's']],
#  'aaron': [['E:', 'r', '@', 'n'],
#   ['E', 'r', '@', 'n'],
#   ['E', 'r', 'V', 'n'],
#   ['{', 'r', '@', 'n']],
#  "aaron's": [['E:', 'r', '@', 'n', 'z'], ['E', 'r', 'V', 'n', 'z']],
#  'aaronic': [['E:', 'r', '@', 'n', 'I', 'k']],
#  'aaronovitch': [['E', 'r', 'A', 'n', 'V', 'v', 'i', 'tS'],
#   ['E', 'r', 'V', 'n', 'oU', 'v', 'I', 'tS']],
#  'aarons': [['E:', 'r', '@', 'n', 'z'], ['E', 'r', 'V', 'n', 'z']],
#  'aaronsburg': [['E:', 'r', '@', 'n', 'z', 'b', '3`', 'g'],
#   ['{', 'r', '@', 'n', 'z', 'b', '3`', 'g']],
#  'aaronson': [['A', 'r', '@', 'n', 's', '@', 'n'],
#   ['A', 'r', 'V', 'n', 's', 'V', 'n'],
#   ['E:', 'r', '@', 'n', 's', '@', 'n'],
#   ['E', 'r', 'V', 'n', 's', 'V', 'n']],
#  'aarp': [['A', 'r', 'p']],
#  'aarti': [['A', 'r', 't', 'i']],
#  'aartsen': [['A', 'r', 't', 's', 'V', 'n']],
#  'aas': [['A', 's'], ['{', 'z']],
#  'aasa': [['A', 's', '@']],
#  'aasan': [['A', 's', 'A', 'n']],
#  'aase': [['A', 's']],
#  'aasha': [['A', 'S', 'V']],
#  'aasiya': [['A', 's', 'i', 'V'], ['V', 's', 'i', 'j', 'V']],
#  'aasld': [['A', 's', 'l', 'd']],
#  'aasvogel': [['A', 'z', 'v', 'oU', 'g', '@', 'l']],
#  'aasvogels': [['A', 'z', 'v', 'oU', 'g', '@', 'l', 'z']],
#  'aat': [['A', 't']],
#  'aatcagggaccc': [['{', 't', 'k', '{', 'g', 'A', 'k']],
#  'aau': [['A', 'u'], ['oU']],
#  'aav': [['{', 'v']],
#  'aaviksoo': [['A', 'v', 'I', 'k', 's', 'u']],
#  'ab': [['eI', 'b', 'i'], ['{', 'b']],
#  "ab's": [['{', 'b', 'z']],
#  'ab-': [['@', 'b'], ['eI', 'b'], ['{', 'b']],
#  'aba': [['A', 'b', '@'], ['A', 'b', 'V'], ['{', 'b', 'V']],
#  'abaat': [['@', 'b', 'A', 't']],
#  "abab'deh": [['@', 'b', 'A', 'b', 'd', '@']],
#  'ababa': [['@', 'b', 'A', 'b', '@'],
#   ['A', 'b', '@', 'b', '@'],
#   ['A', 'b', 'V', 'b', 'V'],
#   ['V', 'b', 'A', 'b', 'V']],
#  'ababde': [['A', 'b', '@', 'b', 'd']],
#  'ababdeh': [['@', 'b', '{', 'b', 'd', 'E']],
#  'abaca': [['{', 'b', '@', 'k', '@']],
#  'abacavir': [['{', 'b', 'V', 'k', 'V', 'v', 'I', 'r']],
#  'abacazanian': [['{', 'b', '{', 'k', 'A', 'z', '{', 'n', 'i', 'V', 'n']],
#  'abacha': [['{', 'b', 'V', 'k', 'V']],
#  'aback': [['@', 'b', '{', 'k'], ['V', 'b', '{', 'k']],
#  'abaco': [['{', 'b', '@', 'k', 'oU'], ['{', 'b', 'V', 'k', 'oU']],
#  'abacus': [['{', 'b', '@', 'k', '@', 's'], ['{', 'b', 'V', 'k', 'V', 's']],
#  'abacuses': [['{', 'b', 'V', 'k', 'V', 's', 'I', 'z']],
#  'abad': [['@', 'b', 'A', 'd'], ['V', 'b', 'A', 'd']],
#  'abadan': [['@', 'b', '{', 'd', '@', 'n'],
#   ['V', 'b', 'A', 'd', 'V', 'n'],
#   ['V', 'b', '{', 'd', 'V', 'n']],
#  'abaddon': [['@', 'b', '{', 'd', '@', 'n'], ['V', 'b', '{', 'd', 'V', 'n']],
#  'abadgaran': [['V', 'b', '{', 'd', 'dZ', 'A', 'r', 'V', 'n']],
#  'abadi': [['V', 'b', 'A', 'd', 'i'], ['V', 'b', '{', 'd', 'i']],
#  'abadia': [['V', 'b', 'eI', 'd', 'i', 'V']],
#  'abadie': [['V', 'b', '{', 'd', 'i']],
#  'abaft': [['@', 'b', '{', 'f', 't']],
#  'abaga': [['V', 'b', 'A', 'g', 'V']],
#  'abagnale': [['V', 'b', 'A', 'g', 'n', 'A', 'l', 'i']],
#  'abaht': [['@', 'b', 'A', 't']],
#  'abaire': [['V', 'b', 'E', 'r']],
#  'abajo': [['{', 'b', '@', 'dZ', 'oU']],
#  'abakan': [['V', 'b', 'eI', 'k', 'V', 'n']],
#  'abalon': [['{', 'b', '@', 'l', 'A', 'n']],
#  'abalone': [['{', 'b', '@', 'l', 'oU', 'n'],
#   ['{', 'b', '@', 'l', 'oU', 'n', 'i'],
#   ['{', 'b', 'V', 'l', 'oU', 'n', 'i']],
#  'abalones': [['{', 'b', '@', 'l', 'oU', 'n', 'z']],
#  'abalos': [['A', 'b', 'A', 'l', 'oU', 'z']],
#  'abana': [['@', 'b', '{', 'n', '@']],
#  'abanazar': [['@', 'b', '{', 'n', 'A', 'z', 'A', 'r']],
#  'aband': [['V', 'b', 'V', 'n', 'd']],
#  'abandon': [['@', 'b', '{', 'n', 'd', '@', 'n'],
#   ['V', 'b', '{', 'n', 'd', 'V', 'n']],
#  "abandon'd": [['@', 'b', '{', 'n', 'd', '@', 'n', 'd']],
#  'abandoned': [['@', 'b', '{', 'n', 'd', '@', 'n', 'd'],
#   ['V', 'b', '{', 'n', 'd', 'V', 'n', 'd']],
#  'abandonedly': [['@', 'b', '{', 'n', 'd', '@', 'n', 'd', 'l', 'i']],
#  'abandoning': [['@', 'b', '{', 'n', 'd', '@', 'n', 'I', 'N'],
#   ['V', 'b', '{', 'n', 'd', 'V', 'n', 'I', 'N']],
#  'abandonment': [['@', 'b', '{', 'n', 'd', '@', 'n', 'm', '@', 'n', 't'],
#   ['@', 'b', '{', 'n', 'd', '@', 'n', 'm', 'E', 'n', 't'],
#   ['V', 'b', '{', 'n', 'd', 'V', 'n', 'm', 'V', 'n', 't']],
#  'abandonments': [['@', 'b', '{', 'n', 'd', '@', 'n', 'm', '@', 'n', 't', 's'],
#   ['V', 'b', '{', 'n', 'd', 'V', 'n', 'm', 'V', 'n', 't', 's']],
#  'abandons': [['@', 'b', '{', 'n', 'd', '@', 'n', 'z'],
#   ['V', 'b', '{', 'n', 'd', 'V', 'n', 'z']],
#  'abani': [['V', 'b', 'A', 'n', 'i']],
#  'abaout': [['@', 'b', 'eI', 'aU', 't']],
#  'abara': [['@', 'b', 'A', 'r', '@']],
#  'abarak': [['@', 'b', 'A', 'r', '@', 'k']],
#  'abaria': [['A', 'b', 'A', 'r', 'i', '@']],
#  'abarian': [['@', 'b', 'E:', 'r', 'i', '@', 'n']],
#  'abarians': [['@', 'b', 'E:', 'r', 'i', '@', 'n', 'z']],
#  'abaris': [['A', 'b', 'A', 'r', 'i', 'z']],
#  'abart': [['@', 'b', 'A', 'r', 't']],
#  'abarth': [['V', 'b', 'A', 'r', 'T']],
#  'abas': [['V', 'b', '{', 's'], ['{', 'b', '@', 's'], ['{', 'b', 'V', 's']],
#  'abase': [['@', 'b', 'eI', 's'], ['V', 'b', 'eI', 's']],
#  'abased': [['@', 'b', 'eI', 's', 't']],
#  'abasement': [['@', 'b', 'eI', 's', 'm', '@', 'n', 't'],
#   ['V', 'b', 'V', 's', 'm', 'V', 'n', 't'],
#   ['V', 'b', 'eI', 's', 'm', 'V', 'n', 't']],
#  'abases': [['@', 'b', 'eI', 's', 'I', 'z']],
#  'abash': [['@', 'b', '{', 'S'], ['V', 'b', '{', 'S']],
#  "abash'd": [['@', 'b', '{', 'S', 'd']],
#  'abashed': [['@', 'b', '{', 'S', 't'], ['V', 'b', '{', 'S', 't']],
#  'abashedly': [['V', 'b', '{', 'S', 'V', 'd', 'l', 'i']],
#  'abashes': [['@', 'b', '{', 'S', 'I', 'z']],
#  'abashing': [['@', 'b', '{', 'S', 'I', 'N']],
#  'abashment': [['@', 'b', '{', 'S', 'm', '@', 'n', 't']],
#  'abasing': [['@', 'b', 'eI', 's', 'I', 'N']],
#  'abassi': [['V', 'b', 'V', 's', 'i'], ['V', 'b', '{', 's', 'i']],
#  'abatagati': [['@', 'b', 'eI', '4', '@', 'g', 'A', '4', 'i']],
#  'abate': [['@', 'b', 'eI', 't'], ['V', 'b', 'eI', 't']],
#  'abated': [['@', 'b', 'eI', '4', 'I', 'd'], ['V', 'b', 'eI', 't', 'I', 'd']],
#  'abatement': [['@', 'b', 'eI', 't', 'm', '@', 'n', 't'],
#   ['V', 'b', 'eI', 't', 'm', 'V', 'n', 't']],
#  'abatements': [['@', 'b', 'eI', 't', 'm', '@', 'n', 't', 's'],
#   ['V', 'b', 'eI', 't', 'm', 'V', 'n', 't', 's']],
#  'abates': [['@', 'b', 'eI', 't', 's'], ['V', 'b', 'eI', 't', 's']],
#  'abati': [['@', 'b', 'A', '4', 'i']],
#  'abating': [['@', 'b', 'eI', '4', 'I', 'N'], ['V', 'b', 'eI', 't', 'I', 'N']],
#  'abatis': [['@', 'b', 'eI', '4', 'I', 's']],
#  'abatte': [['V', 'b', '{', 't']],
#  'abattis': [['@', 'b', '{', '4', 'I', 's']],
#  'abattoir': [['@', 'b', '{', 't', 'w', 'A', 'r'],
#   ['V', 'b', 'A', 't', 'w', 'A', 'r'],
#   ['V', 'b', '{', 't', 'w', 'A', 'r']],
#  'abattoirs': [['@', 'b', '{', 't', 'w', 'A', 'r', 'z'],
#   ['V', 'b', 'A', 't', 'w', 'A', 'r', 'z'],
#   ['V', 'b', '{', 't', 'w', 'A', 'r', 'z']],
#  'abaurrea': [['V', 'b', 'A', '3`', 'i', 'V']],
#  'abawi': [['V', 'b', 'A', 'w', 'i']],
#  'abaya': [['A', 'b', 'A', 'j', 'V'], ['V', 'b', 'A', 'j', 'V']],
#  'abayas': [['V', 'b', 'A', 'aI', 'V', 's'], ['V', 'b', 'aI', 'V', 's']],
#  'abayomi': [['V', 'b', 'eI', 'oU', 'm', 'i']],
#  'abb': [['{', 'b']],
#  "abb's": [['A', 'b', 'z']],
#  'abba': [['{', 'b', '@'], ['{', 'b', 'V']],
#  "abba's": [['{', 'b', 'V', 'z']],
#  'abbacy': [['{', 'b', '@', 's', 'i']],
#  'abbad': [['@', 'b', 'A', 'd']],
#  'abbado': [['V', 'b', 'A', 'd', 'oU']],
#  'abban': [['@', 'b', 'A', 'n']],
#  'abbas': [['@', 'b', 'A', 's'], ['V', 'b', 'A', 's']],
#  "abbas's": [['V', 'b', 'A', 's', 'I', 'z']],
#  'abbasali': [['V', 'b', 'A', 's', 'A', 'l', 'i'],
#   ['V', 'b', '{', 's', 'A', 'l', 'i']],
#  'abbasgholizadeh': [['V',
#    'b',
#    'A',
#    's',
#    'g',
#    'h',
#    'O',
#    'l',
#    'I',
#    'z',
#    'A',
#    'd',
#    'E']],
#  'abbasi': [['A', 'b', 'A', 's', 'i']],
#  'abbasid': [['A', 'b', 'A', 's', 'i', 'd']],
#  'abbasids': [['@', 'b', 'A', 's', 'I', 'd', 'z']],
#  'abbass': [['V', 'b', '{', 's']],
#  'abbassi': [['V', 'b', 'A', 's', 'i']],
#  'abbat': [['@', 'b', '{', 't']],
#  "abbat's": [['A', 'b', 'A', 't', 's']],
#  'abbate': [['A', 'b', 'eI', 't']],
#  'abbati': [['@', 'b', 'A', '4', 'i']],
#  'abbatial': [['A', 'b', 'A', '4', 'i', '@', 'l']],
#  'abbaworld': [['V', 'b', 'V', 'w', 'l', 'd']],
#  'abbaye': [['A', 'b', 'eI']],
#  'abbazia': [['@', 'b', 'A', 'z', 'i', '@']],
#  'abbe': [['{', 'b', 'eI'], ['{', 'b', 'i']],
#  "abbe's": [['{', 'b', 'i', 'z']],
#  'abbeel': [['{', 'b', 'i', 'l']],
#  'abbeokuta': [['{', 'b', 'i', 'A', 'k', 'u', '4', '@']],
#  'abbes': [['{', 'b', 'i', 'z']],
#  'abbess': [['@', 'b', 'E', 's'], ['V', 'b', 'E', 's'], ['{', 'b', 'I', 's']],
#  "abbess's": [['{', 'b', '@', 's', 'I', 'z']],
#  'abbesses': [['@', 'b', 'E', 's', '@', 'z']],
#  'abbeville': [['{', 'b', 'v', 'I', 'l']],
#  'abbeway': [['{', 'b', 'w', 'eI']],
#  'abbey': [['{', 'b', 'i']],
#  "abbey's": [['{', 'b', 'i', 'z']],
#  'abbeydale': [['{', 'b', 'd', 'eI', 'l'], ['{', 'b', 'eI', 'd', 'eI', 'l']],
#  'abbeyfield': [['{', 'b', 'f', 'i', 'l', 'd'],
#   ['{', 'b', 'i', 'f', 'i', 'l', 'd']],
#  'abbeys': [['{', 'b', 'eI', 'z'], ['{', 'b', 'i', 'z']],
#  'abbeytown': [['{', 'b', 'i', 't', 'aU', 'n']],
#  'abbi': [['{', 'b', 'i']],
#  'abbia': [['{', 'b', 'i', '@']],
#  'abbiati': [['{', 'b', 'i', 'A', 't', 'i']],
#  'abbie': [['{', 'b', 'i']],
#  "abbie's": [['{', 'b', 'i', 'z']],
#  'abbitibbi': [['{', 'b', 'I', '4', 'I', 'b', 'i']],
#  'abbot': [['{', 'b', '@', 't'], ['{', 'b', 'V', 't']],
#  "abbot's": [['{', 'b', '@', 't', 's']],
#  'abbots': [['{', 'b', '@', 't', 's'], ['{', 'b', 'V', 't', 's']],
#  'abbotsbury': [['{', 'b', 'V', 't', 's', 'b', 'E', 'r', 'i']],
#  'abbotscliff': [['{', 'b', '@', 't', 's', 'k', 'l', 'I', 'f']],
#  'abbotsford': [['{', 'b', '@', 't', 's', 'f', '@`', 'd'],
#   ['{', 'b', 'V', 't', 's', 'f', '3`', 'd']],
#  'abbotsmead': [['{', 'b', '@', 't', 's', 'm', 'i', 'd']],
#  'abbotsworthy': [['{', 'b', '@', 't', 's', 'w', '@`', 'D', 'i']],
#  'abbott': [['{', 'b', '@', 't'], ['{', 'b', 'V', 't']],
#  "abbott's": [['{', 'b', '@', 't', 's'], ['{', 'b', 'V', 't', 's']],
#  'abbottabad': [['{', 'b', 'V', 't', 'A', 'b', '{', 'd']],
#  'abbotts': [['{', 'b', '@', 't', 's'], ['{', 'b', 'V', 't', 's']],
#  'abboud': [['V', 'b', 'aU', 'd'], ['V', 'b', 'u', 'd']],
#  'abbr': [['V', 'b', 'r']],
#  'abbreviate': [['@', 'b', 'r', 'i', 'v', 'i', '@', 't'],
#   ['@', 'b', 'r', 'i', 'v', 'i', 'eI', 't'],
#   ['V', 'b', 'r', 'i', 'v', 'i', 'eI', 't']],
#  'abbreviated': [['@', 'b', 'r', 'i', 'v', 'i', 'eI', '4', '@', 'd'],
#   ['@', 'b', 'r', 'i', 'v', 'i', 'eI', '4', 'I', 'd'],
#   ['@', 'b', 'r', 'i', 'v', 'i', 'eI', 't', 'I', 'd'],
#   ['V', 'b', 'r', 'i', 'v', 'i', 'eI', 't', 'I', 'd'],
#   ['V', 'b', 'r', 'i', 'v', 'i', 'eI', 't', 'V', 'd']],
#  'abbreviates': [['V', 'b', 'r', 'i', 'v', 'i', 'eI', 't', 's']],
#  'abbreviating': [['@', 'b', 'r', 'i', 'v', 'i', 'eI', '4', 'I', 'N'],
#   ['V', 'b', 'r', 'i', 'v', 'i', 'eI', 't', 'I', 'N']],
#  'abbreviation': [['@', 'b', 'r', 'i', 'v', 'i', 'eI', 'S', '@', 'n'],
#   ['V', 'b', 'r', 'i', 'v', 'i', 'eI', 'S', 'V', 'n']],
#  'abbreviations': [['@', 'b', 'r', 'i', 'v', 'i', 'eI', 'S', '@', 'n', 'z'],
#   ['V', 'b', 'r', 'i', 'v', 'i', 'eI', 'S', 'V', 'n', 'z']],
#  'abbruzzese': [['A', 'b', 'r', 'u', 't', 's', 'eI', 'z', 'i']],
#  'abbs': [['{', 'b', 'z']],
#  'abbut': [['A', 'b', '@', 't']],
#  'abby': [['{', 'b', 'i']],
#  "abby's": [['{', 'b', 'i', 'z']],
#  'abc': [['{', 'b', 'k']],
#  'abchester': [['{', 'b', 'tS', 'E', 's', 't', '@`']],
#  'abchurch': [['{', 'b', 'tS', '3`', 'tS']],
#  'abcnews': [['V', 'b', 'k', 'n', 'u', 'z']],
#  'abcp': [['{', 'b', 'k', 'p']],
#  'abcs': [['V', 'b', 'k', 's'], ['i', 'b', 'i', 's', 'i', 'z']],
#  'abd': [['{', 'b', 'd']],
#  'abdal': [['{', 'b', 'd', 'V', 'l'], ['{', 'b', 'd', '{', 'l']],
#  'abdala': [['{', 'b', 'd', 'A', 'l', 'V']],
#  'abdalhaleem': [['{', 'b', 'd', '{', 'l', 'h', 'V', 'l', 'i', 'm']],
#  'abdalla': [['{', 'b', 'd', '{', 'l', '@'], ['{', 'b', 'd', '{', 'l', 'V']],
#  'abdallah': [['{', 'b', 'd', '{', 'l', '@'], ['{', 'b', 'd', '{', 'l', 'V']],
#  "abdallah's": [['{', 'b', 'd', '{', 'l', '@', 'z']],
#  'abdallahi': [['{', 'b', 'd', '{', 'l', 'A', 'h', 'i'],
#   ['{', 'b', 'd', '{', 'l', 'V', 'h', 'i']],
#  'abdalmahmood': [['{', 'b', 'd', '{', 'l', 'm', '{', 'm', 'u', 'd']],
#  'abdalonim': [['{', 'b', 'd', '{', 'l', 'oU', 'n', 'i', 'm']],
#  'abdc': [['{', 'b', 'd', 'k']],
#  'abdel': [['{', 'b', 'd', 'E', 'l']],
#  'abdel-hakim': [['{', 'b', 'd', 'E', 'l', 'A', 'k', 'i', 'm']],
#  'abdel-karim': [['{', 'b', 'd', 'E', 'l', 'k', '3`', 'i', 'm']],
#  'abdel-nasser': [['{', 'b', 'd', 'E', 'l', 'n', '{', 's', '3`']],
#  'abdel-rahim': [['{', 'b', 'd', 'E', 'l', 'r', 'V', 'h', 'i', 'm']],
#  'abdel-rahman': [['{', 'b', 'd', 'E', 'l', 'r', 'A', 'm', 'V', 'n']],
#  'abdelal': [['{', 'b', 'd', 'I', 'l', 'V', 'l']],
#  'abdelaziz': [['{', 'b', 'd', 'E', 'l', '@', 'z', 'i', 'z'],
#   ['{', 'b', 'd', 'E', 'l', 'V', 'z', 'i', 'z'],
#   ['{', 'b', 'd', 'I', 'l', 'V', 'z', 'I', 'z']],
#  'abdelbaset': [['{', 'b', 'd', 'E', 'l', 'b', 'V', 's', 'E', 't'],
#   ['{', 'b', 'd', 'I', 'l', 'b', 'V', 'z', 'E', 't']],
#  'abdelbasset': [['{', 'b', 'd', 'I', 'l', 'b', 'V', 's', 'V', 't']],
#  'abdelbeset': [['{', 'b', 'd', 'V', 'l', 'b', 's', 'E', 't']],
#  'abdelhadi': [['{', 'b', 'd', 'E', 'l', 'V', 'd', 'i']],
#  'abdelkader': [['{', 'b', 'd', 'E', 'l', 'k', 'V', 'd', '3`'],
#   ['{', 'b', 'd', 'E', 'l', 'k', 'eI', 'd', '3`']],
#  'abdellah': [['{', 'b', 'd', 'E', 'l', 'V']],
#  'abdellatif': [['{', 'b', 'd', 'E', 'l', 'A', 't', 'i', 'f']],
#  'abdelmalek': [['{', 'b', 'd', 'E', 'l', 'm', 'A', 'l', 'E', 'k'],
#   ['{', 'b', 'd', 'V', 'l', 'm', 'A', 'l', 'E', 'k']],
#  'abdelrahman': [['{', 'b', 'd', 'I', 'l', 'r', 'A', 'm', 'V', 'n']],
#  'abdelrazik': [['{', 'b', 'd', 'E', 'l', 'r', 'V', 'z', 'I', 'k']],
#  'abdelsalam': [['{', 'b', 'd', 'V', 'l', 's', 'V', 'l', 'V', 'm']],
#  'abdennour': [['{', 'b', 'd', 'E', 'n', '3`', 'r']],
#  'abdera': [['{', 'b', 'd', 'E:', 'r', '@']],
#  'abderrahim': [['{', 'b', 'd', 'E', 'r', 'V', 'h', 'I', 'm']],
#  'abderrahman': [['{', 'b', 'd', 'E:', 'r', 'A', 'm', '@', 'n']],
#  'abderrahmane': [['{', 'b', 'd', 'E', 'r', 'V', 'm', 'V', 'n']],
#  'abdi': [['{', 'b', 'd', 'i']],
#  "abdi's": [['{', 'b', 'd', 'i', 'z']],
#  'abdias': [['{', 'b', 'd', 'i', '@', 'z']],
#  'abdicate': [['{', 'b', 'd', '@', 'k', 'eI', 't'],
#   ['{', 'b', 'd', 'V', 'k', 'eI', 't']],
#  'abdicated': [['{', 'b', 'd', '@', 'k', 'eI', '4', '@', 'd'],
#   ['{', 'b', 'd', 'V', 'k', 'eI', 't', 'V', 'd']],
#  'abdicates': [['{', 'b', 'd', '@', 'k', 'eI', 't', 's'],
#   ['{', 'b', 'd', 'V', 'k', 'eI', 't', 's']],
#  'abdicating': [['{', 'b', 'd', 'I', 'k', 'eI', '4', 'I', 'N'],
#   ['{', 'b', 'd', 'I', 'k', 'eI', 't', 'I', 'N']],
#  'abdication': [['{', 'b', 'd', 'I', 'k', 'eI', 'S', '@', 'n'],
#   ['{', 'b', 'd', 'I', 'k', 'eI', 'S', 'V', 'n']],
#  'abdiel': [['{', 'b', 'd', 'i', 'l']],
#  'abdifatah': [['{', 'b', 'd', 'V', 'f', 'V', 't', 'V']],
#  'abdillahi': [['{', 'b', 'd', 'I', 'l', 'V', 'h', 'i']],
#  'abdin': [['{', 'b', 'd', '@', 'n'], ['{', 'b', 'd', 'V', 'n']],
#  'abdinur': [['{', 'b', 'd', 'V', 'n']],
#  'abdiqadir': [['{', 'b', 'd', 'I', 'k', 'V', 'd', 'I', 'r']],
#  'abdirahman': [['{', 'b', 'd', 'I', 'r', 'A', 'm', 'V', 'n'],
#   ['{', 'b', 'd', 'I', 'r', 'V', 'm', 'V', 'n']],
#  'abdirashid': [['{', 'b', 'd', 'i', 'r', 'A', 'S', 'V', 'd']],
#  'abdirizak': [['{', 'b', 'd', 'I', 'r', 'I', 'z', '{', 'k']],
#  'abdiwali': [['{', 'b', 'd', 'V', 'w', 'A', 'l', 'i']],
#  'abdo': [['{', 'b', 'd', 'oU']],
#  'abdolfattah': [['{', 'b', 'd', 'A', 'f', 'A', 't', 'A'],
#   ['{', 'b', 'd', 'A', 'l', 'f', 'A', 't', 'V']],
#  'abdolhossein': [['{', 'b', 'd', 'A', 'l', 'h', 'oU', 's', 'aI', 'n']],
#  'abdollah': [['{', 'b', 'd', 'A', 'l', 'V']],
#  'abdolmalek': [['{', 'b', 'd', 'A', 'l', 'm', 'A', 'l', 'E', 'k']],
#  'abdolsamad': [['{', 'b', 'd', 'A', 'l', 's', 'V', 'm', 'V', 'd'],
#   ['{', 'b', 'd', 'oU', 'l', 's', 'A', 'm', 'V', 'd']],
#  'abdom': [['{', 'b', 'd', 'V', 'm']],
#  'abdomen': [['{', 'b', 'd', '@', 'm', '@', 'n'],
#   ['{', 'b', 'd', 'V', 'm', 'V', 'n'],
#   ['{', 'b', 'd', 'oU', 'm', '@', 'n'],
#   ['{', 'b', 'd', 'oU', 'm', 'V', 'n']],
#  'abdomens': [['{', 'b', 'd', 'V', 'm', 'V', 'n', 'z'],
#   ['{', 'b', 'd', 'oU', 'm', '@', 'n', 'z'],
#   ['{', 'b', 'd', 'oU', 'm', 'V', 'n', 'z']],
#  'abdominal': [['@', 'b', 'd', 'A', 'm', '@', 'n', '@', 'l'],
#   ['@', 'b', 'd', 'A', 'm', 'I', 'n', '@', 'l'],
#   ['V', 'b', 'd', 'A', 'm', 'V', 'n', 'V', 'l'],
#   ['{', 'b', 'd', 'A', 'm', '@', 'n', '@', 'l'],
#   ['{', 'b', 'd', 'A', 'm', 'V', 'n', 'V', 'l']],
#  'abdominals': [['V', 'b', 'd', 'A', 'm', 'V', 'n', 'V', 'l', 'z'],
#   ['{', 'b', 'd', 'A', 'm', 'I', 'n', '@', 'l', 'z'],
#   ['{', 'b', 'd', 'A', 'm', 'V', 'n', 'V', 'l', 'z']],
#  'abdominoplasty': [['{',
#    'b',
#    'd',
#    'A',
#    'm',
#    'V',
#    'n',
#    'oU',
#    'p',
#    'l',
#    '{',
#    's',
#    't',
#    'i']],
#  'abdon': [['{', 'b', 'd', '@', 'n']],
#  'abdool': [['{', 'b', 'd', 'u', 'l']],
#  'abdoolah': [['{', 'b', 'd', 'u', 'l', '@']],
#  'abdou': [['{', 'b', 'd', 'u']],
#  'abdoulaye': [['{', 'b', 'd', 'l', 'eI'], ['{', 'b', 'd', 'u', 'l', 'eI']],
#  'abdoulie': [['{', 'b', 'd', 'l', 'i']],
#  'abdslem': [['{', 'b', 'd', 'z', 'l', '@', 'm']],
#  'abdu': [['{', 'b', 'd', 'u']],
#  "abdu'l": [['{', 'b', 'd', 'u', '@', 'l']],
#  'abduct': [['@', 'b', 'd', 'V', 'k', 't'], ['{', 'b', 'd', 'V', 'k', 't']],
#  'abducted': [['@', 'b', 'd', 'V', 'k', 't', 'I', 'd'],
#   ['V', 'b', 'd', 'V', 'k', 't', 'I', 'd'],
#   ['{', 'b', 'd', 'V', 'k', 't', 'I', 'd']],
#  'abductee': [['{', 'b', 'd', 'V', 'k', 't', 'i']],
#  'abductees': [['{', 'b', 'd', 'V', 'k', 't', 'i', 'z']],
#  'abducting': [['@', 'b', 'd', 'V', 'k', 't', 'I', 'N'],
#   ['V', 'b', 'd', 'V', 'k', 't', 'I', 'N'],
#   ['{', 'b', 'd', 'V', 'k', 't', 'I', 'N']],
#  'abduction': [['@', 'b', 'd', 'V', 'k', 'S', '@', 'n'],
#   ['V', 'b', 'd', 'V', 'k', 'S', 'V', 'n'],
#   ['{', 'b', 'd', 'V', 'k', 'S', '@', 'n'],
#   ['{', 'b', 'd', 'V', 'k', 'S', 'V', 'n']],
#  'abductions': [['@', 'b', 'd', 'V', 'k', 'S', '@', 'n', 'z'],
#   ['V', 'b', 'd', 'V', 'k', 'S', 'V', 'n', 'z'],
#   ['{', 'b', 'd', 'V', 'k', 'S', '@', 'n', 'z'],
#   ['{', 'b', 'd', 'V', 'k', 'S', 'V', 'n', 'z']],
#  'abductor': [['@', 'b', 'd', 'V', 'k', 't', '@`'],
#   ['V', 'b', 'd', 'V', 'k', 't', '3`'],
#   ['{', 'b', 'd', 'V', 'k', 't', '3`'],
#   ['{', 'b', 'd', 'V', 'k', 't', '@`']],
#  'abductors': [['@', 'b', 'd', 'V', 'k', 't', '@`', 'z'],
#   ['V', 'b', 'd', 'V', 'k', 't', '3`', 'z'],
#   ['{', 'b', 'd', 'V', 'k', 't', '3`', 'z'],
#   ['{', 'b', 'd', 'V', 'k', 't', '@`', 'z']],
#  'abducts': [['{', 'b', 'd', 'V', 'k', 't', 's']],
#  'abduh': [['{', 'b', 'd', 'V'], ['{', 'b', 'd', 'u']],
#  'abduhl': [['{', 'b', 'd', 'V', 'l']],
#  'abdukhadir': [['{', 'b', 'd', 'u', 'k', 'h', 'V', 'd', 'I', 'r']],
#  'abdul': [['{', 'b', 'd', 'U', 'l'], ['{', 'b', 'd', 'u', 'l']],
#  "abdul's": [['{', 'b', 'd', 'u', 'l', 'z']],
#  'abdul-aziz': [['{', 'b', 'd', 'u', 'l', 'V', 'z', 'i', 'z']],
#  'abdul-ghani': [['{', 'b', 'd', 'u', 'l', 'g', 'A', 'n', 'i']],
#  'abdul-hamid': [['{', 'b', 'd', 'u', 'l', 'h', 'V', 'm', 'i', 'd']],
#  'abdul-jabbar': [['{', 'b', 'd', 'u', 'l', 'dZ', 'V', 'b', 'A', 'r']],
#  'abdul-karim': [['{', 'b', 'd', 'u', 'l', 'k', '3`', 'i', 'm']],
#  'abdul-malik': [['{', 'b', 'd', 'u', 'l', 'm', '{', 'l', 'I', 'k']],
#  'abdul-qadir': [['{', 'b', 'd', 'u', 'l', 'k', 'eI', 'd', '3`']],
#  'abdul-rahman': [['{', 'b', 'd', 'u', 'l', 'r', 'A', 'm', 'V', 'n']],
#  'abdul-salam': [['{', 'b', 'd', 'u', 'l', 's', 'A', 'l', 'A', 'm']],
#  'abdulahi': [['{', 'b', 'd', 'V', 'l', 'A', 'h', 'i'],
#   ['{', 'b', 'd', 'u', 'l', 'A', 'h', 'i']],
#  'abdulaziz': [['{', 'b', 'd', 'u', 'l', 'V', 'z', 'i', 'z']],
#  'abdulhak': [['{', 'b', 'd', 'u', 'l', 'h', 'V', 'k']],
#  'abdulhakim': [['{', 'b', 'd', 'u', 'l', 'h', 'A', 'k', 'i', 'm']],
#  'abdulhamid': [['{', 'b', 'd', 'u', 'l', 'h', 'V', 'm', 'I', 'd'],
#   ['{', 'b', 'd', 'u', 'l', 'h', 'V', 'm', 'i', 'd']],
#  'abdulhamit': [['{', 'b', 'd', 'u', 'l', 'h', 'V', 'm', 'I', 't']],
#  'abdulkader': [['{', 'b', 'd', 'u', 'l', 'k', 'eI', 'd', '@`']],
#  'abdulkadir': [['{', 'b', 'd', 'V', 'l', 'k', 'A', 'd', 'I', 'r'],
#   ['{', 'b', 'd', 'u', 'l', 'k', 'V', 'd', '3`']],
#  'abdulkarim': [['{', 'b', 'd', 'V', 'l', 'k', '3`', 'r', 'I', 'm'],
#   ['{', 'b', 'd', 'u', 'l', 'k', '3`', 'i', 'm']],
#  'abdulla': [['A', 'b', 'd', 'u', 'l', '@'], ['A', 'b', 'd', 'u', 'l', 'V']],
#  "abdulla's": [['A', 'b', 'd', 'u', 'l', '@', 'z']],
#  'abdullah': [['{', 'b', 'd', 'V', 'l', '@'], ['{', 'b', 'd', 'V', 'l', 'V']],
#  "abdullah's": [['{', 'b', 'd', 'V', 'l', '@', 'z'],
#   ['{', 'b', 'd', 'V', 'l', 'V', 'z']],
#  'abdullahi': [['{', 'b', 'd', 'U', 'l', 'A', 'h', 'i'],
#   ['{', 'b', 'd', 'V', 'l', 'A', 'h', 'i'],
#   ['{', 'b', 'd', 'V', 'l', 'V', 'h', 'i']],
#  'abdullahu': [['{', 'b', 'd', 'U', 'l', 'A', 'h', 'u']],
#  'abdullayev': [['{', 'b', 'd', 'U', 'l', 'aI', 'V', 'v'],
#   ['{', 'b', 'd', 'V', 'l', 'aI', 'E', 'v']],
#  'abdullayeva': [['{', 'b', 'd', 'U', 'l', 'aI', 'E', 'v', 'V']],
#  'abdulle': [['{', 'b', 'd', 'V', 'l']],
#  'abdulmalik': [['{', 'b', 'd', 'V', 'l', 'm', 'A', 'l', 'I', 'k'],
#   ['{', 'b', 'd', 'u', 'l', 'm', 'A', 'l', 'I', 'k']],
#  'abdulmutallab': [['{',
#    'b',
#    'd',
#    'V',
#    'l',
#    'm',
#    'j',
#    'u',
#    't',
#    '{',
#    'l',
#    '{',
#    'b'],
#   ['{', 'b', 'd', 'u', 'l', 'm', 'u', 't', 'V', 'l', '{', 'b']],
#  'abdulmuttalab': [['{',
#    'b',
#    'd',
#    'V',
#    'l',
#    'm',
#    'V',
#    't',
#    'eI',
#    'l',
#    '{',
#    'b']],
#  'abdulqader': [['{', 'b', 'd', 'V', 'l', 'k', 'V', 'd', '3`']],
#  'abdulqadir': [['{', 'b', 'd', 'V', 'l', 'k', 'A', 'd', 'I', 'r'],
#   ['{', 'b', 'd', 'u', 'l', 'k', 'eI', 'd', '3`']],
#  'abdulrahim': [['{', 'b', 'd', 'j', 'u', 'l', 'r', 'A', 'h', 'I', 'm']],
#  'abdulrahman': [['{', 'b', 'd', 'j', 'u', 'l', 'r', 'A', 'm', 'V', 'n'],
#   ['{', 'b', 'd', 'u', 'l', 'r', 'A', 'm', 'V', 'n']],
#  'abdulrazak': [['{', 'b', 'd', 'u', 'l', 'r', 'A', 'z', 'V', 'k']],
#  'abdulwahab': [['{', 'b', 'd', 'u', 'l', 'w', 'eI', 'h', '{', 'b']],
#  'abdulzai': [['{', 'b', 'd', 'V', 'l', 't', 's', 'aI']],
#  'abdur': [['{', 'b', 'd', '3`'], ['{', 'b', 'd', '@`']],
#  'abdur-rahim': [['{', 'b', 'd', '3`', 'r', 'V', 'h', 'i', 'm']],
#  'abdurahman': [['{', 'b', 'd', 'U', 'V', 'm', 'V', 'n'],
#   ['{', 'b', 'd', 'U', 'r', 'A', 'm', 'V', 'n']],
#  'abdurajak': [['{', 'b', 'd', 'U', 'V', 'dZ', 'V', 'k']],
#  'abdurakhmanova': [['{',
#    'b',
#    'd',
#    'U',
#    'V',
#    'k',
#    'm',
#    'A',
#    'n',
#    'oU',
#    'v',
#    'V']],
#  'abdurazakov': [['{', 'b', 'd', 'U', 'A', 'z', 'V', 'k', 'A', 'v']],
#  'abdurrahman': [['{', 'b', 'd', '3`', 'r', 'A', 'm', 'V', 'n'],
#   ['{', 'b', 'd', '@`', 'r', 'A', 'm', '@', 'n'],
#   ['{', 'b', 'd', 'r', 'V', 'm', 'V', 'n']],
#  'abdus': [['{', 'b', 'd', 'I', 's']],
#  'abduwali': [['{', 'b', 'd', 'u', 'w', 'A', 'l', 'i']],
#  'abdy': [['{', 'b', 'd', 'i']],
#  'abe': [['eI', 'b'], ['{', 'b', 'eI']],
#  "abe's": [['A', 'b', 'eI', 'z'], ['eI', 'b', 'z']],
#  'abeam': [['@', 'b', 'i', 'm']],
#  'abear': [['@', 'b', 'E:', 'r']],
#  'abebe': [['V', 'b', 'i', 'b'], ['V', 'b', 'i', 'b', 'i']],
#  'abebooks': [['V', 'b', 'V', 'b', 'U', 'k', 's']],
#  'abeche': [['V', 'b', 'V', 'S'], ['{', 'b', 'E', 'S']],
#  'abed': [['@', 'b', 'E', 'd'], ['V', 'b', 'E', 'd']],
#  'abedi': [['V', 'b', 'E', 'd', 'i']],
#  'abedin': [['V', 'b', 'E', 'd', 'I', 'n'], ['{', 'b', '@', 'd', '@', 'n']],
#  'abedine': [['V', 'b', 'E', 'd', 'aI', 'n']],
#  'abednego': [['@', 'b', 'E', 'd', 'n', 'eI', 'g', 'oU']],
#  'abeer': [['V', 'b', 'I', 'r'], ['eI', 'b', 'I', 'r']],
#  'abegg': [['V', 'b', 'E', 'g']],
#  'abeid': [['V', 'b', 'aI', 'd']],
#  'abeille': [['@', 'b', 'eI', 'l']],
#  'abein': [['V', 'b', 'aI', 'n']],
#  'abel': [['eI', 'b', '@', 'l'], ['eI', 'b', 'V', 'l']],
#  "abel's": [['eI', 'b', '@', 'l', 'z']],
#  'abela': [['A', 'b', 'E', 'l', '@'], ['A', 'b', 'E', 'l', 'V']],
#  'abelard': [['{', 'b', 'I', 'l', '3`', 'd'], ['{', 'b', 'I', 'l', '@`', 'd']],
#  "abelard's": [['{', 'b', 'I', 'l', '@`', 'd', 'z']],
#  'abelardo': [['{', 'b', 'V', 'l', 'A', 'r', 'd', 'oU']],
#  'abele': [['V', 'b', 'i', 'l']],
#  'abeles': [['@', 'b', 'E', 'l', 'z'],
#   ['V', 'b', 'i', 'l', 'z'],
#   ['eI', 'b', '@', 'l', 'i', 'z'],
#   ['eI', 'b', 'V', 'l', 'i', 'z']],
#  'abell': [['@', 'b', 'E', 'l'], ['eI', 'b', '@', 'l'], ['eI', 'b', 'V', 'l']],
#  'abella': [['@', 'b', 'E', 'l', '@'], ['V', 'b', 'E', 'l', 'V']],
#  'abellino': [['eI', 'b', 'E', 'l', 'i', 'n', 'oU']],
#  'abelow': [['{', 'b', 'V', 'l', 'oU']],
#  'abels': [['eI', 'b', 'V', 'l', 'z']],
#  'abelson': [['{', 'b', 'I', 'l', 's', 'V', 'n']],
#  'abelungu': [['{', 'b', 'I', 'l', 'V', 'N', 'u']],
#  'aben': [['{', 'b', '@', 'n']],
#  'abenadar': [['@', 'b', 'E', 'n', '@', 'd', 'A', 'r']],
#  'abenaki': [['{', 'b', 'E', 'n', 'A', 'k', 'i']],
#  'abenakis': [['{', 'b', 'E', 'n', 'A', 'k', 'I', 's']],
#  'abenalfange': [['{', 'b', 'E', 'n', 'A', 'l', 'f', 'A', 'n', 'dZ']],
#  'abenalfarax': [['{', 'b', 'E', 'n', 'A', 'l', 'f', 'A', 'r', '{', 'k', 's']],
#  'abenali': [['{', 'b', 'E', 'n', 'A', 'l', 'i']],
#  'abenamar': [['{', 'b', 'E', 'n', 'A', 'm', 'A', 'r']],
#  'abenaquis': [['{', 'b', 'E', 'n', 'A', 'k', 'i']],
#  'abencerrage': [['@', 'b', 'E', 'n', 's', '@`', 'A', 'Z']],
#  'abencerrages': [['@', 'b', 'E', 'n', 's', '@`', 'A', 'Z', 'I', 'z']],
#  'abend': [['@', 'b', 'E', 'n', 'd'],
#   ['V', 'b', 'E', 'n', 'd'],
#   ['{', 'b', 'E', 'n', 'd']],
#  'abendanon': [['V', 'b', 'E', 'n', 'd', 'V', 'n', 'V', 'n'],
#   ['{', 'b', 'I', 'n', 'd', 'V', 'n', 'A', 'n']],
#  'abendblatt': [['{', 'b', 'E', 'n', 'd', 'b', 'l', '@', 't']],
#  'abengoa': [['V', 'b', 'E', 'N', 'g', 'oU', 'V'],
#   ['{', 'b', 'I', 'n', 'g', 'oU', 'V']],
#  'abeniaf': [['@', 'b', 'E', 'n', 'i', '{', 'f']],
#  'abenoz': [['{', 'b', 'I', 'n', 'oU', 'z']],
#  'abeokuta': [['@', 'b', 'i', 'A', 'k', 'u', '4', '@']],
#  'abeout': [['@', 'b', 'aU', 't']],
#  'aber': [['eI', 'b', '3`'], ['eI', 'b', '@`']],
#  'aberaeron': [['{', 'b', '3`', 'E', 'r', 'V', 'n'],
#   ['{', 'b', '3`', 'r', '3`', 'V', 'n']],
#  'aberalva': [['{', 'b', '@`', 'A', 'l', 'v', '@']],
#  'aberaman': [['{', 'b', '3`', 'V', 'm', 'V', 'n']],
#  'aberavon': [['{', 'b', '3`', 'A', 'v', 'O', 'n'],
#   ['{', 'b', '3`', 'r', 'A', 'v', 'A', 'n']],
#  'abercorn': [['{', 'b', '3`', 'k', '3`', 'n'],
#   ['{', 'b', '@`', 'k', 'O', 'r', 'n']],
#  'abercrombie': [['{', 'b', '3`', 'k', 'r', 'A', 'm', 'b', 'i'],
#   ['{', 'b', '@`', 'k', 'r', 'A', 'm', 'b', 'i']],
#  "abercrombie's": [['{', 'b', '@`', 'k', 'r', 'A', 'm', 'b', 'i', 'z']],
#  'abercrombies': [['{', 'b', '@`', 'k', 'r', 'A', 'm', 'b', 'i', 'z']],
#  'abercromby': [['{', 'b', '@`', 'k', 'r', 'A', 'm', 'b', 'i']],
#  "abercromby's": [['{', 'b', '@`', 'k', 'r', 'A', 'm', 'b', 'i', 'z']],
#  'abercynon': [['{', 'b', '3`', 'k', 'i', 'n', 'O', 'n']],
#  'aberdare': [['{', 'b', '3`', 'd', 'E', 'r'],
#   ['{', 'b', '3`', 'd', 'eI', 'r'],
#   ['{', 'b', '@`', 'd', 'E:', 'r']],
#  'aberdeen': [['{', 'b', '3`', 'd', 'i', 'n'],
#   ['{', 'b', '@`', 'd', 'i', 'n']],
#  "aberdeen's": [['{', 'b', '3`', 'd', 'i', 'n', 'z'],
#   ['{', 'b', '@`', 'd', 'i', 'n', 'z']],
#  'aberdeenshire': [['{', 'b', '3`', '3`', 'd', 'i', 'n', 'S', 'aI', 'r'],
#   ['{', 'b', '3`', 'd', 'i', 'n', 'S', 'aI', 'r'],
#   ['{', 'b', '@`', 'd', 'i', 'n', 'S', 'aI', 'r']],
#  'aberdonian': [['{', 'b', '3`', 'd', 'oU', 'n', 'i', 'V', 'n'],
#   ['{', 'b', '@`', 'd', 'oU', 'n', 'i', '@', 'n']],
#  'aberdonians': [['{', 'b', '3`', 'd', 'oU', 'n', 'i', 'V', 'n', 'z']],
#  'aberdour': [['{', 'b', '@`', 'd', 'O', 'r']],
#  'aberdyfi': [['{', 'b', '3`', '3`', 'd', 'V', 'f', 'i'],
#   ['{', 'b', '3`', 'd', 'aI', 'f', 'i']],
#  'aberfan': [['eI', 'b', '3`', 'f', '{', 'n'],
#   ['{', 'b', '3`', 'f', '{', 'n']],
#  'aberfeldy': [['eI', 'b', '3`', 'f', 'E', 'l', 'd', 'i'],
#   ['{', 'b', '3`', 'f', 'I', 'l', 'd', 'i']],
#  'aberffraw': [['{', 'b', '3`', 'f', 'r', 'O']],
#  'aberfilly': [['eI', 'b', '@`', 'f', 'I', 'l', 'i']],
#  'aberfoil': [['eI', 'b', '@`', 'f', 'OI', 'l']],
#  'aberford': [['eI', 'b', '@`', 'f', '@`', 'd']],
#  'aberfoyle': [['eI', 'b', '3`', 'f', 'OI', 'l'],
#   ['eI', 'b', '@`', 'f', 'OI', 'l']],
#  'abergann': [['{', 'b', '@`', 'g', '{', 'n']],
#  'abergavenny': [['{', 'b', '3`', 'g', 'A', 'v', 'E', 'n', 'i'],
#   ['{', 'b', '3`', 'g', 'A', 'v', 'I', 'n', 'i'],
#   ['{', 'b', '@`', 'g', 'A', 'v', 'E', 'n', 'i']],
#  'abergeldie': [['{', 'b', '@`', 'g', 'E', 'l', 'd', 'i']],
#  'abergele': [['{', 'b', '3`', 'g', 'V', 'l']],
#  'abergil': [['{', 'b', '3`', 'dZ', 'V', 'l']],
#  'aberglaslyn': [['{', 'b', '3`', 'g', 'l', '{', 's', 'l', 'I', 'n']],
#  'aberglyn': [['{', 'b', '@`', 'g', 'l', 'I', 'n']],
#  'aberleigh': [['{', 'b', '@`', 'l', '@']],
#  'aberlour': [['{', 'b', '3`', 'l', '3`']],
#  'abermouth': [['{', 'b', '@`', 'm', '@', 'T']],
#  'abernathy': [['{', 'b', '3`', 'n', '{', 'T', 'i'],
#   ['{', 'b', '@`', 'n', '{', 'T', 'i']],
#  'abernethy': [['{', 'b', '3`', 'n', 'E', 'T', 'i'],
#   ['{', 'b', '@`', 'n', 'E', 'T', 'i']],
#  "abernethy's": [['{', 'b', '@`', 'n', 'E', 'T', 'i', 'z']],
#  'aberpergwm': [['{', 'b', '3`', 'p', '3`', 'm']],
#  'aberporth': [['{', 'b', '3`', 'p', 'O', 'r', 'T']],
#  'aberra': [['{', 'b', 'E', 'r', 'V']],
#  'aberrant': [['{', 'b', 'E:', 'r', '@', 'n', 't'],
#   ['{', 'b', 'E', 'r', 'V', 'n', 't']],
#  'aberration': [['{', 'b', '3`', 'eI', 'S', 'V', 'n'],
#   ['{', 'b', '@`', 'eI', 'S', '@', 'n']],
#  'aberrational': [['{', 'b', '3`', 'eI', 'S', 'V', 'n', 'V', 'l']],
#  'aberrations': [['{', 'b', '3`', 'eI', 'S', 'V', 'n', 'z'],
#   ['{', 'b', '@`', 'eI', 'S', '@', 'n', 'z']],
#  'abershaw': [['{', 'b', '@`', 'S', 'O']],
#  'abersoch': [['{', 'b', '3`', 's', 'A', 'k'],
#   ['{', 'b', '3`', 's', 'V', 'k']],
#  'abertaff': [['{', 'b', '@`', '4', '{', 'f']],
#  'abertawe': [['{', 'b', 'E', 't', 'eI', 'w']],
#  'abertay': [['{', 'b', '3`', 't', 'eI'], ['{', 'b', 'E', 't', 'eI']],
#  'abertewey': [['{', 'b', '@`', '4', 'u', 'i']],
#  'aberthaw': [['{', 'b', '3`', 'T', 'O']],
#  'abertillery': [['{', 'b', '3`', 't', 'I', 'l', '3`', 'i']],
#  'abertzale': [['{', 'b', '3`', 't', 'z', 'V', 'l']],
#  'aberystwith': [['{', 'b', '@`', 'I', 's', 't', 'w', 'I', 'T']],
#  'aberystwyth': [['{', 'b', '3`', 'I', 'S', 't', 'w', 'I', 'T'],
#   ['{', 'b', '3`', 'I', 's', 't', 'w', 'I', 'T'],
#   ['{', 'b', '@`', 'I', 'S', 't', 'w', 'I', 'T']],
#  'abess': [['V', 'b', 'V', 's'], ['{', 'b', 'I', 's']],
#  'abest': [['eI', 'b', '@', 's', 't']],
#  'abet': [['@', 'b', 'E', 't'], ['V', 'b', 'E', 't']],
#  'abets': [['@', 'b', 'E', 't', 's'], ['V', 'b', 'V', 't', 's']],
#  'abetted': [['@', 'b', 'E', '4', 'I', 'd'], ['V', 'b', 'E', 't', 'I', 'd']],
#  'abetter': [['@', 'b', 'E', '4', '@`']],
#  'abetting': [['@', 'b', 'E', '4', 'I', 'N'], ['V', 'b', 'E', 't', 'I', 'N']],
#  'abettor': [['@', 'b', 'E', '4', '@`'], ['V', 'b', 'E', 't', '3`']],
#  'abettors': [['@', 'b', 'E', '4', '@`', 'z']],
#  'abeuchapeta': [['@', 'b', 'eI', '@', 'S', '@', 'p', 'i', '4', '@']],
#  'abeundi': [['@', 'b', 'U', 'n', 'd', 'i']],
#  'abey': [['eI', 'b', 'i']],
#  'abeyance': [['@', 'b', 'eI', '@', 'n', 's'],
#   ['V', 'b', 'eI', 'V', 'n', 's']],
#  'abeyie': [['V', 'b', 'eI', 'i']],
#  'abf': [['{', 'b', 'f']],
#  'abg': [['{', 'b', 'g']],
#  'abgarus': [['{', 'b', 'g', '@`', '@', 's']],
#  'abh': [['{', 'b']],
#  'abha': [['@', 'b', 'h', '@'], ['{', 'b', 'h', 'V']],
#  'abhijit': [['V', 'b', 'h', 'I', 'dZ', 'V', 't'],
#   ['{', 'b', 'h', 'I', 'dZ', 'I', 't']],
#  'abhishek': [['V', 'b', 'h', 'I', 'S', 'I', 'k'],
#   ['{', 'b', 'h', 'I', 'S', 'I', 'k']],
#  'abhisit': [['V', 'b', 'h', 'I', 's', 'V', 't'],
#   ['{', 'b', 'h', 'I', 'z', 'I', 't']],
#  'abhor': [['{', 'b', 'h', 'O', 'r']],
#  "abhorr'd": [['@', 'b', 'h', 'O', '@`', 'd']],
#  'abhorred': [['@', 'b', 'h', 'O', 'r', 'd'],
#   ['V', 'b', 'h', 'O', 'r', 'd'],
#   ['{', 'b', 'h', 'O', 'r', 'd']],
#  'abhorrence': [['@', 'b', 'h', 'O', 'r', '@', 'n', 's'],
#   ['V', 'b', 'h', 'O', 'r', 'V', 'n', 's']],
#  'abhorrent': [['{', 'b', 'h', 'O', 'r', '@', 'n', 't'],
#   ['{', 'b', 'h', 'O', 'r', 'V', 'n', 't']],
#  'abhorrently': [['@', 'b', 'h', 'O', 'r', '@', 'n', 't', 'l', 'i']],
#  'abhorreth': [['@', 'b', 'h', 'O', 'r', 'I', 'T']],
#  'abhorring': [['@', 'b', 'h', 'O', 'r', 'I', 'N']],
#  'abhors': [['@', 'b', 'h', 'O', 'r', 'z'], ['V', 'b', 'h', 'O', 'r', 'z']],
#  'abi': [['A', 'b', 'aI'], ['A', 'b', 'i'], ['{', 'b', 'i']],
#  'abia': [['eI', 'b', 'i', 'V']],
#  'abiad': [['@', 'b', 'aI', '{', 'd']],
#  'abiah': [['@', 'b', 'aI', '@']],
#  'abiathar': [['@', 'b', 'aI', '@', 'T', 'A', 'r']],
#  'abib': [['@', 'b', 'i', 'b']],
#  'abid': [['eI', 'b', 'I', 'd']],
#  'abidal': [['V', 'b', 'aI', 'd', 'V', 'l'], ['V', 'b', 'i', 'd', 'V', 'l']],
#  'abide': [['@', 'b', 'aI', 'd'], ['V', 'b', 'aI', 'd']],
#  'abided': [['@', 'b', 'aI', 'd', 'I', 'd'], ['V', 'b', 'aI', 'd', 'I', 'd']],
#  'abiders': [['@', 'b', 'aI', 'd', '@`', 'z']],
#  'abides': [['@', 'b', 'aI', 'd', 'z'], ['V', 'b', 'aI', 'd', 'z']],
#  'abidest': [['@', 'b', 'aI', 'd', '@', 's', 't']],
#  'abideth': [['@', 'b', 'aI', 'd', 'I', 'T']],
#  'abidin': [['@', 'b', 'aI', 'd', 'I', 'n'], ['V', 'b', 'aI', 'd', 'I', 'n']],
#  'abidine': [['V', 'b', 'aI', 'd', 'aI', 'n']],
#  'abiding': [['@', 'b', 'aI', 'd', 'I', 'N'], ['V', 'b', 'aI', 'd', 'I', 'N']],
#  'abidingly': [['@', 'b', 'aI', 'd', 'I', 'N', 'l', 'i']],
#  'abidjan': [['{', 'b', 'I', 'dZ', 'A', 'n']],
#  'abie': [['{', 'b', 'i']],
#  'abiel': [['{', 'b', 'i', 'V', 'l'], ['{', 'b', 'i', 'l']],
#  'abiertas': [['{', 'b', 'r', 't', 'V', 's']],
#  'abies': [['eI', 'b', 'i', 'z']],
#  'abiet': [['@', 'b', 'aI', 'I', 't']],
#  'abigail': [['{', 'b', '@', 'g', 'eI', 'l'],
#   ['{', 'b', 'I', 'g', 'eI', 'l'],
#   ['{', 'b', 'V', 'g', 'eI', 'l']],
#  "abigail's": [['{', 'b', '@', 'g', 'eI', 'l', 'z'],
#   ['{', 'b', 'V', 'g', 'eI', 'l', 'z']],
#  'abigails': [['{', 'b', '@', 'g', 'eI', 'l', 'z']],
#  'abihu': [['{', 'b', 'I', 'h', 'u']],
#  'abiit': [['@', 'b', 'aI', 'I', 't']],
#  'abijah': [['@', 'b', 'I', 'dZ', '@']],
#  "abijah's": [['@', 'b', 'I', 'dZ', '@', 'z']],
#  'abil': [['{', 'b', 'I', 'l']],
#  'abila': [['A', 'b', 'i', 'l', 'V']],
#  'abilene': [['{', 'b', 'I', 'l', 'i', 'n']],
#  'abilify': [['A', 'b', 'i', 'l', 'I', 'f', 'aI'],
#   ['V', 'b', 'I', 'l', 'V', 'f', 'aI']],
#  'abilities': [['@', 'b', 'I', 'l', '@', '4', 'i', 'z'],
#   ['@', 'b', 'I', 'l', '@', 't', 'i', 'z'],
#   ['V', 'b', 'I', 'l', 'V', 't', 'i', 'z']],
#  'ability': [['@', 'b', 'I', 'l', '@', '4', 'i'],
#   ['@', 'b', 'I', 'l', 'I', '4', 'i'],
#   ['@', 'b', 'I', 'l', 'I', 't', 'i'],
#   ['V', 'b', 'I', 'l', 'V', 't', 'i']],
#  'abimael': [['{', 'b', 'I', 'm', 'eI', 'l']],
#  'abimelech': [['{', 'b', 'I', 'm', 'E', 'l', 'E', 'k']],
#  'abinadab': [['@', 'b', 'aI', 'n', '@', 'd', '{', 'b']],
#  'abingdon': [['{', 'b', 'I', 'N', 'd', '@', 'n'],
#   ['{', 'b', 'I', 'N', 'd', 'V', 'n']],
#  "abingdon's": [['{', 'b', 'I', 'N', 'd', '@', 'n', 'z']],
#  'abinger': [['{', 'b', 'I', 'N', '@`']],
#  "abinger's": [['{', 'b', 'I', 'N', '@`', 'z']],
#  'abington': [['{', 'b', 'I', 'N', 't', '@', 'n'],
#   ['{', 'b', 'I', 'N', 't', 'V', 'n']],
#  'abiogenesis': [['A', 'b', 'i', 'oU', 'dZ', 'E', 'n', 'V', 's', 'V', 's'],
#   ['V', 'b', 'aI', 'oU', 'dZ', 'E', 'n', 'V', 's', 'V', 's']],
#  'abiola': [['A', 'b', 'i', 'oU', 'l', 'V']],
#  'abir': [['{', 'b', 'I', 'r']],
#  'abiram': [['eI', 'b', 'i', 'r', '@', 'm']],
#  'abiraterone': [['{', 'b', 'I', 'r', 'A', 't', '3`', 'oU', 'n']],
#  'abishag': [['{', 'b', 'I', 'S', '{', 'g']],
#  'abishai': [['{', 'b', 'I', 'S', 'aI']],
#  'abissinia': [['{', 'b', 'V', 's', 'I', 'n', 'i', 'V']],
#  'abit': [['{', 'b', 'I', 't']],
#  'abita': [['{', 'b', 'i', 't', 'V']],
#  'abitbol': [['{', 'b', 'I', 't', 'b', 'A', 'l']],
#  'abitibi': [['{', 'b', 'I', '4', 'i', 'b', 'i'],
#   ['{', 'b', 'I', 't', 'i', 'b', 'i']],
#  'abitibibowater': [['{',
#    'b',
#    'i',
#    't',
#    'I',
#    'b',
#    'I',
#    'b',
#    'V',
#    'O',
#    't',
#    '3`']],
#  'abits': [['{', 'b', '@', 't', 's']],
#  'abitur': [['{', 'b', 'I', 't', '3`']],
#  'abiye': [['{', 'b', 'I', 'j']],
#  'abizaid': [['V', 'b', 'I', 'z', 'eI', 'd'], ['{', 'b', 'I', 'z', 'eI', 'd']],
#  'abject': [['{', 'b', 'dZ', 'E', 'k', 't']],
#  'abjection': [['{', 'b', 'dZ', 'E', 'k', 'S', '@', 'n'],
#   ['{', 'b', 'dZ', 'E', 'k', 'S', 'V', 'n']],
#  'abjectly': [['{', 'b', 'dZ', 'E', 'k', 'l', 'i'],
#   ['{', 'b', 'dZ', 'E', 'k', 't', 'l', 'i']],
#  'abjectness': [['{', 'b', 'dZ', 'E', 'k', 't', 'n', '@', 's']],
#  'abjuration': [['{', 'b', 'dZ', '@`', 'eI', 'S', '@', 'n']],
#  'abjurations': [['{', 'b', 'dZ', '@`', 'eI', 'S', '@', 'n', 'z']],
#  'abjure': [['V', 'b', 'dZ', 'r', '3`'],
#   ['{', 'b', 'dZ', '3`'],
#   ['{', 'b', 'dZ', '@`']],
#  'abjured': [['{', 'b', 'dZ', '3`', 'd'], ['{', 'b', 'dZ', '@`', 'd']],
#  'abjures': [['{', 'b', 'dZ', '3`', 'z'], ['{', 'b', 'dZ', '@`', 'z']],
#  'abjuring': [['V', 'b', 'dZ', 'U', 'I', 'N'],
#   ['{', 'b', 'dZ', '@`', 'I', 'N']],
#  'abk': [['{', 'b', 'k']],
#  'abkazian': [['{', 'b', 'k', 'eI', 'z', 'i', 'V', 'n']],
#  'abkco': [['{', 'b', 'k', 'k', 'oU'], ['{', 'b', 'k', 'oU']],
#  'abkhasia': [['{', 'b', 'k', 'h', '{', 'z', 'V']],
#  'abkhaz': [['{', 'b', 'k', 'h', 'A', 'z'], ['{', 'b', 'k', '{', 'z']],
#  'abkhazia': [['{', 'b', 'k', 'A', 'z', 'j', 'V'],
#   ['{', 'b', 'k', 'h', 'A', 'z', 'j', 'V'],
#   ['{', 'b', 'k', 'h', '{', 'z', 'j', 'V'],
#   ['{', 'b', 'k', '{', 'z', 'j', 'V']],
#  "abkhazia's": [['{', 'b', 'k', 'A', 'z', 'j', 'V', 'z'],
#   ['{', 'b', 'k', '{', 'z', 'j', 'V', 'z']],
#  'abkhazian': [['{', 'b', 'k', 'A', 'z', 'i', 'V', 'n'],
#   ['{', 'b', 'k', 'A', 'z', 'j', 'V', 'n'],
#   ['{', 'b', 'k', 'h', 'A', 'z', 'i', 'V', 'n'],
#   ['{', 'b', 'k', 'h', 'A', 'z', 'j', 'V', 'n'],
#   ['{', 'b', 'k', 'h', '{', 'z', 'i', 'V', 'n'],
#   ['{', 'b', 'k', 'h', '{', 'z', 'j', 'V', 'n'],
#   ['{', 'b', 'k', '{', 'z', 'i', 'V', 'n'],
#   ['{', 'b', 'k', '{', 'z', 'j', 'V', 'n']],
#  'abkhazians': [['{', 'b', 'k', 'A', 'z', 'i', 'V', 'n', 'z'],
#   ['{', 'b', 'k', 'h', 'A', 'z', 'i', 'V', 'n', 'z'],
#   ['{', 'b', 'k', 'h', '{', 'z', 'i', 'V', 'n', 'z'],
#   ['{', 'b', 'k', '{', 'z', 'i', 'V', 'n', 'z']],
#  'abl': [['eI', 'b', 'V', 'l'], ['{', 'b', 'l']],
#  'abla': [['{', 'b', 'l', '@']],
#  'ablage': [['@', 'b', 'l', 'eI', 'dZ']],
#  'ablain': [['eI', 'b', 'l', 'eI', 'n']],
#  'ablano': [['eI', 'b', 'l', 'A', 'n', 'oU']],
#  'ablate': [['V', 'b', 'l', 'eI', 't']],
#  'ablation': [['@', 'b', 'l', 'eI', 'S', '@', 'n'],
#   ['V', 'b', 'l', 'eI', 'S', 'V', 'n']],
#  'ablative': [['V', 'b', 'l', 'eI', 't', 'I', 'v'],
#   ['{', 'b', 'l', '@', '4', 'I', 'v']],
#  'ablaze': [['@', 'b', 'l', 'eI', 'z'], ['V', 'b', 'l', 'eI', 'z']],
#  'able': [['eI', 'b', '@', 'l'], ['eI', 'b', 'V', 'l']],
#  'able-bodied': [['eI', 'b', '@', 'l', 'b', 'A', 'd', 'i', 'd']],
#  'abled': [['eI', 'b', '@', 'l', 'd'], ['eI', 'b', 'V', 'l', 'd']],
#  'ableism': [['eI', 'b', '@', 'l', 'I', 'z', '@', 'm']],
#  'abler': [['eI', 'b', '@', 'l', '@`'],
#   ['eI', 'b', 'V', 'l', '3`'],
#   ['eI', 'b', 'l', '3`'],
#   ['eI', 'b', 'l', '@`']],
#  'ables': [['eI', 'b', 'V', 'l', 'z']],
#  'ablest': [['eI', 'b', '@', 'l', 's', 't'],
#   ['eI', 'b', 'V', 'l', 's', 't'],
#   ['eI', 'b', 'l', '@', 's', 't'],
#   ['eI', 'b', 'l', 'V', 's', 't']],
#  'ablethorpe': [['eI', 'b', '@', 'l', 'T', 'O', 'r', 'p']],
#  'ablett': [['eI', 'b', 'V', 'l', 'I', 't'], ['eI', 'b', 'l', 'I', 't']],
#  "ablett's": [['eI', 'b', 'l', '@', 't', 's']],
#  'ablewhite': [['eI', 'b', '@', 'l', 'w', 'aI', 't']],
#  "ablewhite's": [['eI', 'b', '@', 'l', 'w', 'aI', 't', 's']],
#  'abli': [['eI', 'b', 'l', 'i']],
#  'ablin': [['eI', 'b', 'l', 'I', 'n'], ['{', 'b', 'l', 'I', 'n']],
#  'abloom': [['@', 'b', 'l', 'u', 'm'], ['V', 'b', 'l', 'u', 'm']],
#  'ablow': [['V', 'b', 'l', 'aU'], ['{', 'b', 'l', 'oU']],
#  'ablution': [['eI', 'b', 'l', 'u', 'S', '@', 'n']],
#  'ablutions': [['V', 'b', 'l', 'u', 'S', 'V', 'n', 'z'],
#   ['eI', 'b', 'l', 'u', 'S', '@', 'n', 'z'],
#   ['eI', 'b', 'l', 'u', 'S', 'V', 'n', 'z']],
#  'ably': [['eI', 'b', 'l', 'i']],
#  'abm': [['V', 'b', 'm']],
#  'abms': [['V', 'b', 'm', 'z']],
#  'abn': [['{', 'b', 'n']],
#  'abnakis': [['{', 'b', 'n', 'A', 'k', 'I', 's']],
#  'abnegate': [['{', 'b', 'n', 'g', 'eI', 't']],
#  'abnegated': [['eI', 'b', 'i', 'E', 'n', 'i', 'g', 'eI', '4', 'I', 'd']],
#  'abnegating': [['{', 'b', 'n', 'I', 'g', 'eI', '4', 'I', 'N']],
#  'abnegation': [['{', 'b', 'n', '@', 'g', 'eI', 'S', '@', 'n'],
#   ['{', 'b', 'n', 'V', 'g', 'eI', 'S', 'V', 'n']],
#  'abnegations': [['{', 'b', 'n', '@', 'g', 'eI', 'S', '@', 'n', 'z']],
#  'abner': [['{', 'b', 'n', '3`'], ['{', 'b', 'n', '@`']],
#  "abner's": [['{', 'b', 'n', '3`', 'z'], ['{', 'b', 'n', '@`', 'z']],
#  'abneris': [['{', 'b', 'n', '3`', 'I', 's']],
#  'abnett': [['{', 'b', 'n', 'I', 't']],
#  'abney': [['{', 'b', 'n', 'i']],
#  "abney's": [['{', 'b', 'n', 'i', 'z']],
#  'abnormal': [['{', 'b', 'n', 'O', 'r', 'm', '@', 'l'],
#   ['{', 'b', 'n', 'O', 'r', 'm', 'V', 'l']],
#  'abnormalities': [['{', 'b', 'n', '@`', 'm', '{', 'l', '@', '4', 'i', 'z'],
#   ['{', 'b', 'n', '@`', 'm', '{', 'l', '@', 't', 'i', 'z'],
#   ['{', 'b', 'n', 'O', 'r', 'm', '{', 'l', '@', '4', 'i', 'z'],
#   ['{', 'b', 'n', 'O', 'r', 'm', '{', 'l', 'V', 't', 'i', 'z']],
#  'abnormality': [['{', 'b', 'n', 'O', 'r', 'm', '{', 'l', '@', '4', 'i'],
#   ['{', 'b', 'n', 'O', 'r', 'm', '{', 'l', 'V', 't', 'i']],
#  'abnormally': [['{', 'b', 'n', 'O', 'r', 'm', '@', 'l', 'i'],
#   ['{', 'b', 'n', 'O', 'r', 'm', 'V', 'l', 'i']],
#  'abo': [['A', 'b', 'oU'], ['{', 'b', 'oU']],
#  "abo's": [['A', 'b', 'oU', 'z']],
#  'aboard': [['@', 'b', 'O', 'r', 'd'], ['V', 'b', 'O', 'r', 'd']],
#  'abobo': [['V', 'b', 'oU', 'b', 'oU']],
#  'abode': [['@', 'b', 'oU', 'd'], ['V', 'b', 'oU', 'd']],
#  'abodes': [['@', 'b', 'oU', 'd', 'z'], ['V', 'b', 'oU', 'd', 'z']],
#  'aboegib': [['@', 'b', 'oU', 'g', 'I', 'b']],
#  'aboeza': [['@', 'b', 'eI', 'z', '@']],
#  'abogaz': [['A', 'b', 'oU', 'g', 'A', 'z']],
#  'abogin': [['@', 'b', 'oU', 'g', '@', 'n']],
#  'abolfazl': [['{', 'b', 'A', 'l', 'f', 'z', 'l']],
#  'abolhassan': [['{', 'b', 'A', 'l', 'h', 'V', 's', 'V', 'n'],
#   ['{', 'b', 'V', 'l', 'h', 'V', 's', 'A', 'n']],
#  'abolish': [['@', 'b', 'A', 'l', 'I', 'S'], ['V', 'b', 'A', 'l', 'I', 'S']],
#  'abolished': [['@', 'b', 'A', 'l', 'I', 'S', 't'],
#   ['V', 'b', 'A', 'l', 'I', 'S', 't']],
#  'abolishes': [['@', 'b', 'A', 'l', 'I', 'S', 'I', 'z'],
#   ['V', 'b', 'A', 'l', 'I', 'S', 'I', 'z']],
#  'abolishing': [['@', 'b', 'A', 'l', '@', 'S', 'I', 'N'],
#   ['@', 'b', 'A', 'l', 'I', 'S', 'I', 'N'],
#   ['V', 'b', 'A', 'l', 'I', 'S', 'I', 'N']],
#  'abolishment': [['@', 'b', 'A', 'l', 'I', 'S', 'm', '@', 'n', 't'],
#   ['V', 'b', 'A', 'l', 'I', 'S', 'm', 'V', 'n', 't'],
#   ['{', 'b', 'A', 'l', 'I', 'S', 'm', 'V', 'n', 't']],
#  'abolition': [['{', 'b', '@', 'l', 'I', 'S', '@', 'n'],
#   ['{', 'b', 'V', 'l', 'I', 'S', 'V', 'n']],
#  'abolitionism': [['{', 'b', '@', 'l', 'I', 'S', '@', 'n', 'I', 'z', '@', 'm'],
#   ['{', 'b', 'V', 'l', 'I', 'S', 'V', 'n', 'I', 'z', 'V', 'm']],
#  'abolitionist': [['{', 'b', '@', 'l', 'I', 'S', '@', 'n', '@', 's', 't'],
#   ['{', 'b', 'V', 'l', 'I', 'S', 'V', 'n', 'V', 's', 't']],
#  'abolitionists': [['{', 'b', '@', 'l', 'I', 'S', '@', 'n', '@', 's'],
#   ['{', 'b', '@', 'l', 'I', 'S', '@', 'n', '@', 's', 't', 's'],
#   ['{', 'b', 'V', 'l', 'I', 'S', 'V', 'n', 'V', 's'],
#   ['{', 'b', 'V', 'l', 'I', 'S', 'V', 'n', 'V', 's', 't', 's']],
#  'abololo': [['{', 'b', 'V', 'l', 'oU', 'l', 'oU']],
#  'abominable': [['@', 'b', 'A', 'm', '@', 'n', '@', 'b', '@', 'l'],
#   ['@', 'b', 'A', 'm', 'I', 'n', '@', 'b', '@', 'l'],
#   ['V', 'b', 'A', 'm', 'V', 'n', 'V', 'b', 'V', 'l']],
#  'abominably': [['@', 'b', 'A', 'm', '@', 'n', '@', 'b', 'l', 'i'],
#   ['V', 'b', 'A', 'm', 'V', 'n', 'V', 'b', 'l', 'i']],
#  'abominate': [['@', 'b', 'A', 'm', '@', 'n', 'eI', 't'],
#   ['V', 'b', 'A', 'm', 'V', 'n', 'eI', 't'],
#   ['V', 'b', 'O', 'm', 'V', 'n', 'eI', 't']],
#  'abominated': [['@', 'b', 'A', 'm', '@', 'n', 'eI', '4', '@', 'd']],
#  'abominates': [['@', 'b', 'A', 'm', '@', 'n', 'eI', 't', 's']],
#  'abominating': [['@', 'b', 'A', 'm', '@', 'n', 'eI', '4', 'I', 'N']],
#  'abomination': [['@', 'b', 'A', 'm', '@', 'n', 'eI', 'S', '@', 'n'],
#   ['@', 'b', 'A', 'm', 'I', 'n', 'eI', 'S', '@', 'n'],
#   ['V', 'b', 'A', 'm', 'V', 'n', 'eI', 'S', 'V', 'n']],
#  'abominations': [['@', 'b', 'A', 'm', '@', 'n', 'eI', 'S', '@', 'n', 'z'],
#   ['V', 'b', 'A', 'm', 'V', 'n', 'eI', 'S', 'V', 'n', 'z']],
#  'abon': [['A', 'b', 'O', 'n']],
#  'abonyi': [['@', 'b', 'A', 'n', 'j', 'i']],
#  'aboo': [['@', 'b', 'u']],
#  'aboobaker': [['V', 'b', 'u', 'b', 'eI', 'k', '3`']],
#  'abood': [['V', 'b', 'u', 'd']],
#  'aboody': [['V', 'b', 'u', 'd', 'i']],
#  'aboolian': [['V', 'b', 'u', 'l', 'i', 'V', 'n']],
#  'aboon': [['@', 'b', 'u', 'n']],
#  'aboord': [['@', 'b', 'U', 'r', 'd']],
#  'aboot': [['@', 'b', 'u', 't']],
#  'abor': [['V', 'b', 'O', 'r']],
#  'abord': [['@', 'b', 'O', 'r', 'd']],
#  'aboriginal': [['{', 'b', '3`', 'I', 'dZ', 'V', 'n', 'V', 'l'],
#   ['{', 'b', '@', 'r', 'I', 'dZ', 'I', 'n', '@', 'l'],
#   ['{', 'b', '@`', 'I', 'dZ', '@', 'n', '@', 'l']],
#  'aboriginals': [['V', 'b', '3`', 'I', 'dZ', 'V', 'n', 'V', 'l', 'z'],
#   ['{', 'b', '3`', 'I', 'dZ', 'V', 'n', 'V', 'l', 'z'],
#   ['{', 'b', '@`', 'I', 'dZ', '@', 'n', '@', 'l', 'z']],
#  'aborigine': [['{', 'b', '3`', 'I', 'dZ', 'V', 'n', 'i'],
#   ['{', 'b', '@', 'r', 'I', 'dZ', 'I', 'n', 'i'],
#   ['{', 'b', '@`', 'I', 'dZ', '@', 'n', 'i']],
#  'aborigines': [['{', 'b', '3`', 'I', 'dZ', 'V', 'n', 'i', 'z'],
#   ['{', 'b', '@', 'r', 'I', 'dZ', 'I', 'n', 'i', 'z'],
#   ['{', 'b', '@`', 'I', 'dZ', '@', 'n', 'i', 'z']],
#  'aborn': [['@', 'b', 'O', 'r', 'n']],
#  'aborning': [['V', 'b', 'O', 'r', 'n', 'I', 'N']],
#  'abort': [['@', 'b', 'O', 'r', 't'], ['V', 'b', 'O', 'r', 't']],
#  'aborted': [['@', 'b', 'O', 'r', 't', 'I', 'd'],
#   ['V', 'b', 'O', 'r', 't', 'I', 'd']],
#  ...}

# %%
# run through the vocab file we just generated above and add words to the standard dictionary as necessary
with open("vosk_lm/vocab", 'r') as f:
    line = f.readline().lower().strip()
    while line:
        # filter out comments and open vocabulary matches
        if line[:1] != '#' and line[:1] != '{':
            if line not in lexicon:
                print(f"Adding '{line}'")
                lexicon[line] = " ".join(
                    phonetisaurus.predict(
                        words=[line],
                        model_path=os.path.expanduser('~/.config/naomi/vosk/vosk-model-en-us-0.22-compile/db/en-g2p/en.fst')
                    )[1]
                )
        line = f.readline().lower().strip()

# %%
# generate a new dictionary with all the words
with open('vosk_lm/en.dict', 'w') as f:
    for word in lexicon:
        for pronunciation in lexicon[word]:
            f.write("{word} {pronunciation}\n".format(
                word=word,
                pronunciation=" ".join(pronunciation)
            ))

# %%
# Use the JSGF .gram files to generate an ARPA language model
# !sphinx_jsgf2fsg -jsgf vosk_lm/default.gram -fsg vosk_lm/default.fsg
# Out:
# Current configuration:
# [NAME]		[DEFLT]	[VALUE]
# -compile	no	no
# -fsg			vosk_lm/default.fsg
# -fsm
# -help		no	no
# -jsgf			vosk_lm/default.gram
# -symtab
# -toprule
#
# INFO: jsgf.c(799): Importing <number.number> from vosk_lm/number.gram to default
# INFO: jsgf.c(705): Defined rule: <number.g00000>
# INFO: jsgf.c(705): Defined rule: <number.ones>
# INFO: jsgf.c(705): Defined rule: <number.g00002>
# INFO: jsgf.c(705): Defined rule: <number.one_to_ten>
# INFO: jsgf.c(705): Defined rule: <number.g00004>
# INFO: jsgf.c(705): Defined rule: <number.g00005>
# INFO: jsgf.c(705): Defined rule: <number.oneteens>
# INFO: jsgf.c(705): Defined rule: <number.g00007>
# INFO: jsgf.c(705): Defined rule: <number.tens>
# INFO: jsgf.c(705): Defined rule: <number.hundred>
# INFO: jsgf.c(705): Defined rule: <number.g00010>
# INFO: jsgf.c(705): Defined rule: <number.magnitude>
# INFO: jsgf.c(705): Defined rule: <number.g00012>
# INFO: jsgf.c(705): Defined rule: <number.trailing>
# INFO: jsgf.c(705): Defined rule: <number.leadinghundred>
# INFO: jsgf.c(705): Defined rule: <number.g00015>
# INFO: jsgf.c(705): Defined rule: <number.leadinglasthundred>
# INFO: jsgf.c(705): Defined rule: <number.g00017>
# INFO: jsgf.c(705): Defined rule: <number.leadingmagnitude>
# INFO: jsgf.c(705): Defined rule: <number.g00019>
# INFO: jsgf.c(705): Defined rule: <number.g00020>
# INFO: jsgf.c(705): Defined rule: <number.g00021>
# INFO: jsgf.c(705): Defined rule: <number.g00022>
# INFO: jsgf.c(705): Defined rule: <number.g00023>
# INFO: jsgf.c(705): Defined rule: <number.g00024>
# INFO: jsgf.c(705): Defined rule: <number.g00025>
# INFO: jsgf.c(705): Defined rule: <number.g00026>
# INFO: jsgf.c(705): Defined rule: <number.g00027>
# INFO: jsgf.c(705): Defined rule: <number.g00028>
# INFO: jsgf.c(705): Defined rule: <number.g00029>
# INFO: jsgf.c(705): Defined rule: <number.g00030>
# INFO: jsgf.c(705): Defined rule: <number.g00031>
# INFO: jsgf.c(705): Defined rule: <number.g00032>
# INFO: jsgf.c(705): Defined rule: <number.g00033>
# INFO: jsgf.c(705): Defined rule: <number.g00034>
# INFO: jsgf.c(705): Defined rule: <number.g00035>
# INFO: jsgf.c(705): Defined rule: <number.g00036>
# INFO: jsgf.c(705): Defined rule: <number.g00037>
# INFO: jsgf.c(705): Defined rule: <number.g00038>
# INFO: jsgf.c(705): Defined rule: <number.g00039>
# INFO: jsgf.c(705): Defined rule: <number.g00040>
# INFO: jsgf.c(705): Defined rule: <number.g00041>
# INFO: jsgf.c(705): Defined rule: <number.g00042>
# INFO: jsgf.c(705): Defined rule: <number.g00043>
# INFO: jsgf.c(705): Defined rule: <number.g00044>
# INFO: jsgf.c(705): Defined rule: <number.g00045>
# INFO: jsgf.c(705): Defined rule: <number.g00046>
# INFO: jsgf.c(705): Defined rule: <number.g00047>
# INFO: jsgf.c(705): Defined rule: <number.g00048>
# INFO: jsgf.c(705): Defined rule: <number.g00049>
# INFO: jsgf.c(705): Defined rule: <number.g00050>
# INFO: jsgf.c(705): Defined rule: PUBLIC <number.number>
# INFO: jsgf.c(846): Imported <default.number>
# INFO: jsgf.c(705): Defined rule: <default.g00053>
# INFO: jsgf.c(705): Defined rule: <default.keyword>
# INFO: jsgf.c(705): Defined rule: <default.g00055>
# INFO: jsgf.c(705): Defined rule: <default.calculate>
# INFO: jsgf.c(705): Defined rule: <default.g00057>
# INFO: jsgf.c(705): Defined rule: <default.clock>
# INFO: jsgf.c(705): Defined rule: <default.g00059>
# INFO: jsgf.c(705): Defined rule: <default.checkemail>
# INFO: jsgf.c(705): Defined rule: <default.g00061>
# INFO: jsgf.c(705): Defined rule: <default.g00062>
# INFO: jsgf.c(705): Defined rule: <default.g00063>
# INFO: jsgf.c(705): Defined rule: <default.g00064>
# INFO: jsgf.c(705): Defined rule: <default.g00065>
# INFO: jsgf.c(705): Defined rule: <default.hackernews>
# INFO: jsgf.c(705): Defined rule: <default.g00067>
# INFO: jsgf.c(705): Defined rule: <default.joke>
# INFO: jsgf.c(705): Defined rule: <default.g00069>
# INFO: jsgf.c(705): Defined rule: <default.life>
# INFO: jsgf.c(705): Defined rule: <default.g00071>
# INFO: jsgf.c(705): Defined rule: <default.playlist>
# INFO: jsgf.c(705): Defined rule: <default.g00073>
# INFO: jsgf.c(705): Defined rule: <default.g00074>
# INFO: jsgf.c(705): Defined rule: <default.g00075>
# INFO: jsgf.c(705): Defined rule: <default.mpdcontrol>
# INFO: jsgf.c(705): Defined rule: <default.g00077>
# INFO: jsgf.c(705): Defined rule: <default.newskeyword>
# INFO: jsgf.c(705): Defined rule: <default.g00079>
# INFO: jsgf.c(705): Defined rule: <default.g00080>
# INFO: jsgf.c(705): Defined rule: <default.g00081>
# INFO: jsgf.c(705): Defined rule: <default.g00082>
# INFO: jsgf.c(705): Defined rule: <default.news>
# INFO: jsgf.c(705): Defined rule: <default.g00084>
# INFO: jsgf.c(705): Defined rule: <default.shutdown>
# INFO: jsgf.c(705): Defined rule: <default.g00086>
# INFO: jsgf.c(705): Defined rule: <default.stop>
# INFO: jsgf.c(705): Defined rule: <default.g00088>
# INFO: jsgf.c(705): Defined rule: <default.Forecast>
# INFO: jsgf.c(705): Defined rule: <default.g00090>
# INFO: jsgf.c(705): Defined rule: <default.Location>
# INFO: jsgf.c(705): Defined rule: <default.g00092>
# INFO: jsgf.c(705): Defined rule: <default.WeatherTypePresent>
# INFO: jsgf.c(705): Defined rule: <default.g00094>
# INFO: jsgf.c(705): Defined rule: <default.WeatherTypeFuture>
# INFO: jsgf.c(705): Defined rule: <default.g00096>
# INFO: jsgf.c(705): Defined rule: <default.Time>
# INFO: jsgf.c(705): Defined rule: <default.g00098>
# INFO: jsgf.c(705): Defined rule: <default.Day>
# INFO: jsgf.c(705): Defined rule: <default.g00100>
# INFO: jsgf.c(705): Defined rule: <default.g00101>
# INFO: jsgf.c(705): Defined rule: <default.wwis_weather>
# INFO: jsgf.c(705): Defined rule: <default.g00103>
# INFO: jsgf.c(705): Defined rule: <default.command>
# INFO: jsgf.c(705): Defined rule: <default.g00105>
# INFO: jsgf.c(705): Defined rule: PUBLIC <default.default>
# INFO: main.c(116): No -toprule was given; grabbing the first public rule: '<default.default>' of the grammar 'default'.
# INFO: fsg_model.c(843): Writing FSG file 'vosk_lm/default.fsg'

# %%
for pronunciation in phonetisaurus.predict(
    words=['magicvoice'],
    model_path=os.path.expanduser('~/.config/naomi/vosk/vosk-model-en-us-0.22-compile/db/en-g2p/en.fst')
):
    print(" ".join(pronunciation[1]))
# Out:
# m { dZ I k v OI s
